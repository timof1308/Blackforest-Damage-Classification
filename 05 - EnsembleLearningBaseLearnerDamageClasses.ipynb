# %% [markdown]
# # Ensemble Learning - Base-Models
# Build and optimize base models

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import os
import json

import pickle

from sklearn import metrics
from sklearn.base import clone
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, HistGradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

from imblearn.ensemble import BalancedRandomForestClassifier, RUSBoostClassifier

from collections import Counter

pd.set_option("display.max_columns", None)

# %%
DATA_PATH = "./data"
EXPORT_PATH = f"{DATA_PATH}/BaseLearner/v1"

SPECIES_CODE = {
    "1":"Deciduous",
    "2":"Conifer",
    "1 2":"Mixed"
}

SPECIES_CODE_INVERSE = {
    "Deciduous": "1",
    "Conifer": "2",
    "Mixed": "1 2"
}

# %% [markdown]
# ## Data Import & Data Preparation

# %%
df = pd.read_csv(f"{DATA_PATH}/location_cluster.csv")

df = df.sort_values(by="year")

# -----

def is_healthy(damage_class_group:str)->int:
    if damage_class_group == "healthy":
        return 1
    else:
        return 0
    
def is_damaged(damage_class_group:str)->int:
    if damage_class_group == "damaged":
        return 1
    else:
        return 0
    
def is_dead(damage_class_group:str)->int:
    if damage_class_group == "dead":
        return 1
    else:
        return 0
    
df["is_healthy"] = df["damage_class_group"].apply(lambda x: is_healthy(x))
df["is_damaged"] = df["damage_class_group"].apply(lambda x: is_damaged(x))
df["is_dead"] = df["damage_class_group"].apply(lambda x: is_dead(x))

# -----

static_cols = [
    col for col in df.columns if "location_cluster_" in col
]
static_cols.append("tree_1")

vegetation_cols = [
    col for col in df.columns if (("ndvi" in col) or ("evi2" in col)) and not col.endswith('max')
]

weather_cols = [
    'autumn_humidity',
    'autumn_rain_mm',
    'autumn_sun_h',
    'extreme_heat_day',
    'frozen_day',
    'heat_day',
    'heavy_rain',
    'spring_humidity',
    'spring_rain_mm',
    'spring_sun_h',
    'storm',
    'summer_humidity',
    'summer_longest_heat_wave',
    'summer_periods_without_rain_summer',
    'summer_rain_mm',
    'summer_sun_h',
    'winter_humidity',
    'winter_longest_cold_wave',
    'winter_rain_mm',
    'winter_snow_cm',
    'winter_sun_h',
]

all_features = static_cols + vegetation_cols + weather_cols

df[all_features].head()
# Out:
#       location_cluster_0  location_cluster_1  location_cluster_2  \
# 0                      0                   1                   0
# 5188                   0                   0                   0
# 5187                   0                   0                   0
# 5186                   0                   0                   0
# 5185                   0                   0                   0
#
#       location_cluster_3  location_cluster_4  location_cluster_5  \
# 0                      0                   0                   0
# 5188                   1                   0                   0
# 5187                   1                   0                   0
# 5186                   1                   0                   0
# 5185                   1                   0                   0
#
#       location_cluster_6  location_cluster_7  location_cluster_8  \
# 0                      0                   0                   0
# 5188                   0                   0                   0
# 5187                   0                   0                   0
# 5186                   0                   0                   0
# 5185                   0                   0                   0
#
#       location_cluster_9  location_cluster_10  location_cluster_11  \
# 0                      0                    0                    0
# 5188                   0                    0                    0
# 5187                   0                    0                    0
# 5186                   0                    0                    0
# 5185                   0                    0                    0
#
#       location_cluster_12  location_cluster_13    tree_1      evi2    evi2-1  \
# 0                       0                    0 -0.780422  0.247127  0.134649
# 5188                    0                    0 -0.630696 -1.377409  0.134649
# 5187                    0                    0 -0.630696 -1.606661  0.134649
# 5186                    0                    0 -0.630696 -1.074025  0.134649
# 5185                    0                    0 -0.630696 -1.332807  0.134649
#
#       evi2_diff  evi2_max_diff  evi2_raster  evi2_raster-1  evi2_raster_diff  \
# 0     -0.063166       0.558887    -1.965227       2.321263          2.190397
# 5188   1.210990       1.661654    -1.010216       0.702443          0.638921
# 5187   1.546983       1.771145    -1.010216       0.702443          0.372483
# 5186   0.871901       1.478956    -1.010216       0.702443          0.858797
# 5185   1.155192       1.658395    -1.010216       0.702443          0.678140
#
#       evi2_vegetation_raster  evi2_vegetation_raster-1  \
# 0                  -1.591913                  1.467303
# 5188               -0.897612                  0.639956
# 5187               -0.897612                  0.639956
# 5186               -0.897612                  0.639956
# 5185               -0.897612                  0.639956
#
#       evi2_vegetation_raster_diff      ndvi    ndvi-1  ndvi_diff  \
# 0                        2.389869  0.269184  0.155518  -0.056732
# 5188                     0.116478 -1.394638  0.155518   1.023457
# 5187                    -0.247533 -1.639614  0.155518   1.352077
# 5186                     0.449890 -1.072860  0.155518   0.711611
# 5185                     0.173522 -1.347134  0.155518   0.970864
#
#       ndvi_max_diff  ndvi_raster  ndvi_raster-1  ndvi_raster_diff  \
# 0          0.396759    -2.000923       2.376153          4.699451
# 5188       1.773875    -1.020630       0.601524         -0.686361
# 5187       1.909480    -1.020630       0.601524         -1.216333
# 5186       1.542268    -1.020630       0.601524         -0.168402
# 5185       1.763622    -1.020630       0.601524         -0.600060
#
#       ndvi_vegetation_raster  ndvi_vegetation_raster-1  \
# 0                  -1.625971                  1.476802
# 5188               -0.906359                  0.610358
# 5187               -0.906359                  0.610358
# 5186               -0.906359                  0.610358
# 5185               -0.906359                  0.610358
#
#       ndvi_vegetation_raster_diff  autumn_humidity  autumn_rain_mm  \
# 0                        3.188868         2.349058       -0.032661
# 5188                    -1.136011         1.391816        0.207266
# 5187                    -1.472954         1.391816        0.207266
# 5186                    -0.695910         1.391816        0.207266
# 5185                    -1.071161         1.391816        0.207266
#
#       autumn_sun_h  extreme_heat_day  frozen_day  heat_day  heavy_rain  \
# 0        -0.510027         -0.844847    0.729139  1.259041    0.020538
# 5188     -0.081468          1.680325   -0.857075  1.889191    0.691020
# 5187     -0.081468          1.680325   -0.857075  1.889191    0.691020
# 5186     -0.081468          1.680325   -0.857075  1.889191    0.691020
# 5185     -0.081468          1.680325   -0.857075  1.889191    0.691020
#
#       spring_humidity  spring_rain_mm  spring_sun_h     storm  \
# 0            0.030137       -0.308301      0.671584 -1.489254
# 5188        -0.369506        0.323830      0.515489  0.852785
# 5187        -0.369506        0.323830      0.515489  0.852785
# 5186        -0.369506        0.323830      0.515489  0.852785
# 5185        -0.369506        0.323830      0.515489  0.852785
#
#       summer_humidity  summer_longest_heat_wave  \
# 0            0.595120                  0.671331
# 5188        -0.814671                  0.897376
# 5187        -0.814671                  0.897376
# 5186        -0.814671                  0.897376
# 5185        -0.814671                  0.897376
#
#       summer_periods_without_rain_summer  summer_rain_mm  summer_sun_h  \
# 0                               1.252978        0.111377     -0.265597
# 5188                            0.046127       -0.719613     -0.140728
# 5187                            0.046127       -0.719613     -0.140728
# 5186                            0.046127       -0.719613     -0.140728
# 5185                            0.046127       -0.719613     -0.140728
#
#       winter_humidity  winter_longest_cold_wave  winter_rain_mm  \
# 0             1.79314                  0.343276       -1.081905
# 5188          0.69179                 -0.815622        0.119561
# 5187          0.69179                 -0.815622        0.119561
# 5186          0.69179                 -0.815622        0.119561
# 5185          0.69179                 -0.815622        0.119561
#
#       winter_snow_cm  winter_sun_h
# 0           0.637993     -0.509518
# 5188       -0.193376     -1.501934
# 5187       -0.193376     -1.501934
# 5186       -0.193376     -1.501934
# 5185       -0.193376     -1.501934

# %% [markdown]
# ### Definition of Functions

# %%
def train_test_split_by_observation(data_frame:pd.DataFrame, target:str, features:list):
    data_frame["key"] = data_frame["observation_id"] + ":" + data_frame["year"].astype(str)
    
    # group by observation_id and year to get unique observations by year only to prevent overfitting
    df_group = data_frame.groupby(["observation_id", "year"]).agg({"damage_class_group": lambda x: x.value_counts().index[0], target: lambda x: x.value_counts().index[0], "aoi": "first"}).reset_index()
    # remove all damaged classes that are not in BF
    #df_group = df_group.loc[~((df_group.damage_class_group == "damaged") & (df_group.aoi != "blackforest"))]
    y_observation_id = df_group.pop(target)
    X_observation_id = df_group

    # key to identify splitted data
    X_observation_id["key"] = X_observation_id["observation_id"] + ":" + X_observation_id["year"].astype(str)
    # train test split
    X_train_observation_id, X_test_observation_id, y_train_observation_id, y_test_observation_id = train_test_split(X_observation_id, y_observation_id, train_size=0.8, stratify=y_observation_id, random_state=2022)

    # filter for train test samples based on observation:year
    _X_train = data_frame.loc[data_frame.key.isin(list(X_train_observation_id.key))][features]
    _X_test = data_frame.loc[data_frame.key.isin(list(X_test_observation_id.key))][features]

    return _X_train, _X_test

def define_class_weight(y:np.array)->dict:
    class_weights = dict()

    for _class, count in Counter(y).items():
        weight = len(y) / (len(Counter(y)) * count)
        class_weights[_class] = weight
    return class_weights

def define_pos_scale(y:np.array)->float:
    return dict(Counter(y))[0] / dict(Counter(y))[1]
    
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
def parameter_tuning(_model=None, _params=None, _scoring=None, _X=None, _y=None):
    sk_fold = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)

    randomized_clf_param_tuning = RandomizedSearchCV(estimator=_model, param_distributions=_params, scoring=_scoring, cv=sk_fold, n_jobs=58, n_iter=100, verbose=0)

    randomized_clf_param_tuning.fit(_X, _y)
    return randomized_clf_param_tuning.best_params_

def apply_prediction(pos_probs, threshold):
     return (pos_probs >= threshold).astype('int')
    
def get_model_params(_model: str, _target: str, _species:str)->dict:
    base_model = clone(pickle.load(open(f"{DATA_PATH}/BaseLearner/tmp/{_model}_{_species}_{_target}.sav", 'rb')))
    return base_model.get_params()

def roc_auc(actual, pred_proba, axes):
    fpr, tpr, thresholds = metrics.roc_curve(actual, pred_proba)
    # calculate the g-mean for each threshold
    gmeans = np.sqrt(tpr * (1-fpr))
    # locate the index of the largest g-mean
    ix = np.argmax(gmeans)
    if axes:
        # plot the roc curve for the model
        sns.lineplot([0,1], [0,1], linestyle='--', label='No Skill', color="tab:gray", ax=axes, err_style=None)
        sns.lineplot(fpr, tpr, label='Model', color="black", ax=axes, err_style=None)
        sns.scatterplot([fpr[ix]], [tpr[ix]], marker='^', color='tab:red', label=f'Optimal threshold @ {thresholds[ix]:.3f}', s=150, zorder=2, ax=axes)
    
    return thresholds[ix], gmeans[ix]

def prc_rc(actual, pred_proba, axes):
    precision, recall, thresholds = metrics.precision_recall_curve(actual, pred_proba)
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    # plot the roc curve for the model
    no_skill = len(actual[actual==1]) / len(actual)
    if axes:
        sns.lineplot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill', color="tab:gray", ax=axes, err_style=None)
        sns.lineplot(recall, precision, label='Model', color="black", ax=axes, err_style=None)
        sns.scatterplot([recall[ix]], [precision[ix]], marker='^', color='tab:red', label=f'Optimal threshold @ {thresholds[ix]:.3f}', s=150, zorder=2, ax=axes)

    return thresholds[ix], fscore[ix]
    
def tune_threshold(actual, pred_proba, axes):
    # Array for finding the optimal threshold
    thresholds = np.arange(0.0, 1.0, 0.001)
    fscore = np.zeros(shape=(len(thresholds)))
    # Fit the model
    def to_labels(pos_probs, threshold):
         return (pos_probs >= threshold).astype('int')
    fscore = [metrics.f1_score(actual, to_labels(pred_proba, t)) for t in thresholds]
        
    # Find the optimal threshold
    ix = np.argmax(fscore)
    if axes:
        sns.lineplot(thresholds, fscore, color="black", ax=axes, err_style=None)
        sns.scatterplot([thresholds[ix]], [fscore[ix]], marker='^', color='tab:red', label=f'Optimal threshold @ {thresholds[ix]:.3f}', s=150, zorder=2, ax=axes)

    return thresholds[ix], fscore[ix]


def parse_results(data_frame:pd.DataFrame):
    param_cols = [col for col in data_frame.columns if col.startswith("params")]
    metric_cols = [col for col in data_frame.columns if col.startswith("metrics")]
    feat_permutation_cols = [col for col in data_frame.columns if col.startswith("feature_permutaion_importance")]

    param_cols.extend(["model", "target", "species"])
    metric_cols.extend(["model", "target", "species"])
    feat_permutation_cols.extend(["model", "target", "species"])
    
    metric_groups = ["roc", "prc", "tuning"]
    actual_metrics = ["threshold", "cohen_kappa", "f1", "recall", "precision", "tn", "fp", "fn", "tp"]

    metrics_values = []
    for metric_group in metric_groups:
        for _i, _r in data_frame.iterrows():
            vals = {"group": metric_group, "model": _r["model"], "target": _r["target"], "species": _r["species"], "auc": _r["metrics.auc"]}
            for col in metric_cols:
                for _m in actual_metrics:
                    if _m in col and metric_group in col:
                        vals[_m] = _r[col]

            metrics_values.append(vals)

    df_metrics = pd.json_normalize(metrics_values)
    df_metrics = df_metrics.sort_values(by="f1", ascending=False)
    #print(f"model results -> {df_metrics.shape[0]} x {list(df_metrics.columns)}")

    best_model_selection = list()
    for _i, _r in df_metrics.groupby(["target", "species", "model"]).size().reset_index().iterrows():
        df_filter = df_metrics.loc[(df_metrics.target == _r.target) & (df_metrics.species == _r.species) & (df_metrics.model == _r.model)].sort_values(by="threshold", ascending=False)
        best_model_selection.append(df_filter.loc[df_filter.cohen_kappa == df_filter.cohen_kappa.max()].iloc[0][["target", "species", "model", "group"]].values)

    df_model_selection = pd.DataFrame(data=best_model_selection, columns=["target", "species", "model", "group"])
    df_best_metrics = df_metrics.merge(df_model_selection, on=["target", "species", "model", "group"], how="inner").drop_duplicates()
    #print(f"best model results -> {df_best_metrics.shape[0]} x {list(df_best_metrics.columns)}")

    df_parameter = data_frame[param_cols].melt(id_vars=param_cols[-3:], var_name="param", value_name="val")
    df_parameter["param"] = df_parameter["param"].apply(lambda x: x.replace("params.", ""))
    df_parameter = df_parameter.dropna()
    #print(f"model params -> {df_parameter.shape[0]} x {list(df_parameter.columns)}")

    df_feature_importance = data_frame[feat_permutation_cols].melt(id_vars=feat_permutation_cols[-3:], var_name="feature", value_name="feature_importance")
    df_feature_importance["feature"] = df_feature_importance["feature"].apply(lambda x: x.replace("feature_permutaion_importance.", ""))
    df_feature_importance = df_feature_importance.sort_values(by="feature_importance", ascending=False)
    #print(f"features -> {df_feature_importance.shape[0]} x {list(df_feature_importance.columns)}")
    
    return df_metrics, df_best_metrics, df_parameter, df_feature_importance

# %% [markdown]
# ### Model Parameters

# %%
PARAMS_RF = {
    'max_depth': np.arange(16, 256, 16),
    'max_features': ["sqrt"],
    'min_samples_leaf': np.arange(2, 16, 2),
    'min_samples_split': np.arange(2, 16, 2),
    'n_estimators': np.arange(32, 512, 16),
    'n_jobs': [58],
    'warm_start': [True, False],
    'random_state': [2022],
}
PARAMS_XGB = {
    'max_depth': np.arange(3, 8, 1),
    'learning_rate': np.arange(0.001, 0.01, 0.002),
    'n_estimators': np.arange(50, 500, 15),
    'colsample_bytree': np.arange(0.5, 1, 0.05),
    'subsample': np.arange(0.5, 1, 0.05),
    'eval_metric': ["aucpr", "auc"],
    'objective': ['binary:logistic'],
    'gamma': np.arange(0, 1, 0.05),
    'lambda': np.arange(0, 1, 0.1),
    'seed': [2022],
    'n_jobs': [58],
}
PARAMS_KN = {
    'n_neighbors': np.arange(2, 18, 1),
    'weights': ["distance", "uniform"],
    'algorithm': ['ball_tree', 'kd_tree', 'brute'],
    'leaf_size': np.arange(10, 50, 2),
    'p': [1, 2],
    'n_jobs': [58],
    'metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis']
}
PARAMS_DT = {
    'criterion': ["gini", "entropy"],
    'splitter': ["random", "best"],
    'max_depth': np.arange(2, 32, 1),
    'min_samples_split': np.arange(2, 32, 2),
    'min_samples_leaf': np.arange(1, 16, 1),
    'max_features': ["sqrt", "log2"],
    'random_state': [2022],
    'min_weight_fraction_leaf': np.arange(0.0, 1.0, 0.05),
    'max_leaf_nodes': np.arange(1, 2048, 32),
    'min_impurity_decrease': np.arange(0.0, 1.0, 0.05),
    'ccp_alpha': np.arange(0, 1, 1),
}
PARAMS_HGB = {
    'loss': ['binary_crossentropy'],
    'learning_rate': np.arange(0.01, 0.05, 0.0005),
    'max_iter': np.arange(25, 500, 25),
    'max_leaf_nodes': np.arange(1, 128, 7),
    'max_depth': np.arange(1, 128, 7),
    'min_samples_leaf': np.arange(2, 32, 1),
    'l2_regularization': np.arange(0.0, 1.0, 0.05),
    #'warm_start': [True, False],
    'scoring': ["f1", "roc_auc"],
    #'tol': np.arange(1e-7, 9e-7, 1e-8),
    'random_state': [2022],
}
PARAMS_BRF = {
    'max_depth': np.arange(16, 256, 16),
    'max_features': ["sqrt"],
    'min_samples_leaf': np.arange(2, 24, 2),
    'min_samples_split': np.arange(2, 24, 2),
    'n_estimators': np.arange(32, 512, 16),
    'n_jobs': [58],
    'warm_start': [True, False],
    'random_state': [2022],
    #'class_weight': [define_class_weight(_y.values)]
}
PARAMS_RUS = {
    'replacement': [True, False],
    'learning_rate': np.arange(0.001, 0.1, 0.002),
    'n_estimators': np.arange(50, 500, 15),
    'algorithm': ["SAMME", "SAMME.R"],
    'random_state': [2022],
}
PARAMS_ADA = {
    'learning_rate': np.arange(0.05, 0.5, 0.025),
    'n_estimators': np.arange(50, 500, 15),
    'algorithm': ["SAMME", "SAMME.R"],
    'random_state': [2022],
}
PARAMS_SVM = {
    'gamma': np.arange(0.001, 1, 0.005),
    'C': np.arange(0.1, 10, 0.25),
    'shrinking': [False, True],
    'kernel': ['rbf', 'poly', 'sigmoid'],
    'probability': [True],
    'tol': np.arange(0.001, 0.01, 0.001),
    'decision_function_shape': ['ovo'],
    'random_state': [2022],
}

# %% [markdown]
# ### Define Hold-Out

# %%
np.random.seed(2022)

binned_data = dict()
for species in ["1", "2", "1 2"]:
    _binned = df.copy()

    _binned = _binned.loc[_binned.list_tree_sp_cat_ids == species]

    for col in all_features:
        _binned[col] = pd.qcut(_binned[col].rank(method='first'), 10) # _binned[col]
        _binned[col] =_binned[col].cat.codes

    min_max_scaler = MinMaxScaler()
    _binned[all_features] = min_max_scaler.fit_transform(_binned[all_features])

    validation_observation_ids = np.random.choice(_binned.loc[_binned.aoi == "blackforest"].observation_id.unique(), size=2)
    _validation = _binned.loc[_binned.observation_id.isin(validation_observation_ids)]
    
    _train, _test = train_test_split_by_observation(data_frame=_binned.loc[~_binned.observation_id.isin(validation_observation_ids)], target="damage_class_group", features=_binned.columns)
    _test = pd.concat([_test, _validation])
    
    splitted_data = {
        'train': _train,
        'test': _test,
        'validation': _validation
    }
    
    binned_data[species] = splitted_data

# %% [markdown]
# ## Base Learner
# The following steps are performed for all damage classes:
# 1) Backward Feature Elemination to identify the 50% most relevant features.
# 2) Perform parameter optimization of the base models.
# 3) Bagging ensemble
# 4) Perform Feature Permutation Importance to calculate the relevance of the features used.
# 5) Evaluate estimates including the determination of the decision boundary as well as the metrics
# 6) Export the results
#
# ### Damaged Vegetation

# %%
SPECIESES = ["1", "2", "1 2"]
MODELS = ["RandomForestClassifier", "BalancedRandomForestClassifier", "DecisionTreeClassifier", "KNeighborsClassifier", "SVM", "RUSBoostClassifier" , "AdaBoostClassifier", "XGBClassifier", "HistGradientBoostingClassifier"]
TARGET = "is_damaged"

binary_classifcation_results = list()

for SPECIES in SPECIESES:
    for MODEL in MODELS:
        if os.path.exists(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json"):
            continue
        print("-"*100)
        print(f"{MODEL} -> {SPECIES_CODE[SPECIES]}@{TARGET}")
        print("\t performing backward feature elemination...")
        init_model_params = get_model_params(_model=MODEL, _target=TARGET, _species=SPECIES_CODE[SPECIES])

        if "class_weight" in init_model_params:
            init_model_params["class_weight"] = define_class_weight(binned_data[SPECIES]["train"][TARGET])
        if "pos_scale" in init_model_params:
            init_model_params["pos_scale"] = define_pos_scale(binned_data[SPECIES]["train"][TARGET])

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)
        kappa_scorer = metrics.make_scorer(metrics.cohen_kappa_score)

        if MODEL == "RandomForestClassifier":
            model = RandomForestClassifier(**init_model_params)
        elif MODEL == "XGBClassifier":
            model = xgb.XGBClassifier(**init_model_params)
        elif MODEL == "KNeighborsClassifier":
            model = KNeighborsClassifier(**init_model_params)
        elif MODEL == "DecisionTreeClassifier":
            model = DecisionTreeClassifier(**init_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            model = HistGradientBoostingClassifier(**init_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            model = BalancedRandomForestClassifier(**init_model_params)
        elif MODEL == "RUSBoostClassifier":
            model = RUSBoostClassifier(**init_model_params)
        elif MODEL == "AdaBoostClassifier":
            model = AdaBoostClassifier(**init_model_params)
        else: #SVM
            model = SVC(**init_model_params)

        sfs = SequentialFeatureSelector(estimator=model, direction="backward", scoring=kappa_scorer, cv=skf, n_jobs=58)
        sfs.fit(binned_data[SPECIES]["train"][all_features], binned_data[SPECIES]["train"][TARGET])
        relevant_features = list(binned_data[SPECIES]["train"][all_features].columns[sfs.get_support()])

        # TRAINING DATA
        X_train = binned_data[SPECIES]["train"][relevant_features]
        y_train = binned_data[SPECIES]["train"][TARGET]
        # TEST DATA
        X_test = binned_data[SPECIES]["test"][relevant_features]
        y_test = binned_data[SPECIES]["test"][TARGET]

        print("\t performing hyperparameter tuning...")

        if MODEL == "RandomForestClassifier":
            params_rf = PARAMS_RF
            params_rf["class_weight"] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=RandomForestClassifier(), _params=params_rf, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = RandomForestClassifier(**fitted_model_params)
        elif MODEL == "XGBClassifier":
            params_xgb = PARAMS_XGB
            params_xgb['scale_pos_weight'] = [define_pos_scale(y_train.values)]
            fitted_model_params = parameter_tuning(_model=xgb.XGBClassifier(), _params=params_xgb, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = xgb.XGBClassifier(**fitted_model_params)
        elif MODEL == "KNeighborsClassifier":
            params_kn = PARAMS_KN
            fitted_model_params = parameter_tuning(_model=KNeighborsClassifier(), _params=params_kn, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = KNeighborsClassifier(**fitted_model_params)
        elif MODEL == "DecisionTreeClassifier":
            params_dt = PARAMS_DT
            params_dt['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=DecisionTreeClassifier(), _params=params_dt, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = DecisionTreeClassifier(**fitted_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            params_hgb = PARAMS_HGB
            fitted_model_params = parameter_tuning(_model=HistGradientBoostingClassifier(), _params=params_hgb, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = HistGradientBoostingClassifier(**fitted_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            params_brf = PARAMS_BRF
            fitted_model_params = parameter_tuning(_model=BalancedRandomForestClassifier(), _params=params_brf, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = BalancedRandomForestClassifier(**fitted_model_params)
        elif MODEL == "RUSBoostClassifier":
            params_rus = PARAMS_RUS
            fitted_model_params = parameter_tuning(_model=RUSBoostClassifier(), _params=params_rus, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = RUSBoostClassifier(**fitted_model_params)
        elif MODEL == "AdaBoostClassifier":
            params_ada = PARAMS_ADA
            fitted_model_params = parameter_tuning(_model=AdaBoostClassifier(), _params=params_ada, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = AdaBoostClassifier(**fitted_model_params)
        else:
            params_svm = PARAMS_SVM
            params_svm['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=SVC(), _params=params_svm, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = SVC(**fitted_model_params)

        # CREATING BAGGING CLASSIFIER
        model = BaggingClassifier(base_estimator=model, n_estimators=15, max_samples=.2, max_features=1., bootstrap=True, bootstrap_features=True, oob_score=True, n_jobs=16)
        print("\t fitting model...")
        model.fit(X_train, y_train)
        # save model
        pickle.dump(model, open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.sav", 'wb'))

        # predict probabilities
        y_pred_proba = model.predict_proba(X_test)

        print("\t performing permutation feature importance...")
        from sklearn.inspection import permutation_importance
        permutation_importance = permutation_importance(model, X_test, y_test, n_repeats=5, random_state=2022, n_jobs=32, scoring=kappa_scorer)
        permutation_importance_obj = {}
        for i, feat_imp in enumerate(permutation_importance.importances_mean):
            permutation_importance_obj[all_features[i]] = feat_imp

        print("\t evaluating...")
        results = {}
        results["species"] = SPECIES_CODE[SPECIES]
        results["model"] = MODEL
        results["target"] = TARGET
        results["params"] = fitted_model_params
        results["relevant_features"] = relevant_features
        results["feature_permutaion_importance"] = permutation_importance_obj

        results["metrics"] = {}
        results["metrics"]["auc"] = metrics.roc_auc_score(y_test.values, y_pred_proba[:, 1])

        ## ROC AUC
        results["metrics"]["roc"] = {}
        threshold_roc, gmean_roc = roc_auc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["roc"]["threshold"] = threshold_roc
        y_pred_roc = apply_prediction(y_pred_proba[:, 1], threshold_roc)
        results["metrics"]["roc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["f1"] = metrics.f1_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["recall"] = metrics.recall_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["precision"] = metrics.precision_score(y_test.values, y_pred_roc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_roc).ravel()
        results["metrics"]["roc"]["tn"] = tn
        results["metrics"]["roc"]["fp"] = fp
        results["metrics"]["roc"]["fn"] = fn
        results["metrics"]["roc"]["tp"] = tp

        ## PRC
        results["metrics"]["prc"] = {}
        threshold_prc, fscore_prc = prc_rc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["prc"]["threshold"] = threshold_prc
        y_pred_prc = apply_prediction(y_pred_proba[:, 1], threshold_prc)
        results["metrics"]["prc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["f1"] = metrics.f1_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["recall"] = metrics.recall_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["precision"] = metrics.precision_score(y_test.values, y_pred_prc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_prc).ravel()
        results["metrics"]["prc"]["tn"] = tn
        results["metrics"]["prc"]["fp"] = fp
        results["metrics"]["prc"]["fn"] = fn
        results["metrics"]["prc"]["tp"] = tp

        ## TUNING
        results["metrics"]["tuning"] = {}
        threshold_tuning, fscore_tuneing = tune_threshold(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["tuning"]["threshold"] = threshold_tuning
        y_pred_tuning = apply_prediction(y_pred_proba[:, 1], threshold_tuning)
        results["metrics"]["tuning"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["f1"] = metrics.f1_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["recall"] = metrics.recall_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["precision"] = metrics.precision_score(y_test.values, y_pred_tuning)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_tuning).ravel()
        results["metrics"]["tuning"]["tn"] = tn
        results["metrics"]["tuning"]["fp"] = fp
        results["metrics"]["tuning"]["fn"] = fn
        results["metrics"]["tuning"]["tp"] = tp

        # quick export to dump data
        with open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json", 'w', encoding='utf-8') as f:
            json.dump(str(dict((k, v) for k,v in results.items())), f, ensure_ascii=False, indent=4)
        pd.json_normalize(results).to_csv(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.csv", index=False)

        binary_classifcation_results.append(results)

print("-"*75)
print(f"EXPORTING OVERALL RESULTS TO {EXPORT_PATH}/modelling_pipeline_results.csv")
print("-"*75)
df_result = pd.json_normalize(binary_classifcation_results)
df_result.to_csv(f"{EXPORT_PATH}/modelling_pipeline_results.csv", index=False)
df_result
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ---------------------------------------------------------------------------
# EXPORTING OVERALL RESULTS TO ./results/optimization/v1/modelling_pipeline_results.csv
# ---------------------------------------------------------------------------
#       species                           model      target  \
# 0   Deciduous          RandomForestClassifier  is_damaged
# 1   Deciduous  BalancedRandomForestClassifier  is_damaged
# 2   Deciduous          DecisionTreeClassifier  is_damaged
# 3   Deciduous            KNeighborsClassifier  is_damaged
# 4   Deciduous                             SVM  is_damaged
# 5   Deciduous              RUSBoostClassifier  is_damaged
# 6   Deciduous              AdaBoostClassifier  is_damaged
# 7   Deciduous                   XGBClassifier  is_damaged
# 8   Deciduous  HistGradientBoostingClassifier  is_damaged
# 9     Conifer          RandomForestClassifier  is_damaged
# 10    Conifer  BalancedRandomForestClassifier  is_damaged
# 11    Conifer          DecisionTreeClassifier  is_damaged
# 12    Conifer            KNeighborsClassifier  is_damaged
# 13    Conifer                             SVM  is_damaged
# 14    Conifer              RUSBoostClassifier  is_damaged
# 15    Conifer              AdaBoostClassifier  is_damaged
# 16    Conifer                   XGBClassifier  is_damaged
# 17    Conifer  HistGradientBoostingClassifier  is_damaged
# 18      Mixed          RandomForestClassifier  is_damaged
# 19      Mixed  BalancedRandomForestClassifier  is_damaged
# 20      Mixed          DecisionTreeClassifier  is_damaged
# 21      Mixed            KNeighborsClassifier  is_damaged
# 22      Mixed                             SVM  is_damaged
# 23      Mixed              RUSBoostClassifier  is_damaged
# 24      Mixed              AdaBoostClassifier  is_damaged
# 25      Mixed                   XGBClassifier  is_damaged
# 26      Mixed  HistGradientBoostingClassifier  is_damaged
#
#                                     relevant_features params.warm_start  \
# 0   [location_cluster_2, location_cluster_3, locat...              True
# 1   [location_cluster_0, location_cluster_4, locat...              True
# 2   [tree_1, evi2_max_diff, evi2_raster, evi2_rast...               NaN
# 3   [location_cluster_0, location_cluster_4, locat...               NaN
# 4   [location_cluster_0, location_cluster_3, locat...               NaN
# 5   [location_cluster_0, location_cluster_1, locat...               NaN
# 6   [location_cluster_0, location_cluster_1, locat...               NaN
# 7   [location_cluster_0, location_cluster_4, locat...               NaN
# 8   [location_cluster_0, location_cluster_3, locat...               NaN
# 9   [location_cluster_1, location_cluster_5, locat...              True
# 10  [location_cluster_0, location_cluster_4, locat...             False
# 11  [location_cluster_0, location_cluster_4, locat...               NaN
# 12  [location_cluster_0, location_cluster_1, locat...               NaN
# 13  [location_cluster_4, location_cluster_5, locat...               NaN
# 14  [location_cluster_0, location_cluster_1, locat...               NaN
# 15  [location_cluster_3, location_cluster_4, locat...               NaN
# 16  [location_cluster_1, location_cluster_6, locat...               NaN
# 17  [location_cluster_0, location_cluster_2, locat...               NaN
# 18  [location_cluster_2, location_cluster_4, locat...              True
# 19  [location_cluster_4, location_cluster_5, locat...              True
# 20  [location_cluster_5, location_cluster_9, locat...               NaN
# 21  [location_cluster_1, location_cluster_2, locat...               NaN
# 22  [location_cluster_0, location_cluster_5, locat...               NaN
# 23  [location_cluster_4, location_cluster_5, locat...               NaN
# 24  [location_cluster_5, location_cluster_10, loca...               NaN
# 25  [location_cluster_2, location_cluster_3, locat...               NaN
# 26  [location_cluster_0, location_cluster_1, locat...               NaN
#
#     params.random_state  params.n_jobs  params.n_estimators  \
# 0                2022.0           58.0                112.0
# 1                2022.0           58.0                160.0
# 2                2022.0            NaN                  NaN
# 3                   NaN           58.0                  NaN
# 4                2022.0            NaN                  NaN
# 5                2022.0            NaN                395.0
# 6                2022.0            NaN                335.0
# 7                   NaN           58.0                335.0
# 8                2022.0            NaN                  NaN
# 9                2022.0           58.0                 80.0
# 10               2022.0           58.0                464.0
# 11               2022.0            NaN                  NaN
# 12                  NaN           58.0                  NaN
# 13               2022.0            NaN                  NaN
# 14               2022.0            NaN                425.0
# 15               2022.0            NaN                455.0
# 16                  NaN           58.0                470.0
# 17               2022.0            NaN                  NaN
# 18               2022.0           58.0                448.0
# 19               2022.0           58.0                480.0
# 20               2022.0            NaN                  NaN
# 21                  NaN           58.0                  NaN
# 22               2022.0            NaN                  NaN
# 23               2022.0            NaN                485.0
# 24               2022.0            NaN                455.0
# 25                  NaN           58.0                470.0
# 26               2022.0            NaN                  NaN
#
#     params.min_samples_split  params.min_samples_leaf params.max_features  \
# 0                        2.0                      2.0                sqrt
# 1                        6.0                      2.0                sqrt
# 2                        4.0                     10.0                log2
# 3                        NaN                      NaN                 NaN
# 4                        NaN                      NaN                 NaN
# 5                        NaN                      NaN                 NaN
# 6                        NaN                      NaN                 NaN
# 7                        NaN                      NaN                 NaN
# 8                        NaN                      9.0                 NaN
# 9                        4.0                      2.0                sqrt
# 10                       2.0                      2.0                sqrt
# 11                      20.0                      4.0                sqrt
# 12                       NaN                      NaN                 NaN
# 13                       NaN                      NaN                 NaN
# 14                       NaN                      NaN                 NaN
# 15                       NaN                      NaN                 NaN
# 16                       NaN                      NaN                 NaN
# 17                       NaN                     15.0                 NaN
# 18                       2.0                      2.0                sqrt
# 19                       4.0                      2.0                sqrt
# 20                      10.0                      1.0                sqrt
# 21                       NaN                      NaN                 NaN
# 22                       NaN                      NaN                 NaN
# 23                       NaN                      NaN                 NaN
# 24                       NaN                      NaN                 NaN
# 25                       NaN                      NaN                 NaN
# 26                       NaN                      3.0                 NaN
#
#     params.max_depth  params.class_weight.1  params.class_weight.0  \
# 0              176.0               0.569779               4.082725
# 1               96.0                    NaN                    NaN
# 2                6.0               0.569779               4.082725
# 3                NaN                    NaN                    NaN
# 4                NaN               0.569779               4.082725
# 5                NaN                    NaN                    NaN
# 6                NaN                    NaN                    NaN
# 7                7.0                    NaN                    NaN
# 8               99.0                    NaN                    NaN
# 9              192.0               0.584908               3.444356
# 10             144.0                    NaN                    NaN
# 11               8.0               0.584908               3.444356
# 12               NaN                    NaN                    NaN
# 13               NaN               0.584908               3.444356
# 14               NaN                    NaN                    NaN
# 15               NaN                    NaN                    NaN
# 16               6.0                    NaN                    NaN
# 17               8.0                    NaN                    NaN
# 18             128.0               0.559012               4.736434
# 19             240.0                    NaN                    NaN
# 20               9.0               0.559012               4.736434
# 21               NaN                    NaN                    NaN
# 22               NaN               0.559012               4.736434
# 23               NaN                    NaN                    NaN
# 24               NaN                    NaN                    NaN
# 25               6.0                    NaN                    NaN
# 26              43.0                    NaN                    NaN
#
#     feature_permutaion_importance.location_cluster_0  \
# 0                                           0.021601
# 1                                           0.015279
# 2                                           0.031191
# 3                                          -0.000235
# 4                                           0.014817
# 5                                          -0.023092
# 6                                           0.075311
# 7                                           0.023165
# 8                                           0.006142
# 9                                          -0.011568
# 10                                         -0.005367
# 11                                         -0.001395
# 12                                          0.015241
# 13                                          0.038021
# 14                                          0.038357
# 15                                          0.049659
# 16                                          0.001830
# 17                                          0.015653
# 18                                          0.001704
# 19                                          0.062924
# 20                                          0.031390
# 21                                         -0.021538
# 22                                          0.031624
# 23                                          0.034968
# 24                                         -0.039460
# 25                                         -0.001439
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_1  \
# 0                                           0.008047
# 1                                           0.103304
# 2                                           0.017805
# 3                                          -0.013352
# 4                                           0.002499
# 5                                           0.024735
# 6                                          -0.003828
# 7                                           0.080526
# 8                                           0.000019
# 9                                           0.106015
# 10                                          0.010144
# 11                                          0.023080
# 12                                          0.005502
# 13                                          0.071083
# 14                                          0.014215
# 15                                          0.028181
# 16                                         -0.003976
# 17                                          0.001881
# 18                                          0.013961
# 19                                          0.032331
# 20                                          0.000000
# 21                                         -0.001614
# 22                                          0.044674
# 23                                          0.037070
# 24                                         -0.046648
# 25                                          0.005186
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_2  \
# 0                                           0.027796
# 1                                          -0.000983
# 2                                           0.000000
# 3                                           0.027539
# 4                                           0.011555
# 5                                           0.001317
# 6                                           0.035245
# 7                                          -0.001256
# 8                                           0.029901
# 9                                           0.004498
# 10                                          0.069607
# 11                                          0.063105
# 12                                          0.013724
# 13                                          0.015355
# 14                                          0.035157
# 15                                          0.105918
# 16                                         -0.010717
# 17                                          0.008663
# 18                                          0.058550
# 19                                          0.015308
# 20                                          0.000000
# 21                                          0.000753
# 22                                          0.033299
# 23                                         -0.006146
# 24                                         -0.014335
# 25                                         -0.036978
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_3  \
# 0                                           0.069923
# 1                                           0.001298
# 2                                          -0.024329
# 3                                          -0.009096
# 4                                           0.006021
# 5                                           0.055534
# 6                                           0.071966
# 7                                           0.000763
# 8                                           0.099865
# 9                                          -0.016872
# 10                                          0.004483
# 11                                          0.000000
# 12                                          0.053256
# 13                                          0.030785
# 14                                          0.067560
# 15                                          0.040245
# 16                                         -0.008895
# 17                                          0.174709
# 18                                         -0.001498
# 19                                          0.018271
# 20                                          0.000000
# 21                                          0.074996
# 22                                          0.035706
# 23                                          0.002998
# 24                                         -0.021171
# 25                                         -0.005810
# 26                                          0.016682
#
#     feature_permutaion_importance.location_cluster_4  \
# 0                                           0.008970
# 1                                           0.185011
# 2                                           0.004897
# 3                                          -0.004254
# 4                                           0.005317
# 5                                           0.004484
# 6                                           0.029557
# 7                                           0.000010
# 8                                           0.002576
# 9                                           0.018998
# 10                                          0.006277
# 11                                          0.000000
# 12                                          0.050387
# 13                                         -0.005868
# 14                                          0.007638
# 15                                         -0.010154
# 16                                          0.181185
# 17                                          0.002187
# 18                                          0.002821
# 19                                          0.000066
# 20                                          0.000000
# 21                                         -0.019570
# 22                                          0.019553
# 23                                         -0.000596
# 24                                          0.021406
# 25                                         -0.003153
# 26                                          0.007128
#
#     feature_permutaion_importance.location_cluster_5  \
# 0                                           0.011206
# 1                                           0.000976
# 2                                           0.000000
# 3                                           0.002539
# 4                                           0.011328
# 5                                           0.166735
# 6                                           0.276523
# 7                                           0.005907
# 8                                          -0.003958
# 9                                           0.002710
# 10                                         -0.002621
# 11                                          0.000000
# 12                                         -0.008304
# 13                                         -0.009450
# 14                                          0.013030
# 15                                         -0.004813
# 16                                          0.003014
# 17                                          0.050171
# 18                                          0.010017
# 19                                          0.008102
# 20                                          0.000000
# 21                                         -0.016781
# 22                                          0.014174
# 23                                         -0.014726
# 24                                          0.025244
# 25                                          0.005292
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_6  \
# 0                                           0.006271
# 1                                          -0.013111
# 2                                           0.000000
# 3                                          -0.005219
# 4                                           0.010861
# 5                                          -0.033168
# 6                                          -0.027745
# 7                                          -0.007780
# 8                                           0.243563
# 9                                          -0.000883
# 10                                         -0.010450
# 11                                          0.000000
# 12                                          0.000817
# 13                                          0.006331
# 14                                          0.085807
# 15                                          0.148545
# 16                                          0.008748
# 17                                          0.004397
# 18                                          0.000484
# 19                                          0.086472
# 20                                          0.000000
# 21                                         -0.009189
# 22                                          0.032576
# 23                                          0.097036
# 24                                         -0.035292
# 25                                          0.000455
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_7  \
# 0                                           0.011206
# 1                                          -0.001629
# 2                                          -0.026616
# 3                                          -0.007579
# 4                                          -0.005104
# 5                                          -0.023694
# 6                                           0.032128
# 7                                          -0.000628
# 8                                           0.000019
# 9                                           0.056993
# 10                                          0.068132
# 11                                          0.009102
# 12                                          0.042518
# 13                                          0.025596
# 14                                         -0.011889
# 15                                          0.001316
# 16                                          0.033888
# 17                                          0.092724
# 18                                          0.007643
# 19                                         -0.035560
# 20                                          0.000000
# 21                                         -0.025653
# 22                                          0.039829
# 23                                         -0.016003
# 24                                         -0.025305
# 25                                         -0.048126
# 26                                          0.016030
#
#     feature_permutaion_importance.location_cluster_8  \
# 0                                           0.017962
# 1                                          -0.004278
# 2                                           0.000000
# 3                                          -0.002502
# 4                                          -0.003687
# 5                                          -0.019279
# 6                                           0.029154
# 7                                          -0.000628
# 8                                           0.012107
# 9                                          -0.001785
# 10                                         -0.012341
# 11                                          0.000000
# 12                                          0.013184
# 13                                          0.036402
# 14                                          0.038662
# 15                                          0.006741
# 16                                          0.028334
# 17                                          0.007868
# 18                                          0.058946
# 19                                         -0.004712
# 20                                          0.031275
# 21                                          0.009922
# 22                                          0.029086
# 23                                          0.015901
# 24                                          0.020043
# 25                                         -0.014045
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_9  \
# 0                                           0.013512
# 1                                          -0.000983
# 2                                           0.000000
# 3                                          -0.004952
# 4                                          -0.012927
# 5                                          -0.002928
# 6                                          -0.020207
# 7                                           0.002446
# 8                                           0.011744
# 9                                           0.001480
# 10                                          0.005447
# 11                                          0.000000
# 12                                         -0.007693
# 13                                          0.013264
# 14                                         -0.012860
# 15                                          0.010004
# 16                                         -0.018595
# 17                                          0.016611
# 18                                          0.005151
# 19                                          0.018068
# 20                                          0.000000
# 21                                          0.049823
# 22                                          0.019092
# 23                                         -0.000236
# 24                                          0.029820
# 25                                         -0.002676
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_10  \
# 0                                            0.110452
# 1                                           -0.000403
# 2                                            0.000000
# 3                                           -0.002583
# 4                                            0.000052
# 5                                            0.010439
# 6                                            0.027014
# 7                                            0.466360
# 8                                            0.018171
# 9                                            0.017304
# 10                                          -0.004576
# 11                                           0.002677
# 12                                           0.057064
# 13                                           0.001260
# 14                                           0.007012
# 15                                           0.032925
# 16                                          -0.000810
# 17                                           0.015166
# 18                                          -0.014746
# 19                                          -0.013695
# 20                                           0.000000
# 21                                           0.015394
# 22                                           0.012970
# 23                                          -0.020471
# 24                                           0.002074
# 25                                           0.150433
# 26                                           0.000000
#
#     feature_permutaion_importance.location_cluster_11  \
# 0                                           -0.020543
# 1                                           -0.001729
# 2                                            0.007369
# 3                                           -0.035170
# 4                                           -0.021153
# 5                                           -0.006135
# 6                                           -0.010021
# 7                                           -0.002488
# 8                                           -0.009555
# 9                                            0.003604
# 10                                          -0.011198
# 11                                          -0.011088
# 12                                           0.033876
# 13                                           0.026479
# 14                                          -0.002006
# 15                                           0.029639
# 16                                          -0.007045
# 17                                           0.000481
# 18                                           0.002181
# 19                                           0.070630
# 20                                           0.000000
# 21                                           0.015842
# 22                                           0.012005
# 23                                          -0.012906
# 24                                          -0.022139
# 25                                          -0.004501
# 26                                           0.139521
#
#     feature_permutaion_importance.location_cluster_12  \
# 0                                            0.011206
# 1                                           -0.000439
# 2                                           -0.012839
# 3                                           -0.043968
# 4                                            0.005118
# 5                                            0.005264
# 6                                           -0.002460
# 7                                           -0.002761
# 8                                            0.013474
# 9                                            0.001804
# 10                                          -0.005052
# 11                                           0.000000
# 12                                           0.014754
# 13                                           0.018551
# 14                                           0.006175
# 15                                           0.021269
# 16                                           0.006270
# 17                                           0.001586
# 18                                           0.002081
# 19                                           0.001361
# 20                                           0.000000
# 21                                           0.040226
# 22                                           0.017652
# 23                                           0.008945
# 24                                          -0.007637
# 25                                          -0.046351
# 26                                          -0.008815
#
#     feature_permutaion_importance.location_cluster_13  \
# 0                                           -0.011004
# 1                                            0.000510
# 2                                            0.000000
# 3                                           -0.023836
# 4                                            0.000704
# 5                                           -0.001320
# 6                                            0.027314
# 7                                            0.046246
# 8                                            0.015224
# 9                                            0.005682
# 10                                           0.003020
# 11                                           0.000000
# 12                                           0.012389
# 13                                           0.022912
# 14                                          -0.012056
# 15                                           0.017847
# 16                                           0.030279
# 17                                           0.047460
# 18                                           0.029831
# 19                                           0.003465
# 20                                           0.000000
# 21                                           0.030243
# 22                                           0.020666
# 23                                          -0.016933
# 24                                           0.002795
# 25                                          -0.020517
# 26                                           0.003323
#
#     feature_permutaion_importance.tree_1  feature_permutaion_importance.evi2  \
# 0                               0.008947                           -0.022138
# 1                              -0.005820                            0.000559
# 2                               0.000000                            0.000000
# 3                               0.010318                            0.030025
# 4                               0.001083                            0.002005
# 5                              -0.015318                           -0.018743
# 6                              -0.013976                            0.018719
# 7                               0.006955                           -0.001380
# 8                               0.002360                           -0.001294
# 9                               0.009911                            0.005397
# 10                              0.032083                            0.016358
# 11                              0.000854                            0.008097
# 12                              0.021184                            0.028492
# 13                              0.108818                            0.035968
# 14                              0.111110                            0.018332
# 15                              0.015724                            0.031581
# 16                              0.020349                            0.024565
# 17                              0.012816                            0.020792
# 18                              0.009187                            0.005166
# 19                             -0.011795                            0.025369
# 20                              0.000000                            0.000000
# 21                             -0.009021                            0.000541
# 22                             -0.002712                            0.038798
# 23                             -0.003968                           -0.013871
# 24                              0.003937                            0.000842
# 25                             -0.027244                           -0.054750
# 26                             -0.011129                            0.000000
#
#     feature_permutaion_importance.evi2-1  \
# 0                               0.010777
# 1                               0.003997
# 2                              -0.040586
# 3                               0.003879
# 4                               0.003286
# 5                               0.000010
# 6                               0.040057
# 7                              -0.002761
# 8                               0.018154
# 9                               0.015594
# 10                             -0.016477
# 11                              0.000000
# 12                             -0.008225
# 13                              0.007147
# 14                              0.024853
# 15                              0.054955
# 16                              0.054051
# 17                              0.009146
# 18                              0.001334
# 19                              0.011978
# 20                              0.000000
# 21                              0.102037
# 22                              0.032547
# 23                             -0.002761
# 24                              0.006314
# 25                              0.007950
# 26                              0.001253
#
#     feature_permutaion_importance.evi2_diff  \
# 0                                  0.004519
# 1                                 -0.002802
# 2                                  0.000000
# 3                                 -0.010021
# 4                                 -0.008456
# 5                                  0.000248
# 6                                  0.013564
# 7                                 -0.004772
# 8                                  0.006309
# 9                                  0.024782
# 10                                 0.030566
# 11                                 0.016309
# 12                                -0.001668
# 13                                 0.043549
# 14                                 0.008565
# 15                                 0.038591
# 16                                -0.032775
# 17                                 0.082231
# 18                                -0.009600
# 19                                 0.014848
# 20                                 0.066337
# 21                                 0.091546
# 22                                 0.015673
# 23                                -0.007877
# 24                                 0.066199
# 25                                 0.001101
# 26                                 0.000000
#
#     feature_permutaion_importance.evi2_max_diff  \
# 0                                      0.013466
# 1                                     -0.004097
# 2                                      0.000000
# 3                                     -0.039875
# 4                                     -0.038864
# 5                                     -0.058259
# 6                                      0.068951
# 7                                     -0.008241
# 8                                     -0.002247
# 9                                      0.021744
# 10                                     0.002298
# 11                                    -0.009330
# 12                                     0.045513
# 13                                     0.028050
# 14                                     0.011017
# 15                                     0.011760
# 16                                     0.084026
# 17                                     0.015866
# 18                                     0.005917
# 19                                    -0.011619
# 20                                     0.000000
# 21                                    -0.020477
# 22                                     0.035728
# 23                                    -0.020028
# 24                                    -0.006124
# 25                                    -0.042156
# 26                                     0.043421
#
#     feature_permutaion_importance.evi2_raster  \
# 0                                    0.011206
# 1                                    0.008737
# 2                                   -0.004460
# 3                                   -0.015369
# 4                                   -0.008613
# 5                                    0.024934
# 6                                    0.015819
# 7                                   -0.001380
# 8                                    0.000923
# 9                                    0.023384
# 10                                   0.124826
# 11                                   0.000000
# 12                                  -0.019306
# 13                                   0.004471
# 14                                   0.029240
# 15                                   0.007176
# 16                                   0.014598
# 17                                   0.003295
# 18                                   0.004788
# 19                                   0.036550
# 20                                   0.000000
# 21                                   0.066053
# 22                                   0.047596
# 23                                  -0.036290
# 24                                   0.065730
# 25                                  -0.002874
# 26                                  -0.013834
#
#     feature_permutaion_importance.evi2_raster-1  \
# ...
# 12                           NaN                    NaN              NaN
# 13                           NaN                    NaN              NaN
# 14                           NaN                    NaN              NaN
# 15                           NaN                    NaN              NaN
# 16                           NaN                    NaN              NaN
# 17                           NaN                   64.0              NaN
# 18                           NaN                    NaN              NaN
# 19                           NaN                    NaN              NaN
# 20                          0.05                 1089.0          entropy
# 21                           NaN                    NaN              NaN
# 22                           NaN                    NaN              NaN
# 23                           NaN                    NaN              NaN
# 24                           NaN                    NaN              NaN
# 25                           NaN                    NaN              NaN
# 26                           NaN                   57.0              NaN
#
#     params.ccp_alpha params.weights  params.p  params.n_neighbors  \
# 0                NaN            NaN       NaN                 NaN
# 1                NaN            NaN       NaN                 NaN
# 2                0.0            NaN       NaN                 NaN
# 3                NaN       distance       1.0                 2.0
# 4                NaN            NaN       NaN                 NaN
# 5                NaN            NaN       NaN                 NaN
# 6                NaN            NaN       NaN                 NaN
# 7                NaN            NaN       NaN                 NaN
# 8                NaN            NaN       NaN                 NaN
# 9                NaN            NaN       NaN                 NaN
# 10               NaN            NaN       NaN                 NaN
# 11               0.0            NaN       NaN                 NaN
# 12               NaN       distance       1.0                 4.0
# 13               NaN            NaN       NaN                 NaN
# 14               NaN            NaN       NaN                 NaN
# 15               NaN            NaN       NaN                 NaN
# 16               NaN            NaN       NaN                 NaN
# 17               NaN            NaN       NaN                 NaN
# 18               NaN            NaN       NaN                 NaN
# 19               NaN            NaN       NaN                 NaN
# 20               0.0            NaN       NaN                 NaN
# 21               NaN       distance       1.0                 2.0
# 22               NaN            NaN       NaN                 NaN
# 23               NaN            NaN       NaN                 NaN
# 24               NaN            NaN       NaN                 NaN
# 25               NaN            NaN       NaN                 NaN
# 26               NaN            NaN       NaN                 NaN
#
#    params.metric  params.leaf_size params.algorithm  params.tol  \
# 0            NaN               NaN              NaN         NaN
# 1            NaN               NaN              NaN         NaN
# 2            NaN               NaN              NaN         NaN
# 3      manhattan              20.0            brute         NaN
# 4            NaN               NaN              NaN       0.007
# 5            NaN               NaN          SAMME.R         NaN
# 6            NaN               NaN          SAMME.R         NaN
# 7            NaN               NaN              NaN         NaN
# 8            NaN               NaN              NaN         NaN
# 9            NaN               NaN              NaN         NaN
# 10           NaN               NaN              NaN         NaN
# 11           NaN               NaN              NaN         NaN
# 12     minkowski              48.0            brute         NaN
# 13           NaN               NaN              NaN       0.004
# 14           NaN               NaN          SAMME.R         NaN
# 15           NaN               NaN          SAMME.R         NaN
# 16           NaN               NaN              NaN         NaN
# 17           NaN               NaN              NaN         NaN
# 18           NaN               NaN              NaN         NaN
# 19           NaN               NaN              NaN         NaN
# 20           NaN               NaN              NaN         NaN
# 21     chebyshev              22.0          kd_tree         NaN
# 22           NaN               NaN              NaN       0.004
# 23           NaN               NaN          SAMME.R         NaN
# 24           NaN               NaN          SAMME.R         NaN
# 25           NaN               NaN              NaN         NaN
# 26           NaN               NaN              NaN         NaN
#
#    params.shrinking params.probability params.kernel  params.gamma  \
# 0               NaN                NaN           NaN           NaN
# 1               NaN                NaN           NaN           NaN
# 2               NaN                NaN           NaN           NaN
# 3               NaN                NaN           NaN           NaN
# 4              True               True           rbf         0.546
# 5               NaN                NaN           NaN           NaN
# 6               NaN                NaN           NaN           NaN
# 7               NaN                NaN           NaN         0.650
# 8               NaN                NaN           NaN           NaN
# 9               NaN                NaN           NaN           NaN
# 10              NaN                NaN           NaN           NaN
# 11              NaN                NaN           NaN           NaN
# 12              NaN                NaN           NaN           NaN
# 13             True               True           rbf         0.871
# 14              NaN                NaN           NaN           NaN
# 15              NaN                NaN           NaN           NaN
# 16              NaN                NaN           NaN         0.050
# 17              NaN                NaN           NaN           NaN
# 18              NaN                NaN           NaN           NaN
# 19              NaN                NaN           NaN           NaN
# 20              NaN                NaN           NaN           NaN
# 21              NaN                NaN           NaN           NaN
# 22             True               True           rbf         0.846
# 23              NaN                NaN           NaN           NaN
# 24              NaN                NaN           NaN           NaN
# 25              NaN                NaN           NaN         0.400
# 26              NaN                NaN           NaN           NaN
#
#    params.decision_function_shape  params.C params.replacement  \
# 0                             NaN       NaN                NaN
# 1                             NaN       NaN                NaN
# 2                             NaN       NaN                NaN
# 3                             NaN       NaN                NaN
# 4                             ovo       6.1                NaN
# 5                             NaN       NaN              False
# 6                             NaN       NaN                NaN
# 7                             NaN       NaN                NaN
# 8                             NaN       NaN                NaN
# 9                             NaN       NaN                NaN
# 10                            NaN       NaN                NaN
# 11                            NaN       NaN                NaN
# 12                            NaN       NaN                NaN
# 13                            ovo       9.6                NaN
# 14                            NaN       NaN               True
# 15                            NaN       NaN                NaN
# 16                            NaN       NaN                NaN
# 17                            NaN       NaN                NaN
# 18                            NaN       NaN                NaN
# 19                            NaN       NaN                NaN
# 20                            NaN       NaN                NaN
# 21                            NaN       NaN                NaN
# 22                            ovo       8.6                NaN
# 23                            NaN       NaN              False
# 24                            NaN       NaN                NaN
# 25                            NaN       NaN                NaN
# 26                            NaN       NaN                NaN
#
#     params.learning_rate  params.subsample  params.seed  \
# 0                    NaN               NaN          NaN
# 1                    NaN               NaN          NaN
# 2                    NaN               NaN          NaN
# 3                    NaN               NaN          NaN
# 4                    NaN               NaN          NaN
# 5                 0.0410               NaN          NaN
# 6                 0.4750               NaN          NaN
# 7                 0.0090              0.95       2022.0
# 8                 0.0235               NaN          NaN
# 9                    NaN               NaN          NaN
# 10                   NaN               NaN          NaN
# 11                   NaN               NaN          NaN
# 12                   NaN               NaN          NaN
# 13                   NaN               NaN          NaN
# 14                0.0910               NaN          NaN
# 15                0.4500               NaN          NaN
# 16                0.0090              0.90       2022.0
# 17                0.0415               NaN          NaN
# 18                   NaN               NaN          NaN
# 19                   NaN               NaN          NaN
# 20                   NaN               NaN          NaN
# 21                   NaN               NaN          NaN
# 22                   NaN               NaN          NaN
# 23                0.0830               NaN          NaN
# 24                0.4500               NaN          NaN
# 25                0.0070              0.90       2022.0
# 26                0.0295               NaN          NaN
#
#     params.scale_pos_weight params.objective  params.lambda  \
# 0                       NaN              NaN            NaN
# 1                       NaN              NaN            NaN
# 2                       NaN              NaN            NaN
# 3                       NaN              NaN            NaN
# 4                       NaN              NaN            NaN
# 5                       NaN              NaN            NaN
# 6                       NaN              NaN            NaN
# 7                  0.139559  binary:logistic            0.6
# 8                       NaN              NaN            NaN
# 9                       NaN              NaN            NaN
# 10                      NaN              NaN            NaN
# 11                      NaN              NaN            NaN
# 12                      NaN              NaN            NaN
# 13                      NaN              NaN            NaN
# 14                      NaN              NaN            NaN
# 15                      NaN              NaN            NaN
# 16                 0.169816  binary:logistic            0.1
# 17                      NaN              NaN            NaN
# 18                      NaN              NaN            NaN
# 19                      NaN              NaN            NaN
# 20                      NaN              NaN            NaN
# 21                      NaN              NaN            NaN
# 22                      NaN              NaN            NaN
# 23                      NaN              NaN            NaN
# 24                      NaN              NaN            NaN
# 25                 0.118024  binary:logistic            0.1
# 26                      NaN              NaN            NaN
#
#    params.eval_metric  params.colsample_bytree params.scoring  \
# 0                 NaN                      NaN            NaN
# 1                 NaN                      NaN            NaN
# 2                 NaN                      NaN            NaN
# 3                 NaN                      NaN            NaN
# 4                 NaN                      NaN            NaN
# 5                 NaN                      NaN            NaN
# 6                 NaN                      NaN            NaN
# 7                 auc                      0.7            NaN
# 8                 NaN                      NaN             f1
# 9                 NaN                      NaN            NaN
# 10                NaN                      NaN            NaN
# 11                NaN                      NaN            NaN
# 12                NaN                      NaN            NaN
# 13                NaN                      NaN            NaN
# 14                NaN                      NaN            NaN
# 15                NaN                      NaN            NaN
# 16              aucpr                      0.8            NaN
# 17                NaN                      NaN        roc_auc
# 18                NaN                      NaN            NaN
# 19                NaN                      NaN            NaN
# 20                NaN                      NaN            NaN
# 21                NaN                      NaN            NaN
# 22                NaN                      NaN            NaN
# 23                NaN                      NaN            NaN
# 24                NaN                      NaN            NaN
# 25              aucpr                      0.5            NaN
# 26                NaN                      NaN             f1
#
#     params.max_iter          params.loss  params.l2_regularization
# 0               NaN                  NaN                       NaN
# 1               NaN                  NaN                       NaN
# 2               NaN                  NaN                       NaN
# 3               NaN                  NaN                       NaN
# 4               NaN                  NaN                       NaN
# 5               NaN                  NaN                       NaN
# 6               NaN                  NaN                       NaN
# 7               NaN                  NaN                       NaN
# 8             475.0  binary_crossentropy                      0.30
# 9               NaN                  NaN                       NaN
# 10              NaN                  NaN                       NaN
# 11              NaN                  NaN                       NaN
# 12              NaN                  NaN                       NaN
# 13              NaN                  NaN                       NaN
# 14              NaN                  NaN                       NaN
# 15              NaN                  NaN                       NaN
# 16              NaN                  NaN                       NaN
# 17            375.0  binary_crossentropy                      0.85
# 18              NaN                  NaN                       NaN
# 19              NaN                  NaN                       NaN
# 20              NaN                  NaN                       NaN
# 21              NaN                  NaN                       NaN
# 22              NaN                  NaN                       NaN
# 23              NaN                  NaN                       NaN
# 24              NaN                  NaN                       NaN
# 25              NaN                  NaN                       NaN
# 26            325.0  binary_crossentropy                      0.10

# %% [markdown]
# ### Dead Vegetation

# %%
SPECIESES = ["1", "2", "1 2"]
MODELS = ["RandomForestClassifier", "BalancedRandomForestClassifier", "DecisionTreeClassifier", "KNeighborsClassifier", "SVM", "RUSBoostClassifier" , "AdaBoostClassifier", "XGBClassifier", "HistGradientBoostingClassifier"]
TARGET = "is_dead"

binary_classifcation_results = list()

for SPECIES in SPECIESES:
    for MODEL in MODELS:
        if os.path.exists(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json"):
            continue
            
        # DO NOT INCLUDE DAMAGE CLASS 2.0 FOR DEAD OR HEALTHY CLASSIFICATION
        data_selection = binned_data[SPECIES]["train"].loc[binned_data[SPECIES]["train"]["damage_class"] != 2.0]
        
        print("-"*100)
        print(f"{MODEL} -> {SPECIES_CODE[SPECIES]}@{TARGET}")
        print("\t performing backward feature elemination...")
        init_model_params = get_model_params(_model=MODEL, _target=TARGET, _species=SPECIES_CODE[SPECIES])

        if "class_weight" in init_model_params:
            init_model_params["class_weight"] = define_class_weight(data_selection[TARGET])
        if "pos_scale" in init_model_params:
            init_model_params["pos_scale"] = define_pos_scale(data_selection[TARGET])

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)
        kappa_scorer = metrics.make_scorer(metrics.cohen_kappa_score)

        if MODEL == "RandomForestClassifier":
            model = RandomForestClassifier(**init_model_params)
        elif MODEL == "XGBClassifier":
            model = xgb.XGBClassifier(**init_model_params)
        elif MODEL == "KNeighborsClassifier":
            model = KNeighborsClassifier(**init_model_params)
        elif MODEL == "DecisionTreeClassifier":
            model = DecisionTreeClassifier(**init_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            model = HistGradientBoostingClassifier(**init_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            model = BalancedRandomForestClassifier(**init_model_params)
        elif MODEL == "RUSBoostClassifier":
            model = RUSBoostClassifier(**init_model_params)
        elif MODEL == "AdaBoostClassifier":
            model = AdaBoostClassifier(**init_model_params)
        else: #SVM
            model = SVC(**init_model_params)

        sfs = SequentialFeatureSelector(estimator=model, direction="backward", scoring=kappa_scorer, cv=skf, n_jobs=58)
        sfs.fit(data_selection[all_features], data_selection[TARGET])
        relevant_features = list(data_selection[all_features].columns[sfs.get_support()])

        # TRAINING DATA
        X_train = data_selection[relevant_features]
        y_train = data_selection[TARGET]
        # TEST DATA
        X_test = binned_data[SPECIES]["test"][relevant_features]
        y_test = binned_data[SPECIES]["test"][TARGET]

        print("\t performing hyperparameter tuning...")

        if MODEL == "RandomForestClassifier":
            params_rf = PARAMS_RF
            params_rf["class_weight"] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=RandomForestClassifier(), _params=params_rf, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = RandomForestClassifier(**fitted_model_params)
        elif MODEL == "XGBClassifier":
            params_xgb = PARAMS_XGB
            params_xgb['scale_pos_weight'] = [define_pos_scale(y_train.values)]
            fitted_model_params = parameter_tuning(_model=xgb.XGBClassifier(), _params=params_xgb, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = xgb.XGBClassifier(**fitted_model_params)
        elif MODEL == "KNeighborsClassifier":
            params_kn = PARAMS_KN
            fitted_model_params = parameter_tuning(_model=KNeighborsClassifier(), _params=params_kn, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = KNeighborsClassifier(**fitted_model_params)
        elif MODEL == "DecisionTreeClassifier":
            params_dt = PARAMS_DT
            params_dt['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=DecisionTreeClassifier(), _params=params_dt, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = DecisionTreeClassifier(**fitted_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            params_hgb = PARAMS_HGB
            fitted_model_params = parameter_tuning(_model=HistGradientBoostingClassifier(), _params=params_hgb, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = HistGradientBoostingClassifier(**fitted_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            params_brf = PARAMS_BRF
            fitted_model_params = parameter_tuning(_model=BalancedRandomForestClassifier(), _params=params_brf, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = BalancedRandomForestClassifier(**fitted_model_params)
        elif MODEL == "RUSBoostClassifier":
            params_rus = PARAMS_RUS
            fitted_model_params = parameter_tuning(_model=RUSBoostClassifier(), _params=params_rus, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = RUSBoostClassifier(**fitted_model_params)
        elif MODEL == "AdaBoostClassifier":
            params_ada = PARAMS_ADA
            fitted_model_params = parameter_tuning(_model=AdaBoostClassifier(), _params=params_ada, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = AdaBoostClassifier(**fitted_model_params)
        else:
            params_svm = PARAMS_SVM
            params_svm['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=SVC(), _params=params_svm, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = SVC(**fitted_model_params)

        # CREATING BAGGING CLASSIFIER
        model = BaggingClassifier(base_estimator=model, n_estimators=15, max_samples=.2, max_features=1., bootstrap=True, bootstrap_features=True, oob_score=True, n_jobs=16)
        print("\t fitting model...")
        model.fit(X_train, y_train)
        # save model
        pickle.dump(model, open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.sav", 'wb'))

        # predict probabilities
        y_pred_proba = model.predict_proba(X_test)

        print("\t performing permutation feature importance...")
        from sklearn.inspection import permutation_importance
        permutation_importance = permutation_importance(model, X_test, y_test, n_repeats=5, random_state=2022, n_jobs=32, scoring=kappa_scorer)
        permutation_importance_obj = {}
        for i, feat_imp in enumerate(permutation_importance.importances_mean):
            permutation_importance_obj[all_features[i]] = feat_imp

        print("\t evaluating...")
        results = {}
        results["species"] = SPECIES_CODE[SPECIES]
        results["model"] = MODEL
        results["target"] = TARGET
        results["params"] = fitted_model_params
        results["relevant_features"] = relevant_features
        results["feature_permutaion_importance"] = permutation_importance_obj

        results["metrics"] = {}
        results["metrics"]["auc"] = metrics.roc_auc_score(y_test.values, y_pred_proba[:, 1])

        ## ROC AUC
        results["metrics"]["roc"] = {}
        threshold_roc, gmean_roc = roc_auc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["roc"]["threshold"] = threshold_roc
        y_pred_roc = apply_prediction(y_pred_proba[:, 1], threshold_roc)
        results["metrics"]["roc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["f1"] = metrics.f1_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["recall"] = metrics.recall_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["precision"] = metrics.precision_score(y_test.values, y_pred_roc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_roc).ravel()
        results["metrics"]["roc"]["tn"] = tn
        results["metrics"]["roc"]["fp"] = fp
        results["metrics"]["roc"]["fn"] = fn
        results["metrics"]["roc"]["tp"] = tp

        ## PRC
        results["metrics"]["prc"] = {}
        threshold_prc, fscore_prc = prc_rc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["prc"]["threshold"] = threshold_prc
        y_pred_prc = apply_prediction(y_pred_proba[:, 1], threshold_prc)
        results["metrics"]["prc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["f1"] = metrics.f1_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["recall"] = metrics.recall_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["precision"] = metrics.precision_score(y_test.values, y_pred_prc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_prc).ravel()
        results["metrics"]["prc"]["tn"] = tn
        results["metrics"]["prc"]["fp"] = fp
        results["metrics"]["prc"]["fn"] = fn
        results["metrics"]["prc"]["tp"] = tp

        ## TUNING
        results["metrics"]["tuning"] = {}
        threshold_tuning, fscore_tuneing = tune_threshold(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["tuning"]["threshold"] = threshold_tuning
        y_pred_tuning = apply_prediction(y_pred_proba[:, 1], threshold_tuning)
        results["metrics"]["tuning"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["f1"] = metrics.f1_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["recall"] = metrics.recall_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["precision"] = metrics.precision_score(y_test.values, y_pred_tuning)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_tuning).ravel()
        results["metrics"]["tuning"]["tn"] = tn
        results["metrics"]["tuning"]["fp"] = fp
        results["metrics"]["tuning"]["fn"] = fn
        results["metrics"]["tuning"]["tp"] = tp

        # quick export to dump data
        with open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json", 'w', encoding='utf-8') as f:
            json.dump(str(dict((k, v) for k,v in results.items())), f, ensure_ascii=False, indent=4)
        pd.json_normalize(results).to_csv(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.csv", index=False)

        binary_classifcation_results.append(results)

print("-"*75)
print(f"EXPORTING OVERALL RESULTS TO {EXPORT_PATH}/modelling_pipeline_results.csv")
print("-"*75)
df_result = pd.json_normalize(binary_classifcation_results)
df_result.to_csv(f"{EXPORT_PATH}/modelling_pipeline_results_dead.csv", index=False)
df_result
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ---------------------------------------------------------------------------
# EXPORTING OVERALL RESULTS TO ./results/optimization/v1/modelling_pipeline_results.csv
# ---------------------------------------------------------------------------
#       species                           model   target  \
# 0   Deciduous          RandomForestClassifier  is_dead
# 1   Deciduous  BalancedRandomForestClassifier  is_dead
# 2   Deciduous          DecisionTreeClassifier  is_dead
# 3   Deciduous            KNeighborsClassifier  is_dead
# 4   Deciduous                             SVM  is_dead
# 5   Deciduous              RUSBoostClassifier  is_dead
# 6   Deciduous              AdaBoostClassifier  is_dead
# 7   Deciduous                   XGBClassifier  is_dead
# 8   Deciduous  HistGradientBoostingClassifier  is_dead
# 9     Conifer          RandomForestClassifier  is_dead
# 10    Conifer  BalancedRandomForestClassifier  is_dead
# 11    Conifer          DecisionTreeClassifier  is_dead
# 12    Conifer            KNeighborsClassifier  is_dead
# 13    Conifer                             SVM  is_dead
# 14    Conifer              RUSBoostClassifier  is_dead
# 15    Conifer              AdaBoostClassifier  is_dead
# 16    Conifer                   XGBClassifier  is_dead
# 17    Conifer  HistGradientBoostingClassifier  is_dead
# 18      Mixed          RandomForestClassifier  is_dead
# 19      Mixed  BalancedRandomForestClassifier  is_dead
# 20      Mixed          DecisionTreeClassifier  is_dead
# 21      Mixed            KNeighborsClassifier  is_dead
# 22      Mixed                             SVM  is_dead
# 23      Mixed              RUSBoostClassifier  is_dead
# 24      Mixed              AdaBoostClassifier  is_dead
# 25      Mixed                   XGBClassifier  is_dead
# 26      Mixed  HistGradientBoostingClassifier  is_dead
#
#                                     relevant_features params.warm_start  \
# 0   [location_cluster_0, location_cluster_4, locat...             False
# 1   [location_cluster_1, location_cluster_2, locat...              True
# 2   [location_cluster_2, location_cluster_3, locat...               NaN
# 3   [location_cluster_4, location_cluster_5, locat...               NaN
# 4   [tree_1, evi2_diff, evi2_max_diff, evi2_vegeta...               NaN
# 5   [location_cluster_0, location_cluster_5, locat...               NaN
# 6   [location_cluster_1, location_cluster_5, locat...               NaN
# 7   [location_cluster_10, evi2_max_diff, evi2_rast...               NaN
# 8   [location_cluster_4, location_cluster_10, tree...               NaN
# 9   [location_cluster_2, location_cluster_4, locat...              True
# 10  [location_cluster_2, location_cluster_5, locat...             False
# 11  [location_cluster_8, location_cluster_9, locat...               NaN
# 12  [location_cluster_4, location_cluster_13, tree...               NaN
# 13  [location_cluster_4, location_cluster_10, loca...               NaN
# 14  [location_cluster_1, location_cluster_4, locat...               NaN
# 15  [location_cluster_5, location_cluster_10, tree...               NaN
# 16  [location_cluster_4, location_cluster_10, tree...               NaN
# 17  [location_cluster_4, location_cluster_5, locat...               NaN
# 18  [location_cluster_7, location_cluster_10, loca...              True
# 19  [location_cluster_0, location_cluster_9, locat...              True
# 20  [evi2_diff, evi2_max_diff, evi2_raster, evi2_r...               NaN
# 21  [evi2_vegetation_raster_diff, ndvi, ndvi_diff,...               NaN
# 22  [evi2, ndvi, ndvi-1, ndvi_diff, ndvi_max_diff,...               NaN
# 23  [location_cluster_1, location_cluster_7, locat...               NaN
# 24  [location_cluster_0, location_cluster_10, tree...               NaN
# 25  [location_cluster_0, tree_1, evi2_vegetation_r...               NaN
# 26  [evi2_vegetation_raster_diff, ndvi, ndvi-1, nd...               NaN
#
#     params.random_state  params.n_jobs  params.n_estimators  \
# 0                2022.0           58.0                144.0
# 1                2022.0           58.0                352.0
# 2                2022.0            NaN                  NaN
# 3                   NaN           58.0                  NaN
# 4                2022.0            NaN                  NaN
# 5                2022.0            NaN                410.0
# 6                2022.0            NaN                470.0
# 7                   NaN           58.0                485.0
# 8                2022.0            NaN                  NaN
# 9                2022.0           58.0                256.0
# 10               2022.0           58.0                160.0
# 11               2022.0            NaN                  NaN
# 12                  NaN           58.0                  NaN
# 13               2022.0            NaN                  NaN
# 14               2022.0            NaN                455.0
# 15               2022.0            NaN                380.0
# 16                  NaN           58.0                410.0
# 17               2022.0            NaN                  NaN
# 18               2022.0           58.0                224.0
# 19               2022.0           58.0                304.0
# 20               2022.0            NaN                  NaN
# 21                  NaN           58.0                  NaN
# 22               2022.0            NaN                  NaN
# 23               2022.0            NaN                275.0
# 24               2022.0            NaN                185.0
# 25                  NaN           58.0                470.0
# 26               2022.0            NaN                  NaN
#
#     params.min_samples_split  params.min_samples_leaf params.max_features  \
# 0                       12.0                      2.0                sqrt
# 1                        4.0                     20.0                sqrt
# 2                       14.0                     14.0                sqrt
# 3                        NaN                      NaN                 NaN
# 4                        NaN                      NaN                 NaN
# 5                        NaN                      NaN                 NaN
# 6                        NaN                      NaN                 NaN
# 7                        NaN                      NaN                 NaN
# 8                        NaN                     12.0                 NaN
# 9                        2.0                     12.0                sqrt
# 10                       4.0                      2.0                sqrt
# 11                      10.0                      2.0                log2
# 12                       NaN                      NaN                 NaN
# 13                       NaN                      NaN                 NaN
# 14                       NaN                      NaN                 NaN
# 15                       NaN                      NaN                 NaN
# 16                       NaN                      NaN                 NaN
# 17                       NaN                     26.0                 NaN
# 18                      14.0                      4.0                sqrt
# 19                       8.0                      2.0                sqrt
# 20                      18.0                      8.0                sqrt
# 21                       NaN                      NaN                 NaN
# 22                       NaN                      NaN                 NaN
# 23                       NaN                      NaN                 NaN
# 24                       NaN                      NaN                 NaN
# 25                       NaN                      NaN                 NaN
# 26                       NaN                     15.0                 NaN
#
#     params.max_depth  params.class_weight.0  params.class_weight.1  \
# 0               80.0               0.514098              18.232558
# 1              144.0                    NaN                    NaN
# 2               20.0               0.514098              18.232558
# 3                NaN                    NaN                    NaN
# 4                NaN               0.514098              18.232558
# 5                NaN                    NaN                    NaN
# 6                NaN                    NaN                    NaN
# 7                7.0                    NaN                    NaN
# 8               15.0                    NaN                    NaN
# 9              144.0               0.508378              30.340278
# 10             160.0                    NaN                    NaN
# 11              21.0               0.508378              30.340278
# 12               NaN                    NaN                    NaN
# 13               NaN               0.508378              30.340278
# 14               NaN                    NaN                    NaN
# 15               NaN                    NaN                    NaN
# 16               7.0                    NaN                    NaN
# 17              64.0                    NaN                    NaN
# 18              48.0               0.503304              76.176471
# 19              32.0                    NaN                    NaN
# 20              20.0               0.503304              76.176471
# 21               NaN                    NaN                    NaN
# 22               NaN               0.503304              76.176471
# 23               NaN                    NaN                    NaN
# 24               NaN                    NaN                    NaN
# 25               7.0                    NaN                    NaN
# 26              29.0                    NaN                    NaN
#
#     feature_permutaion_importance.location_cluster_0  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                          -0.004687
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.001057
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                           0.000024
# 10                                         -0.000336
# 11                                         -0.000008
# 12                                         -0.000153
# 13                                         -0.000487
# 14                                         -0.009956
# 15                                          0.000000
# 16                                         -0.000650
# 17                                         -0.001592
# 18                                          0.000000
# 19                                          0.000229
# 20                                         -0.000954
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.016523
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_1  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.023957
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.000820
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                          -0.001004
# 10                                          0.000507
# 11                                         -0.000008
# 12                                         -0.000743
# 13                                         -0.000487
# 14                                          0.067950
# 15                                          0.000000
# 16                                          0.000925
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000143
# 20                                          0.000000
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.026465
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_2  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                          -0.001963
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.002318
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                          -0.000787
# 10                                         -0.000943
# 11                                         -0.000006
# 12                                          0.000614
# 13                                         -0.000325
# 14                                         -0.006100
# 15                                         -0.000065
# 16                                          0.001628
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000244
# 20                                         -0.000026
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.016947
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_3  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.003706
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                          -0.000513
# 10                                         -0.001835
# 11                                          0.000000
# 12                                          0.000000
# 13                                         -0.000325
# 14                                         -0.003716
# 15                                          0.000000
# 16                                          0.000000
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000033
# 20                                         -0.000686
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.014813
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_4  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                          -0.005116
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.003450
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                          -0.000478
# 10                                         -0.000058
# 11                                          0.000000
# 12                                          0.000479
# 13                                         -0.000487
# 14                                         -0.019675
# 15                                          0.000000
# 16                                          0.001437
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000027
# 20                                          0.000000
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.000918
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_5  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.026086
# 3                                           0.000000
# 4                                           0.000000
# 5                                           0.000483
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                           0.000038
# 10                                         -0.001722
# 11                                         -0.000011
# 12                                          0.000548
# 13                                         -0.000487
# 14                                         -0.006100
# 15                                          0.000000
# 16                                          0.002331
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000125
# 20                                          0.000000
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.000048
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_6  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                          -0.003865
# 3                                           0.000000
# 4                                           0.000000
# 5                                           0.000425
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                          -0.000323
# 10                                         -0.000205
# 11                                          0.000000
# 12                                          0.000000
# 13                                         -0.000487
# 14                                         -0.007432
# 15                                          0.000000
# 16                                          0.000000
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000110
# 20                                          0.000000
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.000142
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_7  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.004753
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.000608
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                          -0.000711
# 10                                         -0.000092
# 11                                          0.000000
# 12                                          0.000192
# 13                                         -0.000487
# 14                                          0.005073
# 15                                          0.000000
# 16                                          0.000781
# 17                                          0.000000
# 18                                          0.000000
# 19                                          0.000056
# 20                                         -0.000067
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.000190
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_8  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.002179
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.000988
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                           0.000925
# 10                                         -0.000173
# 11                                          0.000000
# 12                                         -0.001003
# 13                                          0.000000
# 14                                         -0.069439
# 15                                          0.000000
# 16                                          0.000000
# 17                                         -0.000086
# 18                                          0.000000
# 19                                          0.000115
# 20                                         -0.001486
# 21                                          0.000000
# 22                                          0.000000
# 23                                          0.000094
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_9  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.028288
# 3                                           0.000000
# 4                                           0.000000
# 5                                          -0.001178
# 6                                           0.000000
# 7                                           0.000000
# 8                                           0.000000
# 9                                           0.001106
# 10                                          0.000033
# 11                                          0.000000
# 12                                          0.000341
# 13                                         -0.000162
# 14                                         -0.007432
# 15                                          0.000000
# 16                                          0.000000
# 17                                          0.000000
# 18                                          0.000000
# 19                                         -0.000011
# 20                                          0.000000
# 21                                          0.000000
# 22                                          0.000000
# 23                                         -0.000287
# 24                                          0.000000
# 25                                          0.000000
# 26                                          0.000000
#
#     feature_permutaion_importance.location_cluster_10  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.020333
# 3                                            0.000000
# 4                                            0.000000
# 5                                           -0.000413
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000644
# 10                                          -0.000262
# 11                                           0.000000
# 12                                          -0.000010
# 13                                          -0.000325
# 14                                          -0.002384
# 15                                           0.000000
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000014
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                          -0.000719
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
#
#     feature_permutaion_importance.location_cluster_11  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.000858
# 3                                            0.000000
# 4                                            0.000000
# 5                                           -0.000744
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000459
# 10                                          -0.000110
# 11                                           0.000000
# 12                                           0.000415
# 13                                          -0.000325
# 14                                          -0.011288
# 15                                           0.000000
# 16                                           0.001427
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000119
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                          -0.000382
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
#
#     feature_permutaion_importance.location_cluster_12  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.004105
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.000709
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.000822
# 10                                          -0.000024
# 11                                           0.000000
# 12                                           0.000473
# 13                                          -0.000812
# 14                                          -0.004768
# 15                                           0.000000
# 16                                           0.001576
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000337
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                          -0.000238
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
#
#     feature_permutaion_importance.location_cluster_13  \
# 0                                            0.000000
# 1                                            0.000000
# 2                                            0.000000
# 3                                            0.000000
# 4                                            0.000000
# 5                                            0.000530
# 6                                            0.000000
# 7                                            0.000000
# 8                                            0.000000
# 9                                            0.001106
# 10                                           0.000093
# 11                                          -0.000002
# 12                                           0.000156
# 13                                          -0.000325
# 14                                          -0.033754
# 15                                           0.000000
# 16                                           0.002314
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000024
# 20                                          -0.000067
# 21                                           0.000000
# 22                                           0.000000
# 23                                          -0.000333
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
#
#     feature_permutaion_importance.tree_1  feature_permutaion_importance.evi2  \
# 0                               0.000000                            0.000000
# 1                               0.000000                            0.000000
# 2                               0.002086                            0.016606
# 3                               0.000000                            0.000000
# 4                               0.000000                            0.000000
# 5                              -0.000365                           -0.000133
# 6                               0.000000                            0.000000
# 7                               0.000000                            0.000000
# 8                               0.000000                            0.000000
# 9                               0.000892                           -0.001004
# 10                             -0.000082                           -0.000106
# 11                              0.000000                            0.000003
# 12                             -0.000009                            0.000000
# 13                             -0.000487                           -0.000325
# 14                              0.067364                            0.000954
# 15                              0.000000                            0.000000
# 16                              0.000000                            0.000000
# 17                             -0.002118                            0.000000
# 18                              0.000000                            0.000000
# 19                              0.000054                            0.000008
# 20                              0.000000                           -0.000868
# 21                              0.000000                            0.000000
# 22                              0.000000                            0.000000
# 23                             -0.000095                           -0.000095
# 24                              0.000000                            0.000000
# 25                              0.000000                            0.000000
# 26                              0.000000                            0.000000
#
#     feature_permutaion_importance.evi2-1  \
# 0                               0.000000
# 1                               0.000000
# 2                               0.000000
# 3                               0.000000
# 4                               0.000000
# 5                              -0.000663
# 6                               0.000000
# 7                               0.000000
# 8                               0.000000
# 9                              -0.000711
# 10                             -0.000247
# 11                              0.000006
# 12                             -0.000434
# 13                             -0.000325
# 14                              0.000954
# 15                             -0.000774
# 16                              0.000000
# 17                             -0.000387
# 18                              0.000000
# 19                             -0.000016
# 20                              0.000000
# 21                              0.000000
# 22                              0.000000
# 23                             -0.000433
# 24                              0.000000
# 25                              0.000000
# 26                              0.000000
#
#     feature_permutaion_importance.evi2_diff  \
# 0                                  0.000000
# 1                                  0.000000
# 2                                  0.001017
# 3                                  0.000000
# 4                                  0.000000
# 5                                 -0.002329
# 6                                  0.000000
# 7                                  0.000000
# 8                                  0.000000
# 9                                  0.000239
# 10                                -0.000155
# 11                                -0.000006
# 12                                -0.001239
# 13                                -0.000162
# 14                                -0.007292
# 15                                 0.000000
# 16                                 0.000000
# 17                                 0.000000
# 18                                 0.000000
# 19                                 0.000010
# 20                                 0.000000
# 21                                 0.000000
# 22                                 0.000000
# 23                                -0.000965
# 24                                 0.000000
# 25                                 0.000000
# 26                                 0.000000
#
#     feature_permutaion_importance.evi2_max_diff  \
# 0                                      0.000000
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.000000
# 5                                      0.000783
# 6                                      0.000000
# 7                                      0.000000
# 8                                      0.000000
# 9                                     -0.000589
# 10                                    -0.000223
# 11                                     0.000000
# 12                                    -0.000510
# 13                                    -0.000650
# 14                                    -0.006240
# 15                                     0.000000
# 16                                     0.000000
# 17                                    -0.001394
# 18                                     0.000000
# 19                                     0.000002
# 20                                     0.000000
# 21                                     0.000000
# 22                                     0.000000
# 23                                    -0.001287
# 24                                     0.000000
# 25                                     0.000000
# 26                                     0.000000
#
#     feature_permutaion_importance.evi2_raster  \
# 0                                    0.000000
# 1                                    0.000000
# 2                                    0.000000
# 3                                    0.000000
# 4                                    0.000000
# 5                                   -0.001112
# 6                                    0.000000
# 7                                    0.000000
# 8                                    0.000000
# 9                                   -0.001221
# 10                                  -0.000577
# 11                                   0.000000
# 12                                   0.000548
# 13                                  -0.000162
# 14                                  -0.033371
# 15                                   0.000000
# 16                                   0.000000
# 17                                   0.000000
# 18                                   0.000000
# 19                                   0.000156
# 20                                  -0.000604
# 21                                   0.000000
# 22                                   0.000000
# 23                                  -0.000429
# 24                                   0.000000
# 25                                   0.000000
# 26                                   0.000000
#
#     feature_permutaion_importance.evi2_raster-1  \
# 0                                      0.000000
# 1                                      0.000000
# 2                                      0.000138
# ...
# 12                           NaN                    NaN              NaN
# 13                           NaN                    NaN              NaN
# 14                           NaN                    NaN              NaN
# 15                           NaN                    NaN              NaN
# 16                           NaN                    NaN              NaN
# 17                           NaN                   50.0              NaN
# 18                           NaN                    NaN              NaN
# 19                           NaN                    NaN              NaN
# 20                          0.00                  385.0             gini
# 21                           NaN                    NaN              NaN
# 22                           NaN                    NaN              NaN
# 23                           NaN                    NaN              NaN
# 24                           NaN                    NaN              NaN
# 25                           NaN                    NaN              NaN
# 26                           NaN                  106.0              NaN
#
#     params.ccp_alpha params.weights  params.p  params.n_neighbors  \
# 0                NaN            NaN       NaN                 NaN
# 1                NaN            NaN       NaN                 NaN
# 2                0.0            NaN       NaN                 NaN
# 3                NaN       distance       1.0                 7.0
# 4                NaN            NaN       NaN                 NaN
# 5                NaN            NaN       NaN                 NaN
# 6                NaN            NaN       NaN                 NaN
# 7                NaN            NaN       NaN                 NaN
# 8                NaN            NaN       NaN                 NaN
# 9                NaN            NaN       NaN                 NaN
# 10               NaN            NaN       NaN                 NaN
# 11               0.0            NaN       NaN                 NaN
# 12               NaN       distance       1.0                 3.0
# 13               NaN            NaN       NaN                 NaN
# 14               NaN            NaN       NaN                 NaN
# 15               NaN            NaN       NaN                 NaN
# 16               NaN            NaN       NaN                 NaN
# 17               NaN            NaN       NaN                 NaN
# 18               NaN            NaN       NaN                 NaN
# 19               NaN            NaN       NaN                 NaN
# 20               0.0            NaN       NaN                 NaN
# 21               NaN       distance       1.0                 4.0
# 22               NaN            NaN       NaN                 NaN
# 23               NaN            NaN       NaN                 NaN
# 24               NaN            NaN       NaN                 NaN
# 25               NaN            NaN       NaN                 NaN
# 26               NaN            NaN       NaN                 NaN
#
#    params.metric  params.leaf_size params.algorithm  params.tol  \
# 0            NaN               NaN              NaN         NaN
# 1            NaN               NaN              NaN         NaN
# 2            NaN               NaN              NaN         NaN
# 3      minkowski              46.0          kd_tree         NaN
# 4            NaN               NaN              NaN       0.007
# 5            NaN               NaN          SAMME.R         NaN
# 6            NaN               NaN          SAMME.R         NaN
# 7            NaN               NaN              NaN         NaN
# 8            NaN               NaN              NaN         NaN
# 9            NaN               NaN              NaN         NaN
# 10           NaN               NaN              NaN         NaN
# 11           NaN               NaN              NaN         NaN
# 12     minkowski              42.0        ball_tree         NaN
# 13           NaN               NaN              NaN       0.007
# 14           NaN               NaN          SAMME.R         NaN
# 15           NaN               NaN          SAMME.R         NaN
# 16           NaN               NaN              NaN         NaN
# 17           NaN               NaN              NaN         NaN
# 18           NaN               NaN              NaN         NaN
# 19           NaN               NaN              NaN         NaN
# 20           NaN               NaN              NaN         NaN
# 21     minkowski              16.0            brute         NaN
# 22           NaN               NaN              NaN       0.007
# 23           NaN               NaN          SAMME.R         NaN
# 24           NaN               NaN          SAMME.R         NaN
# 25           NaN               NaN              NaN         NaN
# 26           NaN               NaN              NaN         NaN
#
#    params.shrinking params.probability params.kernel  params.gamma  \
# 0               NaN                NaN           NaN           NaN
# 1               NaN                NaN           NaN           NaN
# 2               NaN                NaN           NaN           NaN
# 3               NaN                NaN           NaN           NaN
# 4              True               True           rbf         0.766
# 5               NaN                NaN           NaN           NaN
# 6               NaN                NaN           NaN           NaN
# 7               NaN                NaN           NaN         0.800
# 8               NaN                NaN           NaN           NaN
# 9               NaN                NaN           NaN           NaN
# 10              NaN                NaN           NaN           NaN
# 11              NaN                NaN           NaN           NaN
# 12              NaN                NaN           NaN           NaN
# 13             True               True           rbf         0.836
# 14              NaN                NaN           NaN           NaN
# 15              NaN                NaN           NaN           NaN
# 16              NaN                NaN           NaN         0.000
# 17              NaN                NaN           NaN           NaN
# 18              NaN                NaN           NaN           NaN
# 19              NaN                NaN           NaN           NaN
# 20              NaN                NaN           NaN           NaN
# 21              NaN                NaN           NaN           NaN
# 22             True               True           rbf         0.226
# 23              NaN                NaN           NaN           NaN
# 24              NaN                NaN           NaN           NaN
# 25              NaN                NaN           NaN         0.050
# 26              NaN                NaN           NaN           NaN
#
#    params.decision_function_shape  params.C params.replacement  \
# 0                             NaN       NaN                NaN
# 1                             NaN       NaN                NaN
# 2                             NaN       NaN                NaN
# 3                             NaN       NaN                NaN
# 4                             ovo      5.85                NaN
# 5                             NaN       NaN               True
# 6                             NaN       NaN                NaN
# 7                             NaN       NaN                NaN
# 8                             NaN       NaN                NaN
# 9                             NaN       NaN                NaN
# 10                            NaN       NaN                NaN
# 11                            NaN       NaN                NaN
# 12                            NaN       NaN                NaN
# 13                            ovo      9.10                NaN
# 14                            NaN       NaN              False
# 15                            NaN       NaN                NaN
# 16                            NaN       NaN                NaN
# 17                            NaN       NaN                NaN
# 18                            NaN       NaN                NaN
# 19                            NaN       NaN                NaN
# 20                            NaN       NaN                NaN
# 21                            NaN       NaN                NaN
# 22                            ovo      7.35                NaN
# 23                            NaN       NaN               True
# 24                            NaN       NaN                NaN
# 25                            NaN       NaN                NaN
# 26                            NaN       NaN                NaN
#
#     params.learning_rate  params.subsample  params.seed  \
# 0                    NaN               NaN          NaN
# 1                    NaN               NaN          NaN
# 2                    NaN               NaN          NaN
# 3                    NaN               NaN          NaN
# 4                    NaN               NaN          NaN
# 5                 0.0930               NaN          NaN
# 6                 0.4500               NaN          NaN
# 7                 0.0090              0.70       2022.0
# 8                 0.0355               NaN          NaN
# 9                    NaN               NaN          NaN
# 10                   NaN               NaN          NaN
# 11                   NaN               NaN          NaN
# 12                   NaN               NaN          NaN
# 13                   NaN               NaN          NaN
# 14                0.0950               NaN          NaN
# 15                0.4750               NaN          NaN
# 16                0.0090              0.95       2022.0
# 17                0.0325               NaN          NaN
# 18                   NaN               NaN          NaN
# 19                   NaN               NaN          NaN
# 20                   NaN               NaN          NaN
# 21                   NaN               NaN          NaN
# 22                   NaN               NaN          NaN
# 23                0.0830               NaN          NaN
# 24                0.0750               NaN          NaN
# 25                0.0070              0.55       2022.0
# 26                0.0365               NaN          NaN
#
#     params.scale_pos_weight params.objective  params.lambda  \
# 0                       NaN              NaN            NaN
# 1                       NaN              NaN            NaN
# 2                       NaN              NaN            NaN
# 3                       NaN              NaN            NaN
# 4                       NaN              NaN            NaN
# 5                       NaN              NaN            NaN
# 6                       NaN              NaN            NaN
# 7                 35.465116  binary:logistic            0.0
# 8                       NaN              NaN            NaN
# 9                       NaN              NaN            NaN
# 10                      NaN              NaN            NaN
# 11                      NaN              NaN            NaN
# 12                      NaN              NaN            NaN
# 13                      NaN              NaN            NaN
# 14                      NaN              NaN            NaN
# 15                      NaN              NaN            NaN
# 16                59.680556  binary:logistic            0.4
# 17                      NaN              NaN            NaN
# 18                      NaN              NaN            NaN
# 19                      NaN              NaN            NaN
# 20                      NaN              NaN            NaN
# 21                      NaN              NaN            NaN
# 22                      NaN              NaN            NaN
# 23                      NaN              NaN            NaN
# 24                      NaN              NaN            NaN
# 25               151.352941  binary:logistic            0.5
# 26                      NaN              NaN            NaN
#
#    params.eval_metric  params.colsample_bytree params.scoring  \
# 0                 NaN                      NaN            NaN
# 1                 NaN                      NaN            NaN
# 2                 NaN                      NaN            NaN
# 3                 NaN                      NaN            NaN
# 4                 NaN                      NaN            NaN
# 5                 NaN                      NaN            NaN
# 6                 NaN                      NaN            NaN
# 7                 auc                      0.7            NaN
# 8                 NaN                      NaN             f1
# 9                 NaN                      NaN            NaN
# 10                NaN                      NaN            NaN
# 11                NaN                      NaN            NaN
# 12                NaN                      NaN            NaN
# 13                NaN                      NaN            NaN
# 14                NaN                      NaN            NaN
# 15                NaN                      NaN            NaN
# 16              aucpr                      0.7            NaN
# 17                NaN                      NaN             f1
# 18                NaN                      NaN            NaN
# 19                NaN                      NaN            NaN
# 20                NaN                      NaN            NaN
# 21                NaN                      NaN            NaN
# 22                NaN                      NaN            NaN
# 23                NaN                      NaN            NaN
# 24                NaN                      NaN            NaN
# 25              aucpr                      0.9            NaN
# 26                NaN                      NaN             f1
#
#     params.max_iter          params.loss  params.l2_regularization
# 0               NaN                  NaN                       NaN
# 1               NaN                  NaN                       NaN
# 2               NaN                  NaN                       NaN
# 3               NaN                  NaN                       NaN
# 4               NaN                  NaN                       NaN
# 5               NaN                  NaN                       NaN
# 6               NaN                  NaN                       NaN
# 7               NaN                  NaN                       NaN
# 8             325.0  binary_crossentropy                      0.50
# 9               NaN                  NaN                       NaN
# 10              NaN                  NaN                       NaN
# 11              NaN                  NaN                       NaN
# 12              NaN                  NaN                       NaN
# 13              NaN                  NaN                       NaN
# 14              NaN                  NaN                       NaN
# 15              NaN                  NaN                       NaN
# 16              NaN                  NaN                       NaN
# 17            325.0  binary_crossentropy                      0.40
# 18              NaN                  NaN                       NaN
# 19              NaN                  NaN                       NaN
# 20              NaN                  NaN                       NaN
# 21              NaN                  NaN                       NaN
# 22              NaN                  NaN                       NaN
# 23              NaN                  NaN                       NaN
# 24              NaN                  NaN                       NaN
# 25              NaN                  NaN                       NaN
# 26            200.0  binary_crossentropy                      0.15

# %% [markdown]
# ### Healthy Vegetation

# %%
SPECIESES = ["1", "2", "1 2"]
MODELS = ["RandomForestClassifier", "BalancedRandomForestClassifier", "DecisionTreeClassifier", "KNeighborsClassifier", "SVM", "RUSBoostClassifier" , "AdaBoostClassifier", "XGBClassifier", "HistGradientBoostingClassifier"]
TARGET = "is_healthy"

binary_classifcation_results = list()

for SPECIES in SPECIESES:
    for MODEL in MODELS:
        if os.path.exists(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json"):
            continue
            
        # DO NOT INCLUDE DAMAGE CLASS 2.0 FOR DEAD OR HEALTHY CLASSIFICATION
        data_selection = binned_data[SPECIES]["train"].loc[binned_data[SPECIES]["train"]["damage_class"] != 2.0]
        
        print("-"*100)
        print(f"{MODEL} -> {SPECIES_CODE[SPECIES]}@{TARGET}")
        print("\t performing backward feature elemination...")
        init_model_params = get_model_params(_model=MODEL, _target=TARGET, _species=SPECIES_CODE[SPECIES])

        if "class_weight" in init_model_params:
            init_model_params["class_weight"] = define_class_weight(data_selection[TARGET])
        if "pos_scale" in init_model_params:
            init_model_params["pos_scale"] = define_pos_scale(data_selection[TARGET])

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)
        kappa_scorer = metrics.make_scorer(metrics.cohen_kappa_score)

        if MODEL == "RandomForestClassifier":
            model = RandomForestClassifier(**init_model_params)
        elif MODEL == "XGBClassifier":
            model = xgb.XGBClassifier(**init_model_params)
        elif MODEL == "KNeighborsClassifier":
            model = KNeighborsClassifier(**init_model_params)
        elif MODEL == "DecisionTreeClassifier":
            model = DecisionTreeClassifier(**init_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            model = HistGradientBoostingClassifier(**init_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            model = BalancedRandomForestClassifier(**init_model_params)
        elif MODEL == "RUSBoostClassifier":
            model = RUSBoostClassifier(**init_model_params)
        elif MODEL == "AdaBoostClassifier":
            model = AdaBoostClassifier(**init_model_params)
        else: #SVM
            model = SVC(**init_model_params)

        sfs = SequentialFeatureSelector(estimator=model, direction="backward", scoring=kappa_scorer, cv=skf, n_jobs=58)
        sfs.fit(data_selection[all_features], data_selection[TARGET])
        relevant_features = list(data_selection[all_features].columns[sfs.get_support()])

        # TRAINING DATA
        X_train = data_selection[relevant_features]
        y_train = data_selection[TARGET]
        # TEST DATA
        X_test = binned_data[SPECIES]["test"][relevant_features]
        y_test = binned_data[SPECIES]["test"][TARGET]

        print("\t performing hyperparameter tuning...")

        if MODEL == "RandomForestClassifier":
            params_rf = PARAMS_RF
            params_rf["class_weight"] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=RandomForestClassifier(), _params=params_rf, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = RandomForestClassifier(**fitted_model_params)
        elif MODEL == "XGBClassifier":
            params_xgb = PARAMS_XGB
            params_xgb['scale_pos_weight'] = [define_pos_scale(y_train.values)]
            fitted_model_params = parameter_tuning(_model=xgb.XGBClassifier(), _params=params_xgb, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = xgb.XGBClassifier(**fitted_model_params)
        elif MODEL == "KNeighborsClassifier":
            params_kn = PARAMS_KN
            fitted_model_params = parameter_tuning(_model=KNeighborsClassifier(), _params=params_kn, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = KNeighborsClassifier(**fitted_model_params)
        elif MODEL == "DecisionTreeClassifier":
            params_dt = PARAMS_DT
            params_dt['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=DecisionTreeClassifier(), _params=params_dt, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = DecisionTreeClassifier(**fitted_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            params_hgb = PARAMS_HGB
            fitted_model_params = parameter_tuning(_model=HistGradientBoostingClassifier(), _params=params_hgb, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = HistGradientBoostingClassifier(**fitted_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            params_brf = PARAMS_BRF
            fitted_model_params = parameter_tuning(_model=BalancedRandomForestClassifier(), _params=params_brf, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = BalancedRandomForestClassifier(**fitted_model_params)
        elif MODEL == "RUSBoostClassifier":
            params_rus = PARAMS_RUS
            fitted_model_params = parameter_tuning(_model=RUSBoostClassifier(), _params=params_rus, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = RUSBoostClassifier(**fitted_model_params)
        elif MODEL == "AdaBoostClassifier":
            params_ada = PARAMS_ADA
            fitted_model_params = parameter_tuning(_model=AdaBoostClassifier(), _params=params_ada, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = AdaBoostClassifier(**fitted_model_params)
        else:
            params_svm = PARAMS_SVM
            params_svm['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=SVC(), _params=params_svm, _scoring=kappa_scorer, _X=X_train, _y=y_train)
            model = SVC(**fitted_model_params)

        # CREATING BAGGING CLASSIFIER
        model = BaggingClassifier(base_estimator=model, n_estimators=15, max_samples=.2, max_features=1., bootstrap=True, bootstrap_features=True, oob_score=True, n_jobs=16)
        print("\t fitting model...")
        model.fit(X_train, y_train)
        # save model
        pickle.dump(model, open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.sav", 'wb'))

        # predict probabilities
        y_pred_proba = model.predict_proba(X_test)

        print("\t performing permutation feature importance...")
        from sklearn.inspection import permutation_importance
        permutation_importance = permutation_importance(model, X_test, y_test, n_repeats=5, random_state=2022, n_jobs=32, scoring=kappa_scorer)
        permutation_importance_obj = {}
        for i, feat_imp in enumerate(permutation_importance.importances_mean):
            permutation_importance_obj[all_features[i]] = feat_imp

        print("\t evaluating...")
        results = {}
        results["species"] = SPECIES_CODE[SPECIES]
        results["model"] = MODEL
        results["target"] = TARGET
        results["params"] = fitted_model_params
        results["relevant_features"] = relevant_features
        results["feature_permutaion_importance"] = permutation_importance_obj

        results["metrics"] = {}
        results["metrics"]["auc"] = metrics.roc_auc_score(y_test.values, y_pred_proba[:, 1])

        ## ROC AUC
        results["metrics"]["roc"] = {}
        threshold_roc, gmean_roc = roc_auc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["roc"]["threshold"] = threshold_roc
        y_pred_roc = apply_prediction(y_pred_proba[:, 1], threshold_roc)
        results["metrics"]["roc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["f1"] = metrics.f1_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["recall"] = metrics.recall_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["precision"] = metrics.precision_score(y_test.values, y_pred_roc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_roc).ravel()
        results["metrics"]["roc"]["tn"] = tn
        results["metrics"]["roc"]["fp"] = fp
        results["metrics"]["roc"]["fn"] = fn
        results["metrics"]["roc"]["tp"] = tp

        ## PRC
        results["metrics"]["prc"] = {}
        threshold_prc, fscore_prc = prc_rc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["prc"]["threshold"] = threshold_prc
        y_pred_prc = apply_prediction(y_pred_proba[:, 1], threshold_prc)
        results["metrics"]["prc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["f1"] = metrics.f1_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["recall"] = metrics.recall_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["precision"] = metrics.precision_score(y_test.values, y_pred_prc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_prc).ravel()
        results["metrics"]["prc"]["tn"] = tn
        results["metrics"]["prc"]["fp"] = fp
        results["metrics"]["prc"]["fn"] = fn
        results["metrics"]["prc"]["tp"] = tp

        ## TUNING
        results["metrics"]["tuning"] = {}
        threshold_tuning, fscore_tuneing = tune_threshold(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["tuning"]["threshold"] = threshold_tuning
        y_pred_tuning = apply_prediction(y_pred_proba[:, 1], threshold_tuning)
        results["metrics"]["tuning"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["f1"] = metrics.f1_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["recall"] = metrics.recall_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["precision"] = metrics.precision_score(y_test.values, y_pred_tuning)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_tuning).ravel()
        results["metrics"]["tuning"]["tn"] = tn
        results["metrics"]["tuning"]["fp"] = fp
        results["metrics"]["tuning"]["fn"] = fn
        results["metrics"]["tuning"]["tp"] = tp

        # quick export to dump data
        with open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json", 'w', encoding='utf-8') as f:
            json.dump(str(dict((k, v) for k,v in results.items())), f, ensure_ascii=False, indent=4)
        pd.json_normalize(results).to_csv(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.csv", index=False)

        binary_classifcation_results.append(results)

print("-"*75)
print(f"EXPORTING OVERALL RESULTS TO {EXPORT_PATH}/modelling_pipeline_results.csv")
print("-"*75)
df_result = pd.json_normalize(binary_classifcation_results)
df_result.to_csv(f"{EXPORT_PATH}/modelling_pipeline_results_healthy.csv", index=False)
df_result
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ---------------------------------------------------------------------------
# EXPORTING OVERALL RESULTS TO ./results/optimization/v1/modelling_pipeline_results.csv
# ---------------------------------------------------------------------------
#       species                           model      target  \
# 0   Deciduous          RandomForestClassifier  is_healthy
# 1   Deciduous  BalancedRandomForestClassifier  is_healthy
# 2   Deciduous          DecisionTreeClassifier  is_healthy
# 3   Deciduous            KNeighborsClassifier  is_healthy
# 4   Deciduous                             SVM  is_healthy
# 5   Deciduous              RUSBoostClassifier  is_healthy
# 6   Deciduous              AdaBoostClassifier  is_healthy
# 7   Deciduous                   XGBClassifier  is_healthy
# 8   Deciduous  HistGradientBoostingClassifier  is_healthy
# 9     Conifer          RandomForestClassifier  is_healthy
# 10    Conifer  BalancedRandomForestClassifier  is_healthy
# 11    Conifer          DecisionTreeClassifier  is_healthy
# 12    Conifer            KNeighborsClassifier  is_healthy
# 13    Conifer                             SVM  is_healthy
# 14    Conifer              RUSBoostClassifier  is_healthy
# 15    Conifer              AdaBoostClassifier  is_healthy
# 16    Conifer                   XGBClassifier  is_healthy
# 17    Conifer  HistGradientBoostingClassifier  is_healthy
# 18      Mixed          RandomForestClassifier  is_healthy
# 19      Mixed  BalancedRandomForestClassifier  is_healthy
# 20      Mixed          DecisionTreeClassifier  is_healthy
# 21      Mixed            KNeighborsClassifier  is_healthy
# 22      Mixed                             SVM  is_healthy
# 23      Mixed              RUSBoostClassifier  is_healthy
# 24      Mixed              AdaBoostClassifier  is_healthy
# 25      Mixed                   XGBClassifier  is_healthy
# 26      Mixed  HistGradientBoostingClassifier  is_healthy
#
#                                     relevant_features params.warm_start  \
# 0   [location_cluster_2, location_cluster_5, locat...             False
# 1   [location_cluster_0, location_cluster_1, locat...              True
# 2   [location_cluster_11, location_cluster_12, loc...               NaN
# 3   [location_cluster_0, location_cluster_1, locat...               NaN
# 4   [location_cluster_1, location_cluster_10, loca...               NaN
# 5   [location_cluster_0, location_cluster_1, locat...               NaN
# 6   [location_cluster_0, location_cluster_3, locat...               NaN
# 7   [location_cluster_0, location_cluster_1, locat...               NaN
# 8   [location_cluster_1, location_cluster_5, tree_...               NaN
# 9   [location_cluster_2, location_cluster_5, locat...             False
# 10  [location_cluster_0, location_cluster_1, locat...              True
# 11  [location_cluster_4, location_cluster_9, locat...               NaN
# 12  [location_cluster_0, location_cluster_2, locat...               NaN
# 13  [location_cluster_5, location_cluster_8, locat...               NaN
# 14  [location_cluster_9, tree_1, evi2, evi2_max_di...               NaN
# 15  [location_cluster_4, location_cluster_5, locat...               NaN
# 16  [location_cluster_2, location_cluster_3, locat...               NaN
# 17  [location_cluster_2, location_cluster_3, locat...               NaN
# 18  [location_cluster_2, location_cluster_4, locat...              True
# 19  [location_cluster_0, location_cluster_4, locat...              True
# 20  [location_cluster_11, tree_1, evi2-1, evi2_dif...               NaN
# 21  [location_cluster_1, location_cluster_2, locat...               NaN
# 22  [location_cluster_3, location_cluster_4, locat...               NaN
# 23  [location_cluster_4, location_cluster_5, locat...               NaN
# 24  [location_cluster_0, location_cluster_3, locat...               NaN
# 25  [location_cluster_3, location_cluster_4, locat...               NaN
# 26  [location_cluster_4, location_cluster_5, locat...               NaN
#
#     params.random_state  params.n_jobs  params.n_estimators  \
# 0                2022.0           58.0                224.0
# 1                2022.0           58.0                224.0
# 2                2022.0            NaN                  NaN
# 3                   NaN           58.0                  NaN
# 4                2022.0            NaN                  NaN
# 5                2022.0            NaN                410.0
# 6                2022.0            NaN                410.0
# 7                   NaN           58.0                395.0
# 8                2022.0            NaN                  NaN
# 9                2022.0           58.0                432.0
# 10               2022.0           58.0                384.0
# 11               2022.0            NaN                  NaN
# 12                  NaN           58.0                  NaN
# 13               2022.0            NaN                  NaN
# 14               2022.0            NaN                455.0
# 15               2022.0            NaN                440.0
# 16                  NaN           58.0                425.0
# 17               2022.0            NaN                  NaN
# 18               2022.0           58.0                368.0
# 19               2022.0           58.0                144.0
# 20               2022.0            NaN                  NaN
# 21                  NaN           58.0                  NaN
# 22               2022.0            NaN                  NaN
# 23               2022.0            NaN                440.0
# 24               2022.0            NaN                485.0
# 25                  NaN           58.0                485.0
# 26               2022.0            NaN                  NaN
#
#     params.min_samples_split  params.min_samples_leaf params.max_features  \
# 0                        6.0                      2.0                sqrt
# 1                        4.0                      2.0                sqrt
# 2                        8.0                     15.0                log2
# 3                        NaN                      NaN                 NaN
# 4                        NaN                      NaN                 NaN
# 5                        NaN                      NaN                 NaN
# 6                        NaN                      NaN                 NaN
# 7                        NaN                      NaN                 NaN
# 8                        NaN                     27.0                 NaN
# 9                        4.0                      2.0                sqrt
# 10                       2.0                      2.0                sqrt
# 11                      20.0                      2.0                sqrt
# 12                       NaN                      NaN                 NaN
# 13                       NaN                      NaN                 NaN
# 14                       NaN                      NaN                 NaN
# 15                       NaN                      NaN                 NaN
# 16                       NaN                      NaN                 NaN
# 17                       NaN                     11.0                 NaN
# 18                       4.0                      2.0                sqrt
# 19                       4.0                      2.0                sqrt
# 20                      28.0                      6.0                log2
# 21                       NaN                      NaN                 NaN
# 22                       NaN                      NaN                 NaN
# 23                       NaN                      NaN                 NaN
# 24                       NaN                      NaN                 NaN
# 25                       NaN                      NaN                 NaN
# 26                       NaN                      3.0                 NaN
#
#     params.max_depth  params.class_weight.1  params.class_weight.0  \
# 0               80.0               2.136240               0.652789
# 1              192.0                    NaN                    NaN
# 2                3.0               2.136240               0.652789
# 3                NaN                    NaN                    NaN
# 4                NaN               2.136240               0.652789
# 5                NaN                    NaN                    NaN
# 6                NaN                    NaN                    NaN
# 7                7.0                    NaN                    NaN
# 8              113.0                    NaN                    NaN
# 9              192.0               1.848139               0.685441
# 10              96.0                    NaN                    NaN
# 11              31.0               1.848139               0.685441
# 12               NaN                    NaN                    NaN
# 13               NaN               1.848139               0.685441
# 14               NaN                    NaN                    NaN
# 15               NaN                    NaN                    NaN
# 16               7.0                    NaN                    NaN
# 17              71.0                    NaN                    NaN
# 18              64.0               2.098865               0.656361
# 19             192.0                    NaN                    NaN
# 20               3.0               2.098865               0.656361
# 21               NaN                    NaN                    NaN
# 22               NaN               2.098865               0.656361
# 23               NaN                    NaN                    NaN
# 24               NaN                    NaN                    NaN
# 25               6.0                    NaN                    NaN
# 26             120.0                    NaN                    NaN
#
#     feature_permutaion_importance.location_cluster_0  \
# 0                                           0.007384
# 1                                           0.005800
# 2                                           0.000000
# 3                                           0.001021
# 4                                           0.014495
# 5                                           0.024405
# 6                                           0.077961
# 7                                          -0.008022
# 8                                          -0.005073
# 9                                          -0.002360
# 10                                         -0.005699
# 11                                          0.029800
# 12                                         -0.007797
# 13                                          0.109182
# 14                                          0.042576
# 15                                         -0.008823
# 16                                         -0.011702
# 17                                         -0.009413
# 18                                         -0.050272
# 19                                         -0.008143
# 20                                          0.004791
# 21                                         -0.012683
# 22                                          0.034345
# 23                                         -0.010020
# 24                                         -0.005038
# 25                                         -0.001487
# 26                                         -0.036597
#
#     feature_permutaion_importance.location_cluster_1  \
# 0                                           0.076365
# 1                                           0.010091
# 2                                           0.000000
# 3                                           0.003633
# 4                                           0.014443
# 5                                           0.031199
# 6                                          -0.013598
# 7                                          -0.008214
# 8                                           0.141013
# 9                                           0.157940
# 10                                         -0.012033
# 11                                          0.011596
# 12                                          0.001756
# 13                                          0.014583
# 14                                          0.031660
# 15                                          0.043961
# 16                                         -0.010940
# 17                                          0.001552
# 18                                         -0.097574
# 19                                          0.017790
# 20                                          0.004023
# 21                                          0.010844
# 22                                          0.023642
# 23                                          0.012032
# 24                                          0.075196
# 25                                         -0.021077
# 26                                          0.062999
#
#     feature_permutaion_importance.location_cluster_2  \
# 0                                           0.001117
# 1                                           0.010745
# 2                                           0.000000
# 3                                          -0.005302
# 4                                           0.010330
# 5                                           0.044873
# 6                                           0.032573
# 7                                          -0.022927
# 8                                           0.279991
# 9                                           0.002266
# 10                                         -0.004000
# 11                                          0.049355
# 12                                          0.001359
# 13                                         -0.001635
# 14                                          0.009260
# 15                                          0.002871
# 16                                          0.121660
# 17                                          0.036492
# 18                                         -0.004452
# 19                                          0.030759
# 20                                         -0.000683
# 21                                         -0.060613
# 22                                          0.067902
# 23                                         -0.000180
# 24                                          0.059195
# 25                                          0.068215
# 26                                         -0.071435
#
#     feature_permutaion_importance.location_cluster_3  \
# 0                                          -0.011860
# 1                                          -0.003822
# 2                                           0.000000
# 3                                           0.016066
# 4                                           0.024941
# 5                                          -0.009850
# 6                                           0.131076
# 7                                           0.023354
# 8                                          -0.010409
# 9                                           0.038108
# 10                                          0.000686
# 11                                          0.007071
# 12                                          0.048048
# 13                                          0.035254
# 14                                          0.007119
# 15                                         -0.007446
# 16                                          0.006571
# 17                                         -0.005769
# 18                                         -0.098599
# 19                                         -0.004692
# 20                                         -0.000743
# 21                                         -0.066892
# 22                                          0.039609
# 23                                          0.004678
# 24                                          0.073316
# 25                                         -0.024946
# 26                                         -0.028583
#
#     feature_permutaion_importance.location_cluster_4  \
# 0                                          -0.004882
# 1                                           0.076286
# 2                                           0.000000
# 3                                           0.009902
# 4                                           0.040851
# 5                                           0.082548
# 6                                           0.149191
# 7                                          -0.007357
# 8                                           0.009370
# 9                                          -0.001728
# 10                                          0.052910
# 11                                         -0.001449
# 12                                         -0.027374
# 13                                         -0.016542
# 14                                          0.028277
# 15                                         -0.014441
# 16                                         -0.022298
# 17                                          0.011715
# 18                                         -0.084633
# 19                                         -0.012907
# 20                                         -0.007921
# 21                                         -0.018477
# 22                                          0.016253
# 23                                          0.031665
# 24                                         -0.004849
# 25                                         -0.010664
# 26                                         -0.041781
#
#     feature_permutaion_importance.location_cluster_5  \
# 0                                           0.108652
# 1                                           0.005013
# 2                                           0.000000
# 3                                          -0.002973
# 4                                           0.020737
# 5                                           0.012079
# 6                                          -0.021266
# 7                                          -0.008131
# 8                                           0.011495
# 9                                           0.055364
# 10                                         -0.001559
# 11                                         -0.002579
# 12                                         -0.001163
# 13                                          0.050931
# 14                                          0.005857
# 15                                         -0.002000
# 16                                         -0.009924
# 17                                          0.116304
# 18                                         -0.085591
# 19                                          0.048182
# 20                                          0.000339
# 21                                         -0.026090
# 22                                          0.019543
# 23                                         -0.002602
# 24                                          0.162580
# 25                                          0.003985
# 26                                         -0.046500
#
#     feature_permutaion_importance.location_cluster_6  \
# 0                                           0.020234
# 1                                           0.006797
# 2                                           0.000000
# 3                                          -0.001974
# 4                                           0.034020
# 5                                           0.014407
# 6                                           0.012890
# 7                                          -0.033986
# 8                                           0.013442
# 9                                           0.001393
# 10                                         -0.006290
# 11                                          0.002537
# 12                                         -0.011561
# 13                                          0.006929
# 14                                          0.004669
# 15                                          0.108844
# 16                                         -0.012414
# 17                                          0.004662
# 18                                          0.079906
# 19                                         -0.007599
# 20                                          0.000000
# 21                                         -0.043748
# 22                                          0.029640
# 23                                         -0.000392
# 24                                          0.000177
# 25                                          0.296929
# 26                                          0.197902
#
#     feature_permutaion_importance.location_cluster_7  \
# 0                                           0.007822
# 1                                           0.013881
# 2                                           0.000000
# 3                                          -0.002676
# 4                                           0.011922
# 5                                           0.022956
# 6                                          -0.020467
# 7                                          -0.006948
# 8                                           0.031995
# 9                                           0.004582
# 10                                          0.076952
# 11                                          0.003565
# 12                                          0.019830
# 13                                          0.012318
# 14                                          0.011547
# 15                                          0.025756
# 16                                          0.057510
# 17                                         -0.036717
# 18                                          0.016217
# 19                                          0.002352
# 20                                          0.000164
# 21                                         -0.036403
# 22                                         -0.003541
# 23                                          0.008421
# 24                                          0.117919
# 25                                          0.002441
# 26                                         -0.001565
#
#     feature_permutaion_importance.location_cluster_8  \
# 0                                          -0.002118
# 1                                           0.012542
# 2                                           0.000000
# 3                                          -0.001977
# 4                                           0.008453
# 5                                           0.019546
# 6                                           0.067534
# 7                                          -0.010281
# 8                                          -0.020084
# 9                                           0.007931
# 10                                          0.006899
# 11                                         -0.005588
# 12                                          0.011241
# 13                                          0.045219
# 14                                          0.009893
# 15                                         -0.004472
# 16                                          0.006356
# 17                                          0.001097
# 18                                          0.011018
# 19                                          0.027323
# 20                                         -0.003591
# 21                                         -0.031775
# 22                                         -0.059256
# 23                                          0.008450
# 24                                          0.090150
# 25                                         -0.003671
# 26                                          0.039727
#
#     feature_permutaion_importance.location_cluster_9  \
# 0                                           0.012620
# 1                                           0.001924
# 2                                           0.000000
# 3                                           0.000956
# 4                                           0.030897
# 5                                           0.032248
# 6                                           0.012646
# 7                                          -0.011091
# 8                                           0.022552
# 9                                           0.005065
# 10                                          0.013775
# 11                                          0.000000
# 12                                         -0.001563
# 13                                          0.044243
# 14                                          0.005152
# 15                                         -0.001762
# 16                                          0.001696
# 17                                         -0.011372
# 18                                          0.014133
# 19                                          0.000670
# 20                                         -0.001710
# 21                                          0.002563
# 22                                          0.022234
# 23                                          0.002083
# 24                                          0.029383
# 25                                          0.005281
# 26                                          0.040004
#
#     feature_permutaion_importance.location_cluster_10  \
# 0                                            0.011975
# 1                                            0.005107
# 2                                            0.000000
# 3                                           -0.006321
# 4                                            0.010352
# 5                                            0.036571
# 6                                            0.023456
# 7                                           -0.026520
# 8                                            0.007408
# 9                                            0.001264
# 10                                          -0.019746
# 11                                           0.009269
# 12                                          -0.000727
# 13                                          -0.007309
# 14                                           0.004564
# 15                                           0.039472
# 16                                          -0.008677
# 17                                          -0.001522
# 18                                          -0.003664
# 19                                          -0.003981
# 20                                          -0.019534
# 21                                          -0.014831
# 22                                           0.018731
# 23                                           0.003994
# 24                                           0.073763
# 25                                           0.020963
# 26                                          -0.020168
#
#     feature_permutaion_importance.location_cluster_11  \
# 0                                            0.014441
# 1                                           -0.003068
# 2                                            0.000000
# 3                                           -0.004616
# 4                                            0.011704
# 5                                            0.025583
# 6                                           -0.012737
# 7                                           -0.005387
# 8                                            0.000018
# 9                                           -0.007036
# 10                                          -0.001645
# 11                                           0.007257
# 12                                          -0.002656
# 13                                           0.005692
# 14                                          -0.001404
# 15                                           0.020529
# 16                                           0.004884
# 17                                          -0.014426
# 18                                           0.002338
# 19                                          -0.002195
# 20                                           0.000000
# 21                                          -0.014209
# 22                                          -0.004023
# 23                                           0.003314
# 24                                           0.032487
# 25                                          -0.001025
# 26                                           0.016032
#
#     feature_permutaion_importance.location_cluster_12  \
# 0                                            0.003802
# 1                                            0.009184
# 2                                            0.000000
# 3                                           -0.006112
# 4                                            0.007341
# 5                                            0.021490
# 6                                            0.015972
# 7                                           -0.043416
# 8                                            0.008215
# 9                                            0.031091
# 10                                          -0.004624
# 11                                           0.004969
# 12                                           0.024259
# 13                                           0.025687
# 14                                           0.020127
# 15                                          -0.009425
# 16                                           0.011009
# 17                                          -0.020313
# 18                                           0.006884
# 19                                           0.002251
# 20                                           0.000000
# 21                                          -0.049026
# 22                                           0.013439
# 23                                           0.001409
# 24                                           0.023244
# 25                                          -0.003051
# 26                                          -0.005994
#
#     feature_permutaion_importance.location_cluster_13  \
# 0                                            0.011505
# 1                                            0.002684
# 2                                            0.000000
# 3                                           -0.004007
# 4                                            0.013935
# 5                                            0.006047
# 6                                            0.024031
# 7                                           -0.015290
# 8                                            0.020039
# 9                                            0.007064
# 10                                           0.004907
# 11                                           0.007661
# 12                                          -0.049325
# 13                                           0.021919
# 14                                          -0.011386
# 15                                           0.010729
# 16                                           0.012999
# 17                                          -0.003517
# 18                                          -0.000596
# 19                                          -0.001684
# 20                                           0.008895
# 21                                          -0.033915
# 22                                           0.004559
# 23                                          -0.005090
# 24                                           0.021422
# 25                                          -0.002975
# 26                                           0.001582
#
#     feature_permutaion_importance.tree_1  feature_permutaion_importance.evi2  \
# 0                               0.003476                            0.043355
# 1                               0.006816                           -0.001279
# 2                               0.000000                            0.000000
# 3                               0.001676                            0.037633
# 4                               0.005732                            0.023682
# 5                               0.023688                            0.031328
# 6                              -0.008212                            0.015438
# 7                              -0.008641                           -0.007079
# 8                               0.020334                            0.018162
# 9                               0.009044                           -0.004297
# 10                              0.009035                           -0.017598
# 11                              0.007288                           -0.007560
# 12                              0.004072                            0.003970
# 13                              0.025072                            0.043748
# 14                              0.012148                           -0.024368
# 15                              0.025710                            0.016424
# 16                             -0.001301                           -0.034998
# 17                              0.035195                            0.012838
# 18                              0.004527                            0.048407
# 19                              0.004200                            0.000036
# 20                             -0.005094                           -0.002237
# 21                              0.006642                           -0.018858
# 22                              0.020460                            0.000430
# 23                             -0.007517                            0.003210
# 24                              0.012493                            0.051115
# 25                              0.001358                            0.001408
# 26                              0.012939                           -0.008787
#
#     feature_permutaion_importance.evi2-1  \
# 0                              -0.023974
# 1                               0.010095
# 2                               0.000000
# 3                              -0.020412
# 4                               0.025543
# 5                               0.023657
# 6                               0.044375
# 7                              -0.036000
# 8                               0.022800
# 9                               0.037249
# 10                             -0.005471
# 11                             -0.004944
# 12                             -0.022128
# 13                             -0.008511
# 14                             -0.009494
# 15                              0.133461
# 16                              0.028832
# 17                              0.020834
# 18                             -0.002663
# 19                              0.003029
# 20                              0.013324
# 21                             -0.002132
# 22                              0.021489
# 23                              0.010920
# 24                              0.037137
# 25                              0.025814
# 26                             -0.002318
#
#     feature_permutaion_importance.evi2_diff  \
# 0                                  0.010953
# 1                                  0.007532
# 2                                  0.000000
# 3                                 -0.005456
# 4                                  0.011071
# 5                                  0.021640
# 6                                  0.032805
# 7                                 -0.026277
# 8                                  0.003190
# 9                                  0.006731
# 10                                 0.004814
# 11                                 0.016358
# 12                                -0.028128
# 13                                 0.013837
# 14                                 0.009487
# 15                                -0.010074
# 16                                -0.045524
# 17                                -0.008324
# 18                                 0.004456
# 19                                 0.015574
# 20                                 0.006839
# 21                                -0.002322
# 22                                 0.012343
# 23                                 0.008277
# 24                                 0.092676
# 25                                -0.009036
# 26                                -0.017113
#
#     feature_permutaion_importance.evi2_max_diff  \
# 0                                      0.010995
# 1                                      0.002244
# 2                                      0.000000
# 3                                     -0.005583
# 4                                      0.046829
# 5                                      0.033793
# 6                                      0.037781
# 7                                      0.003685
# 8                                      0.023026
# 9                                      0.033208
# 10                                     0.021876
# 11                                     0.002868
# 12                                    -0.010391
# 13                                     0.050381
# 14                                    -0.034366
# 15                                    -0.009629
# 16                                    -0.020751
# 17                                     0.004820
# 18                                    -0.016278
# 19                                     0.017603
# 20                                    -0.003773
# 21                                    -0.083149
# 22                                    -0.027540
# 23                                     0.003055
# 24                                     0.089288
# 25                                     0.003787
# 26                                    -0.014751
#
#     feature_permutaion_importance.evi2_raster  \
# 0                                   -0.001892
# 1                                    0.001285
# 2                                    0.000000
# 3                                    0.002655
# 4                                    0.014515
# 5                                    0.010831
# 6                                    0.064814
# 7                                   -0.022285
# 8                                   -0.004250
# 9                                    0.001915
# 10                                   0.047687
# 11                                   0.000000
# 12                                   0.014489
# 13                                   0.005836
# 14                                   0.025042
# 15                                   0.034315
# 16                                   0.038996
# 17                                  -0.018211
# 18                                   0.008983
# 19                                   0.007820
# 20                                   0.000567
# 21                                  -0.012509
# 22                                  -0.013297
# 23                                   0.001103
# 24                                   0.008177
# 25                                  -0.004497
# 26                                   0.022074
#
#     feature_permutaion_importance.evi2_raster-1  \
# ...
# 12                           NaN                    NaN              NaN
# 13                           NaN                    NaN              NaN
# 14                           NaN                    NaN              NaN
# 15                           NaN                    NaN              NaN
# 16                           NaN                    NaN              NaN
# 17                           NaN                   92.0              NaN
# 18                           NaN                    NaN              NaN
# 19                           NaN                    NaN              NaN
# 20                           0.0                  513.0          entropy
# 21                           NaN                    NaN              NaN
# 22                           NaN                    NaN              NaN
# 23                           NaN                    NaN              NaN
# 24                           NaN                    NaN              NaN
# 25                           NaN                    NaN              NaN
# 26                           NaN                   85.0              NaN
#
#     params.ccp_alpha params.weights  params.p  params.n_neighbors  \
# 0                NaN            NaN       NaN                 NaN
# 1                NaN            NaN       NaN                 NaN
# 2                0.0            NaN       NaN                 NaN
# 3                NaN       distance       1.0                14.0
# 4                NaN            NaN       NaN                 NaN
# 5                NaN            NaN       NaN                 NaN
# 6                NaN            NaN       NaN                 NaN
# 7                NaN            NaN       NaN                 NaN
# 8                NaN            NaN       NaN                 NaN
# 9                NaN            NaN       NaN                 NaN
# 10               NaN            NaN       NaN                 NaN
# 11               0.0            NaN       NaN                 NaN
# 12               NaN       distance       2.0                 2.0
# 13               NaN            NaN       NaN                 NaN
# 14               NaN            NaN       NaN                 NaN
# 15               NaN            NaN       NaN                 NaN
# 16               NaN            NaN       NaN                 NaN
# 17               NaN            NaN       NaN                 NaN
# 18               NaN            NaN       NaN                 NaN
# 19               NaN            NaN       NaN                 NaN
# 20               0.0            NaN       NaN                 NaN
# 21               NaN       distance       1.0                 2.0
# 22               NaN            NaN       NaN                 NaN
# 23               NaN            NaN       NaN                 NaN
# 24               NaN            NaN       NaN                 NaN
# 25               NaN            NaN       NaN                 NaN
# 26               NaN            NaN       NaN                 NaN
#
#    params.metric  params.leaf_size params.algorithm  params.tol  \
# 0            NaN               NaN              NaN         NaN
# 1            NaN               NaN              NaN         NaN
# 2            NaN               NaN              NaN         NaN
# 3      minkowski              24.0        ball_tree         NaN
# 4            NaN               NaN              NaN       0.002
# 5            NaN               NaN          SAMME.R         NaN
# 6            NaN               NaN          SAMME.R         NaN
# 7            NaN               NaN              NaN         NaN
# 8            NaN               NaN              NaN         NaN
# 9            NaN               NaN              NaN         NaN
# 10           NaN               NaN              NaN         NaN
# 11           NaN               NaN              NaN         NaN
# 12     manhattan              40.0          kd_tree         NaN
# 13           NaN               NaN              NaN       0.004
# 14           NaN               NaN          SAMME.R         NaN
# 15           NaN               NaN          SAMME.R         NaN
# 16           NaN               NaN              NaN         NaN
# 17           NaN               NaN              NaN         NaN
# 18           NaN               NaN              NaN         NaN
# 19           NaN               NaN              NaN         NaN
# 20           NaN               NaN              NaN         NaN
# 21     manhattan              42.0            brute         NaN
# 22           NaN               NaN              NaN       0.004
# 23           NaN               NaN          SAMME.R         NaN
# 24           NaN               NaN          SAMME.R         NaN
# 25           NaN               NaN              NaN         NaN
# 26           NaN               NaN              NaN         NaN
#
#    params.shrinking params.probability params.kernel  params.gamma  \
# 0               NaN                NaN           NaN           NaN
# 1               NaN                NaN           NaN           NaN
# 2               NaN                NaN           NaN           NaN
# 3               NaN                NaN           NaN           NaN
# 4             False               True           rbf         0.551
# 5               NaN                NaN           NaN           NaN
# 6               NaN                NaN           NaN           NaN
# 7               NaN                NaN           NaN         0.450
# 8               NaN                NaN           NaN           NaN
# 9               NaN                NaN           NaN           NaN
# 10              NaN                NaN           NaN           NaN
# 11              NaN                NaN           NaN           NaN
# 12              NaN                NaN           NaN           NaN
# 13            False               True           rbf         0.831
# 14              NaN                NaN           NaN           NaN
# 15              NaN                NaN           NaN           NaN
# 16              NaN                NaN           NaN         0.650
# 17              NaN                NaN           NaN           NaN
# 18              NaN                NaN           NaN           NaN
# 19              NaN                NaN           NaN           NaN
# 20              NaN                NaN           NaN           NaN
# 21              NaN                NaN           NaN           NaN
# 22             True               True           rbf         0.886
# 23              NaN                NaN           NaN           NaN
# 24              NaN                NaN           NaN           NaN
# 25              NaN                NaN           NaN         0.600
# 26              NaN                NaN           NaN           NaN
#
#    params.decision_function_shape  params.C params.replacement  \
# 0                             NaN       NaN                NaN
# 1                             NaN       NaN                NaN
# 2                             NaN       NaN                NaN
# 3                             NaN       NaN                NaN
# 4                             ovo      5.85                NaN
# 5                             NaN       NaN              False
# 6                             NaN       NaN                NaN
# 7                             NaN       NaN                NaN
# 8                             NaN       NaN                NaN
# 9                             NaN       NaN                NaN
# 10                            NaN       NaN                NaN
# 11                            NaN       NaN                NaN
# 12                            NaN       NaN                NaN
# 13                            ovo      4.60                NaN
# 14                            NaN       NaN               True
# 15                            NaN       NaN                NaN
# 16                            NaN       NaN                NaN
# 17                            NaN       NaN                NaN
# 18                            NaN       NaN                NaN
# 19                            NaN       NaN                NaN
# 20                            NaN       NaN                NaN
# 21                            NaN       NaN                NaN
# 22                            ovo      6.35                NaN
# 23                            NaN       NaN               True
# 24                            NaN       NaN                NaN
# 25                            NaN       NaN                NaN
# 26                            NaN       NaN                NaN
#
#     params.learning_rate  params.subsample  params.seed  \
# 0                    NaN               NaN          NaN
# 1                    NaN               NaN          NaN
# 2                    NaN               NaN          NaN
# 3                    NaN               NaN          NaN
# 4                    NaN               NaN          NaN
# 5                 0.0850               NaN          NaN
# 6                 0.4750               NaN          NaN
# 7                 0.0090              0.55       2022.0
# 8                 0.0470               NaN          NaN
# 9                    NaN               NaN          NaN
# 10                   NaN               NaN          NaN
# 11                   NaN               NaN          NaN
# 12                   NaN               NaN          NaN
# 13                   NaN               NaN          NaN
# 14                0.0890               NaN          NaN
# 15                0.4250               NaN          NaN
# 16                0.0090              0.95       2022.0
# 17                0.0495               NaN          NaN
# 18                   NaN               NaN          NaN
# 19                   NaN               NaN          NaN
# 20                   NaN               NaN          NaN
# 21                   NaN               NaN          NaN
# 22                   NaN               NaN          NaN
# 23                0.0870               NaN          NaN
# 24                0.4500               NaN          NaN
# 25                0.0070              0.90       2022.0
# 26                0.0385               NaN          NaN
#
#     params.scale_pos_weight params.objective  params.lambda  \
# 0                       NaN              NaN            NaN
# 1                       NaN              NaN            NaN
# 2                       NaN              NaN            NaN
# 3                       NaN              NaN            NaN
# 4                       NaN              NaN            NaN
# 5                       NaN              NaN            NaN
# 6                       NaN              NaN            NaN
# 7                  3.272480  binary:logistic            0.2
# 8                       NaN              NaN            NaN
# 9                       NaN              NaN            NaN
# 10                      NaN              NaN            NaN
# 11                      NaN              NaN            NaN
# 12                      NaN              NaN            NaN
# 13                      NaN              NaN            NaN
# 14                      NaN              NaN            NaN
# 15                      NaN              NaN            NaN
# 16                 2.696277  binary:logistic            0.0
# 17                      NaN              NaN            NaN
# 18                      NaN              NaN            NaN
# 19                      NaN              NaN            NaN
# 20                      NaN              NaN            NaN
# 21                      NaN              NaN            NaN
# 22                      NaN              NaN            NaN
# 23                      NaN              NaN            NaN
# 24                      NaN              NaN            NaN
# 25                 3.197731  binary:logistic            0.0
# 26                      NaN              NaN            NaN
#
#    params.eval_metric  params.colsample_bytree params.scoring  \
# 0                 NaN                      NaN            NaN
# 1                 NaN                      NaN            NaN
# 2                 NaN                      NaN            NaN
# 3                 NaN                      NaN            NaN
# 4                 NaN                      NaN            NaN
# 5                 NaN                      NaN            NaN
# 6                 NaN                      NaN            NaN
# 7                 auc                     0.85            NaN
# 8                 NaN                      NaN             f1
# 9                 NaN                      NaN            NaN
# 10                NaN                      NaN            NaN
# 11                NaN                      NaN            NaN
# 12                NaN                      NaN            NaN
# 13                NaN                      NaN            NaN
# 14                NaN                      NaN            NaN
# 15                NaN                      NaN            NaN
# 16              aucpr                     0.80            NaN
# 17                NaN                      NaN        roc_auc
# 18                NaN                      NaN            NaN
# 19                NaN                      NaN            NaN
# 20                NaN                      NaN            NaN
# 21                NaN                      NaN            NaN
# 22                NaN                      NaN            NaN
# 23                NaN                      NaN            NaN
# 24                NaN                      NaN            NaN
# 25              aucpr                     0.95            NaN
# 26                NaN                      NaN        roc_auc
#
#     params.max_iter          params.loss  params.l2_regularization
# 0               NaN                  NaN                       NaN
# 1               NaN                  NaN                       NaN
# 2               NaN                  NaN                       NaN
# 3               NaN                  NaN                       NaN
# 4               NaN                  NaN                       NaN
# 5               NaN                  NaN                       NaN
# 6               NaN                  NaN                       NaN
# 7               NaN                  NaN                       NaN
# 8             450.0  binary_crossentropy                      0.40
# 9               NaN                  NaN                       NaN
# 10              NaN                  NaN                       NaN
# 11              NaN                  NaN                       NaN
# 12              NaN                  NaN                       NaN
# 13              NaN                  NaN                       NaN
# 14              NaN                  NaN                       NaN
# 15              NaN                  NaN                       NaN
# 16              NaN                  NaN                       NaN
# 17            175.0  binary_crossentropy                      0.80
# 18              NaN                  NaN                       NaN
# 19              NaN                  NaN                       NaN
# 20              NaN                  NaN                       NaN
# 21              NaN                  NaN                       NaN
# 22              NaN                  NaN                       NaN
# 23              NaN                  NaN                       NaN
# 24              NaN                  NaN                       NaN
# 25              NaN                  NaN                       NaN
# 26            325.0  binary_crossentropy                      0.65

# %% [markdown]
# ## Ensemble Learning: Base Model Results

# %%
df_results = [pd.read_csv(f"{EXPORT_PATH}/{file}.csv") for file in ["modelling_pipeline_results", "modelling_pipeline_results_dead", "modelling_pipeline_results_healthy"]]
df_results = pd.concat(df_results, ignore_index=True)
df_metrics, df_best_metrics, df_parameter, df_feature_importance = parse_results(df_results)
df_best_metrics.head()
# Out:
#      group                           model      target    species       auc  \
# 0      prc              RUSBoostClassifier  is_damaged      Mixed  0.812994
# 1      prc  HistGradientBoostingClassifier  is_damaged      Mixed  0.839361
# 2      prc                   XGBClassifier  is_damaged      Mixed  0.793658
# 3      prc              AdaBoostClassifier  is_damaged      Mixed  0.789066
# 4      prc  HistGradientBoostingClassifier  is_damaged  Deciduous  0.747019
# ..     ...                             ...         ...        ...       ...
# 76  tuning            KNeighborsClassifier     is_dead  Deciduous  0.493243
# 77  tuning  BalancedRandomForestClassifier     is_dead    Conifer  0.683594
# 78     roc          DecisionTreeClassifier     is_dead    Conifer  0.591797
# 79     roc  BalancedRandomForestClassifier     is_dead  Deciduous  0.500000
# 80     roc          DecisionTreeClassifier  is_healthy  Deciduous  0.500000
#
#     threshold  cohen_kappa        f1    recall  precision    tn    fp   fn  \
# 0    0.494228     0.584773  0.962714  0.976551   0.949265    82    69   31
# 1    0.616753     0.397225  0.953711  0.981846   0.927143    49   102   24
# 2    0.421647     0.336506  0.950531  0.981089   0.921819    41   110   25
# 3    0.500144     0.297043  0.949598  0.983359   0.918079    35   116   22
# 4    0.774345     0.465890  0.948601  0.980021   0.919132    53    82   19
# ..        ...          ...       ...       ...        ...   ...   ...  ...
# 76   0.011000     0.004780  0.020964  0.555556   0.010684   614   463    4
# 77   0.592000     0.011121  0.016598  0.333333   0.008511  1874   233    4
# 78   0.354940     0.003836  0.009461  0.833333   0.004757  1061  1046    1
# 79   1.537468     0.000000  0.000000  0.000000   0.000000  1077     0    9
# 80   1.499642     0.000000  0.000000  0.000000   0.000000   960     0  126
#
#       tp
# 0   1291
# 1   1298
# 2   1297
# 3   1300
# 4    932
# ..   ...
# 76     5
# 77     2
# 78     5
# 79     0
# 80     0
#
# [81 rows x 14 columns]
