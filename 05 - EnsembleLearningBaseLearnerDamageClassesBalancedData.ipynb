# %% [markdown]
# # Ensemble Learning - Base-Models with Balanced Training Data
# Build and optimize base models using balanced training data

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import os
import json

import pickle

from sklearn import metrics
from sklearn.base import clone
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, HistGradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

from imblearn.under_sampling import RandomUnderSampler, EditedNearestNeighbours
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN
from imblearn.ensemble import BalancedRandomForestClassifier, RUSBoostClassifier

from collections import Counter

pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Data Import & Data Preparation

# %%
DATA_PATH = "./data"
EXPORT_PATH = f"{DATA_PATH}/BaseLearner/v5"

SPECIES_CODE = {
    "1":"Deciduous",
    "2":"Conifer",
    "1 2":"Mixed"
}

SPECIES_CODE_INVERSE = {
    "Deciduous": "1",
    "Conifer": "2",
    "Mixed": "1 2"
}

# %%
df = pd.read_csv(f"{DATA_PATH}/location_cluster.csv")

df = df.sort_values(by="year")

# -----

def is_healthy(damage_class_group:str)->int:
    if damage_class_group == "healthy":
        return 1
    else:
        return 0
    
def is_damaged(damage_class_group:str)->int:
    if damage_class_group == "damaged":
        return 1
    else:
        return 0
    
def is_dead(damage_class_group:str)->int:
    if damage_class_group == "dead":
        return 1
    else:
        return 0
    
df["is_healthy"] = df["damage_class_group"].apply(lambda x: is_healthy(x))
df["is_damaged"] = df["damage_class_group"].apply(lambda x: is_damaged(x))
df["is_dead"] = df["damage_class_group"].apply(lambda x: is_dead(x))

# -----

static_cols = [
    col for col in df.columns if "location_cluster_" in col
]
static_cols.append("tree_1")

vegetation_cols = [
    col for col in df.columns if (("ndvi" in col) or ("evi2" in col)) and not col.endswith('max')
]

weather_cols = [
    'autumn_humidity',
    'autumn_rain_mm',
    'autumn_sun_h',
    'extreme_heat_day',
    'frozen_day',
    'heat_day',
    'heavy_rain',
    'spring_humidity',
    'spring_rain_mm',
    'spring_sun_h',
    'storm',
    'summer_humidity',
    'summer_longest_heat_wave',
    'summer_periods_without_rain_summer',
    'summer_rain_mm',
    'summer_sun_h',
    'winter_humidity',
    'winter_longest_cold_wave',
    'winter_rain_mm',
    'winter_snow_cm',
    'winter_sun_h',
]

all_features = static_cols + vegetation_cols + weather_cols

df[all_features].head()
# Out:
#       location_cluster_0  location_cluster_1  location_cluster_2  \
# 0                      0                   1                   0
# 5188                   0                   0                   0
# 5187                   0                   0                   0
# 5186                   0                   0                   0
# 5185                   0                   0                   0
#
#       location_cluster_3  location_cluster_4  location_cluster_5  \
# 0                      0                   0                   0
# 5188                   1                   0                   0
# 5187                   1                   0                   0
# 5186                   1                   0                   0
# 5185                   1                   0                   0
#
#       location_cluster_6  location_cluster_7  location_cluster_8  \
# 0                      0                   0                   0
# 5188                   0                   0                   0
# 5187                   0                   0                   0
# 5186                   0                   0                   0
# 5185                   0                   0                   0
#
#       location_cluster_9  location_cluster_10  location_cluster_11  \
# 0                      0                    0                    0
# 5188                   0                    0                    0
# 5187                   0                    0                    0
# 5186                   0                    0                    0
# 5185                   0                    0                    0
#
#       location_cluster_12  location_cluster_13    tree_1      evi2    evi2-1  \
# 0                       0                    0 -0.780422  0.247127  0.134649
# 5188                    0                    0 -0.630696 -1.377409  0.134649
# 5186                            0.046127       -0.719613     -0.140728
# 5185                            0.046127       -0.719613     -0.140728
#
#       winter_humidity  winter_longest_cold_wave  winter_rain_mm  \
# 0             1.79314                  0.343276       -1.081905
# 5188          0.69179                 -0.815622        0.119561
# 5187          0.69179                 -0.815622        0.119561
# 5186          0.69179                 -0.815622        0.119561
# 5185          0.69179                 -0.815622        0.119561
#
#       winter_snow_cm  winter_sun_h
# 0           0.637993     -0.509518
# 5188       -0.193376     -1.501934
# 5187       -0.193376     -1.501934
# 5186       -0.193376     -1.501934
# 5185       -0.193376     -1.501934

# %% [markdown]
# ### Definition of Functions

# %%
def train_test_split_by_observation(data_frame:pd.DataFrame, target:str, features:list):
    data_frame["key"] = data_frame["observation_id"] + ":" + data_frame["year"].astype(str)
    
    # group by observation_id and year to get unique observations by year only to prevent overfitting
    df_group = data_frame.groupby(["observation_id", "year"]).agg({"damage_class_group": lambda x: x.value_counts().index[0], target: lambda x: x.value_counts().index[0], "aoi": "first"}).reset_index()
    # remove all damaged classes that are not in BF
    #df_group = df_group.loc[~((df_group.damage_class_group == "damaged") & (df_group.aoi != "blackforest"))]
    y_observation_id = df_group.pop(target)
    X_observation_id = df_group

    # key to identify splitted data
    X_observation_id["key"] = X_observation_id["observation_id"] + ":" + X_observation_id["year"].astype(str)
    # train test split
    X_train_observation_id, X_test_observation_id, y_train_observation_id, y_test_observation_id = train_test_split(X_observation_id, y_observation_id, train_size=0.8, stratify=y_observation_id, random_state=2022)

    # filter for train test samples based on observation:year
    _X_train = data_frame.loc[data_frame.key.isin(list(X_train_observation_id.key))][features]
    _X_test = data_frame.loc[data_frame.key.isin(list(X_test_observation_id.key))][features]

    return _X_train, _X_test

def define_class_weight(y:np.array)->dict:
    class_weights = dict()

    for _class, count in Counter(y).items():
        weight = len(y) / (len(Counter(y)) * count)
        class_weights[_class] = weight
    return class_weights

def define_pos_scale(y:np.array)->float:
    return dict(Counter(y))[0] / dict(Counter(y))[1]
    
# https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/
def parameter_tuning(_model=None, _params=None, _scoring=None, _X=None, _y=None):
    sk_fold = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)

    randomized_clf_param_tuning = RandomizedSearchCV(estimator=_model, param_distributions=_params, scoring=_scoring, cv=sk_fold, n_jobs=58, n_iter=100, verbose=0)

    randomized_clf_param_tuning.fit(_X, _y)
    return randomized_clf_param_tuning.best_params_

def apply_prediction(pos_probs, threshold):
     return (pos_probs >= threshold).astype('int')
    
def get_model_params(_model: str, _target: str, _species:str)->dict:
    base_model = clone(pickle.load(open(f"{DATA_PATH}/BaseLearner/tmp/{_model}_{_species}_{_target}.sav", 'rb')))
    return base_model.get_params()

def roc_auc(actual, pred_proba, axes):
    fpr, tpr, thresholds = metrics.roc_curve(actual, pred_proba)
    # calculate the g-mean for each threshold
    gmeans = np.sqrt(tpr * (1-fpr))
    # locate the index of the largest g-mean
    ix = np.argmax(gmeans)
    if axes:
        # plot the roc curve for the model
        sns.lineplot([0,1], [0,1], linestyle='--', label='No Skill', color="tab:gray", ax=axes, err_style=None)
        sns.lineplot(fpr, tpr, label='Model', color="black", ax=axes, err_style=None)
        sns.scatterplot([fpr[ix]], [tpr[ix]], marker='^', color='tab:red', label=f'Optimal threshold @ {thresholds[ix]:.3f}', s=150, zorder=2, ax=axes)
    
    return thresholds[ix], gmeans[ix]

def prc_rc(actual, pred_proba, axes):
    precision, recall, thresholds = metrics.precision_recall_curve(actual, pred_proba)
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    # plot the roc curve for the model
    no_skill = len(actual[actual==1]) / len(actual)
    if axes:
        sns.lineplot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill', color="tab:gray", ax=axes, err_style=None)
        sns.lineplot(recall, precision, label='Model', color="black", ax=axes, err_style=None)
        sns.scatterplot([recall[ix]], [precision[ix]], marker='^', color='tab:red', label=f'Optimal threshold @ {thresholds[ix]:.3f}', s=150, zorder=2, ax=axes)

    return thresholds[ix], fscore[ix]
    
def tune_threshold(actual, pred_proba, axes):
    # Array for finding the optimal threshold
    thresholds = np.arange(0.0, 1.0, 0.001)
    fscore = np.zeros(shape=(len(thresholds)))
    # Fit the model
    def to_labels(pos_probs, threshold):
         return (pos_probs >= threshold).astype('int')
    fscore = [metrics.f1_score(actual, to_labels(pred_proba, t)) for t in thresholds]
        
    # Find the optimal threshold
    ix = np.argmax(fscore)
    if axes:
        sns.lineplot(thresholds, fscore, color="black", ax=axes, err_style=None)
        sns.scatterplot([thresholds[ix]], [fscore[ix]], marker='^', color='tab:red', label=f'Optimal threshold @ {thresholds[ix]:.3f}', s=150, zorder=2, ax=axes)

    return thresholds[ix], fscore[ix]


def parse_results(data_frame:pd.DataFrame):
    param_cols = [col for col in data_frame.columns if col.startswith("params")]
    metric_cols = [col for col in data_frame.columns if col.startswith("metrics")]
    feat_permutation_cols = [col for col in data_frame.columns if col.startswith("feature_permutaion_importance")]

    param_cols.extend(["model", "target", "species"])
    metric_cols.extend(["model", "target", "species"])
    feat_permutation_cols.extend(["model", "target", "species"])
    
    metric_groups = ["roc", "prc", "tuning"]
    actual_metrics = ["threshold", "cohen_kappa", "f1", "recall", "precision", "tn", "fp", "fn", "tp"]

    metrics_values = []
    for metric_group in metric_groups:
        for _i, _r in data_frame.iterrows():
            vals = {"group": metric_group, "model": _r["model"], "target": _r["target"], "species": _r["species"], "auc": _r["metrics.auc"]}
            for col in metric_cols:
                for _m in actual_metrics:
                    if _m in col and metric_group in col:
                        vals[_m] = _r[col]

            metrics_values.append(vals)

    df_metrics = pd.json_normalize(metrics_values)
    df_metrics = df_metrics.sort_values(by="f1", ascending=False)
    #print(f"model results -> {df_metrics.shape[0]} x {list(df_metrics.columns)}")

    best_model_selection = list()
    for _i, _r in df_metrics.groupby(["target", "species", "model"]).size().reset_index().iterrows():
        df_filter = df_metrics.loc[(df_metrics.target == _r.target) & (df_metrics.species == _r.species) & (df_metrics.model == _r.model)].sort_values(by="threshold", ascending=False)
        best_model_selection.append(df_filter.loc[df_filter.cohen_kappa == df_filter.cohen_kappa.max()].iloc[0][["target", "species", "model", "group"]].values)

    df_model_selection = pd.DataFrame(data=best_model_selection, columns=["target", "species", "model", "group"])
    df_best_metrics = df_metrics.merge(df_model_selection, on=["target", "species", "model", "group"], how="inner").drop_duplicates()
    #print(f"best model results -> {df_best_metrics.shape[0]} x {list(df_best_metrics.columns)}")

    df_parameter = data_frame[param_cols].melt(id_vars=param_cols[-3:], var_name="param", value_name="val")
    df_parameter["param"] = df_parameter["param"].apply(lambda x: x.replace("params.", ""))
    df_parameter = df_parameter.dropna()
    #print(f"model params -> {df_parameter.shape[0]} x {list(df_parameter.columns)}")

    df_feature_importance = data_frame[feat_permutation_cols].melt(id_vars=feat_permutation_cols[-3:], var_name="feature", value_name="feature_importance")
    df_feature_importance["feature"] = df_feature_importance["feature"].apply(lambda x: x.replace("feature_permutaion_importance.", ""))
    df_feature_importance = df_feature_importance.sort_values(by="feature_importance", ascending=False)
    #print(f"features -> {df_feature_importance.shape[0]} x {list(df_feature_importance.columns)}")
    
    return df_metrics, df_best_metrics, df_parameter, df_feature_importance

# %% [markdown]
# ### Model Parameters

# %%
PARAMS_RF = {
    'max_depth': np.arange(16, 256, 16),
    'max_features': ["sqrt"],
    'min_samples_leaf': np.arange(2, 16, 2),
    'min_samples_split': np.arange(2, 16, 2),
    'n_estimators': np.arange(32, 512, 16),
    'n_jobs': [58],
    'warm_start': [True, False],
    'random_state': [2022],
}
PARAMS_XGB = {
    'max_depth': np.arange(3, 8, 1),
    'learning_rate': np.arange(0.001, 0.01, 0.002),
    'n_estimators': np.arange(50, 500, 15),
    'colsample_bytree': np.arange(0.5, 1, 0.05),
    'subsample': np.arange(0.5, 1, 0.05),
    'eval_metric': ["aucpr", "auc"],
    'objective': ['binary:logistic'],
    'gamma': np.arange(0, 1, 0.05),
    'lambda': np.arange(0, 1, 0.1),
    'seed': [2022],
    'n_jobs': [58],
}
PARAMS_KN = {
    'n_neighbors': np.arange(2, 18, 1),
    'weights': ["distance", "uniform"],
    'algorithm': ['ball_tree', 'kd_tree', 'brute'],
    'leaf_size': np.arange(10, 50, 2),
    'p': [1, 2],
    'n_jobs': [58],
    'metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski', 'wminkowski', 'seuclidean', 'mahalanobis']
}
PARAMS_DT = {
    'criterion': ["gini", "entropy"],
    'splitter': ["random", "best"],
    'max_depth': np.arange(2, 32, 1),
    'min_samples_split': np.arange(2, 32, 2),
    'min_samples_leaf': np.arange(1, 16, 1),
    'max_features': ["sqrt", "log2"],
    'random_state': [2022],
    'min_weight_fraction_leaf': np.arange(0.0, 1.0, 0.05),
    'max_leaf_nodes': np.arange(1, 2048, 32),
    'min_impurity_decrease': np.arange(0.0, 1.0, 0.05),
    'ccp_alpha': np.arange(0, 1, 1),
}
PARAMS_HGB = {
    'loss': ['binary_crossentropy'],
    'learning_rate': np.arange(0.01, 0.05, 0.0005),
    'max_iter': np.arange(25, 500, 25),
    'max_leaf_nodes': np.arange(1, 128, 7),
    'max_depth': np.arange(1, 128, 7),
    'min_samples_leaf': np.arange(2, 32, 1),
    'l2_regularization': np.arange(0.0, 1.0, 0.05),
    #'warm_start': [True, False],
    'scoring': ["f1", "roc_auc"],
    #'tol': np.arange(1e-7, 9e-7, 1e-8),
    'random_state': [2022],
}
PARAMS_BRF = {
    'max_depth': np.arange(16, 256, 16),
    'max_features': ["sqrt"],
    'min_samples_leaf': np.arange(2, 24, 2),
    'min_samples_split': np.arange(2, 24, 2),
    'n_estimators': np.arange(32, 512, 16),
    'n_jobs': [58],
    'warm_start': [True, False],
    'random_state': [2022],
    #'class_weight': [define_class_weight(_y.values)]
}
PARAMS_RUS = {
    'replacement': [True, False],
    'learning_rate': np.arange(0.001, 0.1, 0.002),
    'n_estimators': np.arange(50, 500, 15),
    'algorithm': ["SAMME", "SAMME.R"],
    'random_state': [2022],
}
PARAMS_ADA = {
    'learning_rate': np.arange(0.05, 0.5, 0.025),
    'n_estimators': np.arange(50, 500, 15),
    'algorithm': ["SAMME", "SAMME.R"],
    'random_state': [2022],
}
PARAMS_SVM = {
    'gamma': np.arange(0.001, 1, 0.005),
    'C': np.arange(0.1, 10, 0.25),
    'shrinking': [False, True],
    'kernel': ['rbf', 'poly', 'sigmoid'],
    'probability': [True],
    'tol': np.arange(0.001, 0.01, 0.001),
    'decision_function_shape': ['ovo'],
    'random_state': [2022],
}

# %% [markdown]
# ### Define Hold-Out

# %%
np.random.seed(2022)

binned_data = dict()
for species in ["1", "2", "1 2"]:
    _binned = df.copy()

    _binned = _binned.loc[_binned.list_tree_sp_cat_ids == species]

    for col in all_features:
        _binned[col] = pd.qcut(_binned[col].rank(method='first'), 10) # _binned[col]
        _binned[col] =_binned[col].cat.codes

    min_max_scaler = MinMaxScaler()
    _binned[all_features] = min_max_scaler.fit_transform(_binned[all_features])

    validation_observation_ids = np.random.choice(_binned.loc[_binned.aoi == "blackforest"].observation_id.unique(), size=2)
    _validation = _binned.loc[_binned.observation_id.isin(validation_observation_ids)]
    
    _train, _test = train_test_split_by_observation(data_frame=_binned.loc[~_binned.observation_id.isin(validation_observation_ids)], target="damage_class_group", features=_binned.columns)
    _test = pd.concat([_test, _validation])
    
    splitted_data = {
        'train': _train,
        'test': _test,
        'validation': _validation
    }
    
    binned_data[species] = splitted_data

# %% [markdown]
# ## Base Learner
# The following steps are performed for all damage classes:
# 1) Balancing the training data with SMOTE-ENN.
# 2) Backward Feature Elemination to identify the 50% most relevant features.
# 3) Perform parameter optimization of the base models
# 4) Bagging ensemble
# 5) Perform Feature Permutation Importance to calculate the relevance of the features used.
# 6) Evaluate estimates including determination of decision boundary as well as metrics
# 7) Export the results
#
# ### Damaged Vegetation

# %%
SPECIESES = ["1", "2", "1 2"]
MODELS = ["RandomForestClassifier", "BalancedRandomForestClassifier", "DecisionTreeClassifier", "KNeighborsClassifier", "SVM", "RUSBoostClassifier" , "AdaBoostClassifier", "XGBClassifier", "HistGradientBoostingClassifier"]
TARGET = "is_damaged"

binary_classifcation_results = list()

for SPECIES in SPECIESES:
    num_cols = [col for col in binned_data[SPECIES]["train"].columns if (binned_data[SPECIES]["train"][col].dtype != object)]
    sampling_strategy_over_sample = {
        "healthy": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["healthy"],
        "damaged": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["damaged"],
        "dead": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["healthy"]
    }
    sampler = SMOTEENN(sampling_strategy=sampling_strategy_over_sample, smote=SMOTE(random_state=2022, k_neighbors=6, sampling_strategy=sampling_strategy_over_sample), enn=EditedNearestNeighbours(n_neighbors=5, kind_sel="mode", n_jobs=58), random_state=2022, n_jobs=58)
    X_resampled, y_resampled = sampler.fit_resample(X=binned_data[SPECIES]["train"][num_cols], y=binned_data[SPECIES]["train"]["damage_class_group"])
    
    # over sample (TARGET WILL BECOME TWICE NUMBERS)
    sampling_strategy_under_sample = {
        "healthy": dict(Counter(y_resampled))["healthy"],
        "damaged": dict(Counter(y_resampled))["healthy"],
        "dead": dict(Counter(y_resampled))["dead"]
    }
    under_sampler = RandomUnderSampler(random_state=2022, sampling_strategy=sampling_strategy_under_sample)
    X_resampled, y_resampled = under_sampler.fit_resample(X=X_resampled[num_cols], y=y_resampled)

    for MODEL in MODELS:
        if os.path.exists(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json"):
            continue
        print("-"*100)
        print(f"{MODEL} -> {SPECIES_CODE[SPECIES]}@{TARGET}")
        print("\t performing backward feature elemination...")
        try:
            init_model_params = get_model_params(_model=MODEL, _target=TARGET, _species=SPECIES_CODE[SPECIES])
        except FileNotFoundError:
            init_model_params = {}
            
        if "class_weight" in init_model_params:
            init_model_params["class_weight"] = define_class_weight(X_resampled[TARGET])
        if "pos_scale" in init_model_params:
            init_model_params["pos_scale"] = define_pos_scale(X_resampled[TARGET])

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)
        f1_scorer = metrics.make_scorer(metrics.f1_score, **{"average": "weighted"})

        if MODEL == "RandomForestClassifier":
            model = RandomForestClassifier(**init_model_params)
        elif MODEL == "XGBClassifier":
            model = xgb.XGBClassifier(**init_model_params)
        elif MODEL == "KNeighborsClassifier":
            model = KNeighborsClassifier(**init_model_params)
        elif MODEL == "DecisionTreeClassifier":
            model = DecisionTreeClassifier(**init_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            model = HistGradientBoostingClassifier(**init_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            model = BalancedRandomForestClassifier(**init_model_params)
        elif MODEL == "RUSBoostClassifier":
            model = RUSBoostClassifier(**init_model_params)
        elif MODEL == "AdaBoostClassifier":
            model = AdaBoostClassifier(**init_model_params)
        else: #SVM
            model = SVC(**init_model_params)

        sfs = SequentialFeatureSelector(estimator=model, direction="backward", scoring=f1_scorer, cv=skf, n_jobs=58)
        sfs.fit(X_resampled[all_features], X_resampled[TARGET])
        relevant_features = list(X_resampled[all_features].columns[sfs.get_support()])

        # TRAINING DATA
        X_train = X_resampled[relevant_features]
        y_train = X_resampled[TARGET]
        # TEST DATA
        X_test = binned_data[SPECIES]["test"][relevant_features]
        y_test = binned_data[SPECIES]["test"][TARGET]

        print("\t performing hyperparameter tuning...")

        if MODEL == "RandomForestClassifier":
            params_rf = PARAMS_RF
            params_rf["class_weight"] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=RandomForestClassifier(), _params=params_rf, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = RandomForestClassifier(**fitted_model_params)
        elif MODEL == "XGBClassifier":
            params_xgb = PARAMS_XGB
            params_xgb['scale_pos_weight'] = [define_pos_scale(y_train.values)]
            fitted_model_params = parameter_tuning(_model=xgb.XGBClassifier(), _params=params_xgb, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = xgb.XGBClassifier(**fitted_model_params)
        elif MODEL == "KNeighborsClassifier":
            params_kn = PARAMS_KN
            fitted_model_params = parameter_tuning(_model=KNeighborsClassifier(), _params=params_kn, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = KNeighborsClassifier(**fitted_model_params)
        elif MODEL == "DecisionTreeClassifier":
            params_dt = PARAMS_DT
            params_dt['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=DecisionTreeClassifier(), _params=params_dt, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = DecisionTreeClassifier(**fitted_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            params_hgb = PARAMS_HGB
            fitted_model_params = parameter_tuning(_model=HistGradientBoostingClassifier(), _params=params_hgb, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = HistGradientBoostingClassifier(**fitted_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            params_brf = PARAMS_BRF
            fitted_model_params = parameter_tuning(_model=BalancedRandomForestClassifier(), _params=params_brf, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = BalancedRandomForestClassifier(**fitted_model_params)
        elif MODEL == "RUSBoostClassifier":
            params_rus = PARAMS_RUS
            fitted_model_params = parameter_tuning(_model=RUSBoostClassifier(), _params=params_rus, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = RUSBoostClassifier(**fitted_model_params)
        elif MODEL == "AdaBoostClassifier":
            params_ada = PARAMS_ADA
            fitted_model_params = parameter_tuning(_model=AdaBoostClassifier(), _params=params_ada, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = AdaBoostClassifier(**fitted_model_params)
        else:
            params_svm = PARAMS_SVM
            params_svm['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=SVC(), _params=params_svm, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = SVC(**fitted_model_params)

        # CREATING BAGGING CLASSIFIER
        model = BaggingClassifier(base_estimator=model, n_estimators=15, max_samples=.2, max_features=1., bootstrap=True, bootstrap_features=True, oob_score=True, n_jobs=16)
        print("\t fitting model...")
        model.fit(X_train, y_train)
        # save model
        pickle.dump(model, open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.sav", 'wb'))

        # predict probabilities
        y_pred_proba = model.predict_proba(X_test)

        print("\t performing permutation feature importance...")
        from sklearn.inspection import permutation_importance
        permutation_importance = permutation_importance(model, X_test, y_test, n_repeats=5, random_state=2022, n_jobs=32, scoring=f1_scorer)
        permutation_importance_obj = {}
        for i, feat_imp in enumerate(permutation_importance.importances_mean):
            permutation_importance_obj[all_features[i]] = feat_imp

        print("\t evaluating...")
        results = {}
        results["species"] = SPECIES_CODE[SPECIES]
        results["model"] = MODEL
        results["target"] = TARGET
        results["params"] = fitted_model_params
        results["relevant_features"] = relevant_features
        results["feature_permutaion_importance"] = permutation_importance_obj

        results["metrics"] = {}
        results["metrics"]["auc"] = metrics.roc_auc_score(y_test.values, y_pred_proba[:, 1])

        ## ROC AUC
        results["metrics"]["roc"] = {}
        threshold_roc, gmean_roc = roc_auc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["roc"]["threshold"] = threshold_roc
        y_pred_roc = apply_prediction(y_pred_proba[:, 1], threshold_roc)
        results["metrics"]["roc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["f1"] = metrics.f1_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["recall"] = metrics.recall_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["precision"] = metrics.precision_score(y_test.values, y_pred_roc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_roc).ravel()
        results["metrics"]["roc"]["tn"] = tn
        results["metrics"]["roc"]["fp"] = fp
        results["metrics"]["roc"]["fn"] = fn
        results["metrics"]["roc"]["tp"] = tp

        ## PRC
        results["metrics"]["prc"] = {}
        threshold_prc, fscore_prc = prc_rc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["prc"]["threshold"] = threshold_prc
        y_pred_prc = apply_prediction(y_pred_proba[:, 1], threshold_prc)
        results["metrics"]["prc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["f1"] = metrics.f1_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["recall"] = metrics.recall_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["precision"] = metrics.precision_score(y_test.values, y_pred_prc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_prc).ravel()
        results["metrics"]["prc"]["tn"] = tn
        results["metrics"]["prc"]["fp"] = fp
        results["metrics"]["prc"]["fn"] = fn
        results["metrics"]["prc"]["tp"] = tp

        ## TUNING
        results["metrics"]["tuning"] = {}
        threshold_tuning, fscore_tuneing = tune_threshold(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["tuning"]["threshold"] = threshold_tuning
        y_pred_tuning = apply_prediction(y_pred_proba[:, 1], threshold_tuning)
        results["metrics"]["tuning"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["f1"] = metrics.f1_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["recall"] = metrics.recall_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["precision"] = metrics.precision_score(y_test.values, y_pred_tuning)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_tuning).ravel()
        results["metrics"]["tuning"]["tn"] = tn
        results["metrics"]["tuning"]["fp"] = fp
        results["metrics"]["tuning"]["fn"] = fn
        results["metrics"]["tuning"]["tp"] = tp

        # quick export to dump data
        with open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json", 'w', encoding='utf-8') as f:
            json.dump(str(dict((k, v) for k,v in results.items())), f, ensure_ascii=False, indent=4)
        pd.json_normalize(results).to_csv(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.csv", index=False)

        binary_classifcation_results.append(results)

print("-"*75)
print(f"EXPORTING OVERALL RESULTS TO {EXPORT_PATH}/modelling_pipeline_results.csv")
print("-"*75)
df_result = pd.json_normalize(binary_classifcation_results)
df_result.to_csv(f"{EXPORT_PATH}/modelling_pipeline_results.csv", index=False)
df_result
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Deciduous@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Conifer@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Mixed@is_damaged
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ---------------------------------------------------------------------------
# EXPORTING OVERALL RESULTS TO ./results/optimization/v5/modelling_pipeline_results.csv
# ---------------------------------------------------------------------------
#       species                           model      target  \
# 0   Deciduous          RandomForestClassifier  is_damaged
# 1   Deciduous  BalancedRandomForestClassifier  is_damaged
# 2   Deciduous          DecisionTreeClassifier  is_damaged
# 3   Deciduous            KNeighborsClassifier  is_damaged
# 4   Deciduous                             SVM  is_damaged
# 5   Deciduous              RUSBoostClassifier  is_damaged
# 6   Deciduous              AdaBoostClassifier  is_damaged
# 7   Deciduous                   XGBClassifier  is_damaged
# 8   Deciduous  HistGradientBoostingClassifier  is_damaged
# 9     Conifer          RandomForestClassifier  is_damaged
# 10    Conifer  BalancedRandomForestClassifier  is_damaged
# 11    Conifer          DecisionTreeClassifier  is_damaged
# 12    Conifer            KNeighborsClassifier  is_damaged
# 13    Conifer                             SVM  is_damaged
# 14    Conifer              RUSBoostClassifier  is_damaged
# 15    Conifer              AdaBoostClassifier  is_damaged
# 16    Conifer                   XGBClassifier  is_damaged
# 17    Conifer  HistGradientBoostingClassifier  is_damaged
# 18      Mixed          RandomForestClassifier  is_damaged
# 19      Mixed  BalancedRandomForestClassifier  is_damaged
# 20      Mixed          DecisionTreeClassifier  is_damaged
# 21      Mixed            KNeighborsClassifier  is_damaged
# 22      Mixed                             SVM  is_damaged
# 23      Mixed              RUSBoostClassifier  is_damaged
# 24      Mixed              AdaBoostClassifier  is_damaged
# 25      Mixed                   XGBClassifier  is_damaged
# 26      Mixed  HistGradientBoostingClassifier  is_damaged
#
#                                     relevant_features params.warm_start  \
# 0   [location_cluster_2, location_cluster_3, locat...             False
# 1   [location_cluster_0, location_cluster_1, locat...             False
# 2   [location_cluster_13, tree_1, evi2, evi2_diff,...               NaN
# 3   [location_cluster_0, location_cluster_1, locat...               NaN
# 4   [location_cluster_0, location_cluster_1, locat...               NaN
# 5   [location_cluster_0, location_cluster_1, locat...               NaN
# 6   [location_cluster_0, location_cluster_1, locat...               NaN
# 7   [location_cluster_1, location_cluster_2, locat...               NaN
# 8   [location_cluster_0, location_cluster_1, locat...               NaN
# 9   [location_cluster_1, location_cluster_2, locat...              True
# 10  [location_cluster_0, location_cluster_1, locat...             False
# 11  [location_cluster_1, location_cluster_2, locat...               NaN
# 12  [location_cluster_2, location_cluster_4, locat...               NaN
# 13  [location_cluster_4, location_cluster_5, locat...               NaN
# 14  [location_cluster_1, location_cluster_4, locat...               NaN
# 15  [location_cluster_1, location_cluster_4, locat...               NaN
# 16  [location_cluster_2, location_cluster_4, locat...               NaN
# 17  [location_cluster_4, location_cluster_5, locat...               NaN
# 18  [location_cluster_0, location_cluster_2, locat...             False
# 19  [location_cluster_0, location_cluster_3, locat...              True
# 20  [tree_1, evi2_raster, evi2_raster_diff, evi2_v...               NaN
# 21  [location_cluster_2, location_cluster_3, locat...               NaN
# 22  [location_cluster_3, location_cluster_4, locat...               NaN
# 23  [location_cluster_1, location_cluster_2, locat...               NaN
# 24  [location_cluster_1, location_cluster_4, locat...               NaN
# 25  [location_cluster_0, location_cluster_2, locat...               NaN
# 26  [location_cluster_0, location_cluster_3, locat...               NaN
#
#     params.random_state  params.n_jobs  params.n_estimators  \
# 0                2022.0           58.0                160.0
# 1                2022.0           58.0                336.0
# 2                2022.0            NaN                  NaN
# 3                   NaN           58.0                  NaN
# 4                2022.0            NaN                  NaN
# 5                2022.0            NaN                470.0
# 6                2022.0            NaN                380.0
# 7                   NaN           58.0                335.0
# 8                2022.0            NaN                  NaN
# 9                2022.0           58.0                 80.0
# 10               2022.0           58.0                464.0
# 11               2022.0            NaN                  NaN
# 12                  NaN           58.0                  NaN
# 13               2022.0            NaN                  NaN
# 14               2022.0            NaN                440.0
# 15               2022.0            NaN                455.0
# 16                  NaN           58.0                470.0
# 17               2022.0            NaN                  NaN
# 18               2022.0           58.0                384.0
# 19               2022.0           58.0                480.0
# 20               2022.0            NaN                  NaN
# 21                  NaN           58.0                  NaN
# 22               2022.0            NaN                  NaN
# 23               2022.0            NaN                440.0
# 24               2022.0            NaN                455.0
# 25                  NaN           58.0                470.0
# 26               2022.0            NaN                  NaN
#
#     params.min_samples_split  params.min_samples_leaf params.max_features  \
# 0                        6.0                      2.0                sqrt
# 1                        6.0                      2.0                sqrt
# 2                       26.0                      3.0                log2
# 3                        NaN                      NaN                 NaN
# 4                        NaN                      NaN                 NaN
# 5                        NaN                      NaN                 NaN
# 6                        NaN                      NaN                 NaN
# 7                        NaN                      NaN                 NaN
# 8                        NaN                     23.0                 NaN
# 9                        4.0                      2.0                sqrt
# 10                       2.0                      2.0                sqrt
# 11                       4.0                      5.0                sqrt
# 12                       NaN                      NaN                 NaN
# 13                       NaN                      NaN                 NaN
# 14                       NaN                      NaN                 NaN
# 15                       NaN                      NaN                 NaN
# 16                       NaN                      NaN                 NaN
# 17                       NaN                     10.0                 NaN
# 18                       2.0                      2.0                sqrt
# 19                       4.0                      2.0                sqrt
# 20                      12.0                     15.0                sqrt
# 21                       NaN                      NaN                 NaN
# 22                       NaN                      NaN                 NaN
# 23                       NaN                      NaN                 NaN
# 24                       NaN                      NaN                 NaN
# 25                       NaN                      NaN                 NaN
# 26                       NaN                     19.0                 NaN
#
#     params.max_depth  params.class_weight.1  params.class_weight.0  \
# 0              160.0               1.593548               0.728614
# 1              240.0                    NaN                    NaN
# 2                7.0               1.593548               0.728614
# 3                NaN                    NaN                    NaN
# 4                NaN               1.593548               0.728614
# 5                NaN                    NaN                    NaN
# 6                NaN                    NaN                    NaN
# 7                7.0                    NaN                    NaN
# 8               78.0                    NaN                    NaN
# 9              192.0               1.699173               0.708477
# 10             144.0                    NaN                    NaN
# 11               6.0               1.699173               0.708477
# 12               NaN                    NaN                    NaN
# 13               NaN               1.699173               0.708477
# 14               NaN                    NaN                    NaN
# 15               NaN                    NaN                    NaN
# 16               6.0                    NaN                    NaN
# 17               8.0                    NaN                    NaN
# 18              16.0               1.569873               0.733673
# 19             240.0                    NaN                    NaN
# 20              15.0               1.569873               0.733673
# 21               NaN                    NaN                    NaN
# 22               NaN               1.569873               0.733673
# 23               NaN                    NaN                    NaN
# 24               NaN                    NaN                    NaN
# 25               6.0                    NaN                    NaN
# 26              78.0                    NaN                    NaN
#
#     feature_permutaion_importance.location_cluster_0  \
# 0                                           0.009460
# 1                                           0.003626
# 2                                           0.000000
# 3                                          -0.011434
# 4                                          -0.012784
# 5                                          -0.000487
# 6                                          -0.003410
# 7                                           0.004427
# 8                                           0.016143
# 9                                          -0.003764
# 10                                         -0.004779
# 11                                          0.023772
# 12                                          0.004681
# 13                                          0.011658
# 14                                         -0.004852
# 15                                         -0.010999
# 16                                          0.004411
# 17                                          0.046188
# 18                                         -0.008851
# 19                                         -0.002511
# 20                                          0.037741
# 21                                          0.009790
# 22                                         -0.000691
# 23                                         -0.013933
# 24                                         -0.004606
# 25                                         -0.001581
# 26                                          0.006436
#
#     feature_permutaion_importance.location_cluster_1  \
# 0                
# 26                              0.002630
#
#     feature_permutaion_importance.evi2_diff  \
# 0                                  0.011244
# 1                                 -0.001695
# 2                                 -0.001658
# 3                                  0.004385
# 4                                 -0.022573
# 5                                 -0.015896
# 6                                 -0.007961
# 7                                  0.009522
# 8                                  0.003334
# 9                                  0.004411
# 10                                 0.014017
# 11                                 0.000000
# 12                                -0.005027
# 13                                 0.000973
# 14                                -0.004612
# 15                                -0.003510
# 16                                 0.011098
# 17                                -0.000634
# 18                                -0.004863
# 19                                 0.000475
# 20                                 0.000000
# 21                                 0.006483
# 22                                 0.008031
# 23                                -0.001508
# 24                                -0.003312
# 25                                 0.005784
# 26                                -0.002718
#
#     feature_permutaion_importance.evi2_max_diff  \
# 0                                      0.001901
# 1                                     -0.013254
# 2                                      0.000000
# 3                                      0.004153
# 4                                     -0.023932
# 5                                     -0.007951
# 6                                      0.001783
# 7                                      0.002994
# 8                                      0.003562
# 9                                      0.000079
# 10                                     0.002659
# 11                                     0.000000
# 12                                    -0.014088
# 13                                     0.004677
# 14                                     0.015152
# 15                                    -0.005062
# 16                                     0.014770
# 17                                     0.005701
# 18                                    -0.009545
# 19                                    -0.000960
# 20                                     0.000000
# 21                                     0.019007
# 22                                     0.004050
# 23                                    -0.001725
# 24                                    -0.000463
# 25                                    -0.004212
# 26                                     0.006230
#
#     feature_permutaion_importance.evi2_raster  \
# 0                                    0.001286
# 1                                    0.001712
# 2                                    0.000000
# 3                                    0.027839
# 4                                    0.015720
# 5                                    0.010957
# 6                                   -0.031217
# 7                                   -0.000140
# 8                                    0.005522
# 9                                   -0.009609
# 10                                  -0.002226
# 11                                   0.000000
# 12                                   0.007074
# 13                                   0.013943
# 14                                  -0.004260
# 15                                   0.000411
# 16                                  -0.008823
# 17                                   0.047457
# 18                                   0.004537
# 19                                   0.008051
# 20                                   0.000735
# 21                                   0.004021
# 22                                   0.014240
# 23                                  -0.008823
# 24                                  -0.001375
# 25                                  -0.002224
# 26                                   0.007075
#
#     feature_permutaion_importance.evi2_raster-1  \
# ...
# 12                           NaN                    NaN              NaN
# 13                           NaN                    NaN              NaN
# 14                           NaN                    NaN              NaN
# 15                           NaN                    NaN              NaN
# 16                           NaN                    NaN              NaN
# 17                           NaN                   99.0              NaN
# 18                           NaN                    NaN              NaN
# 19                           NaN                    NaN              NaN
# 20                          0.05                 1153.0             gini
# 21                           NaN                    NaN              NaN
# 22                           NaN                    NaN              NaN
# 23                           NaN                    NaN              NaN
# 24                           NaN                    NaN              NaN
# 25                           NaN                    NaN              NaN
# 26                           NaN                  106.0              NaN
#
#     params.ccp_alpha params.weights  params.p  params.n_neighbors  \
# 0                NaN            NaN       NaN                 NaN
# 1                NaN            NaN       NaN                 NaN
# 2                0.0            NaN       NaN                 NaN
# 3                NaN       distance       1.0                11.0
# 4                NaN            NaN       NaN                 NaN
# 5                NaN            NaN       NaN                 NaN
# 6                NaN            NaN       NaN                 NaN
# 7                NaN            NaN       NaN                 NaN
# 8                NaN            NaN       NaN                 NaN
# 9                NaN            NaN       NaN                 NaN
# 10               NaN            NaN       NaN                 NaN
# 11               0.0            NaN       NaN                 NaN
# 12               NaN       distance       1.0                 2.0
# 13               NaN            NaN       NaN                 NaN
# 14               NaN            NaN       NaN                 NaN
# 15               NaN            NaN       NaN                 NaN
# 16               NaN            NaN       NaN                 NaN
# 17               NaN            NaN       NaN                 NaN
# 18               NaN            NaN       NaN                 NaN
# 19               NaN            NaN       NaN                 NaN
# 20               0.0            NaN       NaN                 NaN
# 21               NaN       distance       1.0                12.0
# 22               NaN            NaN       NaN                 NaN
# 23               NaN            NaN       NaN                 NaN
# 24               NaN            NaN       NaN                 NaN
# 25               NaN            NaN       NaN                 NaN
# 26               NaN            NaN       NaN                 NaN
#
#    params.metric  params.leaf_size params.algorithm  params.tol  \
# 0            NaN               NaN              NaN         NaN
# 1            NaN               NaN              NaN         NaN
# 2            NaN               NaN              NaN         NaN
# 3      manhattan              44.0            brute         NaN
# 4            NaN               NaN              NaN       0.006
# 5            NaN               NaN          SAMME.R         NaN
# 6            NaN               NaN          SAMME.R         NaN
# 7            NaN               NaN              NaN         NaN
# 8            NaN               NaN              NaN         NaN
# 9            NaN               NaN              NaN         NaN
# 10           NaN               NaN              NaN         NaN
# 11           NaN               NaN              NaN         NaN
# 12     manhattan              30.0          kd_tree         NaN
# 13           NaN               NaN              NaN       0.007
# 14           NaN               NaN          SAMME.R         NaN
# 15           NaN               NaN          SAMME.R         NaN
# 16           NaN               NaN              NaN         NaN
# 17           NaN               NaN              NaN         NaN
# 18           NaN               NaN              NaN         NaN
# 19           NaN               NaN              NaN         NaN
# 20           NaN               NaN              NaN         NaN
# 21     manhattan              44.0          kd_tree         NaN
# 22           NaN               NaN              NaN       0.004
# 23           NaN               NaN          SAMME.R         NaN
# 24           NaN               NaN          SAMME.R         NaN
# 25           NaN               NaN              NaN         NaN
# 26           NaN               NaN              NaN         NaN
#
#    params.shrinking params.probability params.kernel  params.gamma  \
# 0               NaN                NaN           NaN           NaN
# 1               NaN                NaN           NaN           NaN
# 2               NaN                NaN           NaN           NaN
# 3               NaN                NaN           NaN           NaN
# 4              True               True           rbf         0.811
# 5               NaN                NaN           NaN           NaN
# 6               NaN                NaN           NaN           NaN
# 7               NaN                NaN           NaN         0.650
# 8               NaN                NaN           NaN           NaN
# 9               NaN                NaN           NaN           NaN
# 10              NaN                NaN           NaN           NaN
# 11              NaN                NaN           NaN           NaN
# 12              NaN                NaN           NaN           NaN
# 13            False               True           rbf         0.816
# 14              NaN                NaN           NaN           NaN
# 15              NaN                NaN           NaN           NaN
# 16              NaN                NaN           NaN         0.050
# 17              NaN                NaN           NaN           NaN
# 18              NaN                NaN           NaN           NaN
# 19              NaN                NaN           NaN           NaN
# 20              NaN                NaN           NaN           NaN
# 21              NaN                NaN           NaN           NaN
# 22             True               True           rbf         0.846
# 23              NaN                NaN           NaN           NaN
# 24              NaN                NaN           NaN           NaN
# 25              NaN                NaN           NaN         0.400
# 26              NaN                NaN           NaN           NaN
#
#    params.decision_function_shape  params.C params.replacement  \
# 0                             NaN       NaN                NaN
# 1                             NaN       NaN                NaN
# 2                             NaN       NaN                NaN
# 3                             NaN       NaN                NaN
# 4                             ovo      2.85                NaN
# 5                             NaN       NaN               True
# 6                             NaN       NaN                NaN
# 7                             NaN       NaN                NaN
# 8                             NaN       NaN                NaN
# 9                             NaN       NaN                NaN
# 10                            NaN       NaN                NaN
# 11                            NaN       NaN                NaN
# 12                            NaN       NaN                NaN
# 13                            ovo      4.35                NaN
# 14                            NaN       NaN               True
# 15                            NaN       NaN                NaN
# 16                            NaN       NaN                NaN
# 17                            NaN       NaN                NaN
# 18                            NaN       NaN                NaN
# 19                            NaN       NaN                NaN
# 20                            NaN       NaN                NaN
# 21                            NaN       NaN                NaN
# 22                            ovo      8.60                NaN
# 23                            NaN       NaN               True
# 24                            NaN       NaN                NaN
# 25                            NaN       NaN                NaN
# 26                            NaN       NaN                NaN
#
#     params.learning_rate  params.subsample  params.seed  \
# 0                    NaN               NaN          NaN
# 1                    NaN               NaN          NaN
# 2                    NaN               NaN          NaN
# 3                    NaN               NaN          NaN
# 4                    NaN               NaN          NaN
# 5                 0.0930               NaN          NaN
# 6                 0.4000               NaN          NaN
# 7                 0.0090              0.95       2022.0
# 8                 0.0365               NaN          NaN
# 9                    NaN               NaN          NaN
# 10                   NaN               NaN          NaN
# 11                   NaN               NaN          NaN
# 12                   NaN               NaN          NaN
# 13                   NaN               NaN          NaN
# 14                0.0810               NaN          NaN
# 15                0.4500               NaN          NaN
# 16                0.0090              0.90       2022.0
# 17                0.0160               NaN          NaN
# 18                   NaN               NaN          NaN
# 19                   NaN               NaN          NaN
# 20                   NaN               NaN          NaN
# 21                   NaN               NaN          NaN
# 22                   NaN               NaN          NaN
# 23                0.0670               NaN          NaN
# 24                0.4500               NaN          NaN
# 25                0.0070              0.90       2022.0
# 26                0.0490               NaN          NaN
#
#     params.scale_pos_weight params.objective  params.lambda  \
# 0                       NaN              NaN            NaN
# 1                       NaN              NaN            NaN
# 2                       NaN              NaN            NaN
# 3                       NaN              NaN            NaN
# 4                       NaN              NaN            NaN
# 5                       NaN              NaN            NaN
# 6                       NaN              NaN            NaN
# 7                  2.187097  binary:logistic            0.6
# 8                       NaN              NaN            NaN
# 9                       NaN              NaN            NaN
# 10                      NaN              NaN            NaN
# 11                      NaN              NaN            NaN
# 12                      NaN              NaN            NaN
# 13                      NaN              NaN            NaN
# 14                      NaN              NaN            NaN
# 15                      NaN              NaN            NaN
# 16                 2.398345  binary:logistic            0.1
# 17                      NaN              NaN            NaN
# 18                      NaN              NaN            NaN
# 19                      NaN              NaN            NaN
# 20                      NaN              NaN            NaN
# 21                      NaN              NaN            NaN
# 22                      NaN              NaN            NaN
# 23                      NaN              NaN            NaN
# 24                      NaN              NaN            NaN
# 25                 2.139746  binary:logistic            0.1
# 26                      NaN              NaN            NaN
#
#    params.eval_metric  params.colsample_bytree params.scoring  \
# 0                 NaN                      NaN            NaN
# 1                 NaN                      NaN            NaN
# 2                 NaN                      NaN            NaN
# 3                 NaN                      NaN            NaN
# 4                 NaN                      NaN            NaN
# 5                 NaN                      NaN            NaN
# 6                 NaN                      NaN            NaN
# 7                 auc                      0.7            NaN
# 8                 NaN                      NaN        roc_auc
# 9                 NaN                      NaN            NaN
# 10                NaN                      NaN            NaN
# 11                NaN                      NaN            NaN
# 12                NaN                      NaN            NaN
# 13                NaN                      NaN            NaN
# 14                NaN                      NaN            NaN
# 15                NaN                      NaN            NaN
# 16              aucpr                      0.8            NaN
# 17                NaN                      NaN        roc_auc
# 18                NaN                      NaN            NaN
# 19                NaN                      NaN            NaN
# 20                NaN                      NaN            NaN
# 21                NaN                      NaN            NaN
# 22                NaN                      NaN            NaN
# 23                NaN                      NaN            NaN
# 24                NaN                      NaN            NaN
# 25              aucpr                      0.5            NaN
# 26                NaN                      NaN             f1
#
#     params.max_iter          params.loss  params.l2_regularization
# 0               NaN                  NaN                       NaN
# 1               NaN                  NaN                       NaN
# 2               NaN                  NaN                       NaN
# 3               NaN                  NaN                       NaN
# 4               NaN                  NaN                       NaN
# 5               NaN                  NaN                       NaN
# 6               NaN                  NaN                       NaN
# 7               NaN                  NaN                       NaN
# 8             350.0  binary_crossentropy                      0.00
# 9               NaN                  NaN                       NaN
# 10              NaN                  NaN                       NaN
# 11              NaN                  NaN                       NaN
# 12              NaN                  NaN                       NaN
# 13              NaN                  NaN                       NaN
# 14              NaN                  NaN                       NaN
# 15              NaN                  NaN                       NaN
# 16              NaN                  NaN                       NaN
# 17            400.0  binary_crossentropy                      0.40
# 18              NaN                  NaN                       NaN
# 19              NaN                  NaN                       NaN
# 20              NaN                  NaN                       NaN
# 21              NaN                  NaN                       NaN
# 22              NaN                  NaN                       NaN
# 23              NaN                  NaN                       NaN
# 24              NaN                  NaN                       NaN
# 25              NaN                  NaN                       NaN
# 26            275.0  binary_crossentropy                      0.15

# %% [markdown]
# ### Dead Vegetation

# %%
SPECIESES = ["1", "2", "1 2"]
MODELS = ["RandomForestClassifier", "BalancedRandomForestClassifier", "DecisionTreeClassifier", "KNeighborsClassifier", "SVM", "RUSBoostClassifier" , "AdaBoostClassifier", "XGBClassifier", "HistGradientBoostingClassifier"]
TARGET = "is_dead"

binary_classifcation_results = list()

for SPECIES in SPECIESES:
    num_cols = [col for col in binned_data[SPECIES]["train"].columns if (binned_data[SPECIES]["train"][col].dtype != object)]
    sampling_strategy_over_sample = {
        "healthy": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["healthy"],
        "damaged": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["damaged"],
        "dead": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["healthy"]
    }
    sampler = SMOTEENN(sampling_strategy=sampling_strategy_over_sample, smote=SMOTE(random_state=2022, k_neighbors=6, sampling_strategy=sampling_strategy_over_sample), enn=EditedNearestNeighbours(n_neighbors=5, kind_sel="mode", n_jobs=58), random_state=2022, n_jobs=58)
    X_resampled, y_resampled = sampler.fit_resample(X=binned_data[SPECIES]["train"][num_cols], y=binned_data[SPECIES]["train"]["damage_class_group"])
    
    # over sample (TARGET WILL BECOME TWICE NUMBERS)
    sampling_strategy_under_sample = {
        "healthy": dict(Counter(y_resampled))["healthy"],
        "damaged": dict(Counter(y_resampled))["healthy"],
        "dead": dict(Counter(y_resampled))["dead"]
    }
    under_sampler = RandomUnderSampler(random_state=2022, sampling_strategy=sampling_strategy_under_sample)
    X_resampled, y_resampled = under_sampler.fit_resample(X=X_resampled[num_cols], y=y_resampled)

    for MODEL in MODELS:
        if os.path.exists(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json"):
            continue
        print("-"*100)
        print(f"{MODEL} -> {SPECIES_CODE[SPECIES]}@{TARGET}")
        print("\t performing backward feature elemination...")
        try:
            init_model_params = get_model_params(_model=MODEL, _target=TARGET, _species=SPECIES_CODE[SPECIES])
        except FileNotFoundError:
            init_model_params = {}
            
        if "class_weight" in init_model_params:
            init_model_params["class_weight"] = define_class_weight(X_resampled[TARGET])
        if "pos_scale" in init_model_params:
            init_model_params["pos_scale"] = define_pos_scale(X_resampled[TARGET])

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)
        f1_scorer = metrics.make_scorer(metrics.f1_score, **{"average": "weighted"})

        if MODEL == "RandomForestClassifier":
            model = RandomForestClassifier(**init_model_params)
        elif MODEL == "XGBClassifier":
            model = xgb.XGBClassifier(**init_model_params)
        elif MODEL == "KNeighborsClassifier":
            model = KNeighborsClassifier(**init_model_params)
        elif MODEL == "DecisionTreeClassifier":
            model = DecisionTreeClassifier(**init_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            model = HistGradientBoostingClassifier(**init_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            model = BalancedRandomForestClassifier(**init_model_params)
        elif MODEL == "RUSBoostClassifier":
            model = RUSBoostClassifier(**init_model_params)
        elif MODEL == "AdaBoostClassifier":
            model = AdaBoostClassifier(**init_model_params)
        else: #SVM
            model = SVC(**init_model_params)

        sfs = SequentialFeatureSelector(estimator=model, direction="backward", scoring=f1_scorer, cv=skf, n_jobs=58)
        sfs.fit(X_resampled[all_features], X_resampled[TARGET])
        relevant_features = list(X_resampled[all_features].columns[sfs.get_support()])

        # TRAINING DATA
        X_train = X_resampled[relevant_features]
        y_train = X_resampled[TARGET]
        # TEST DATA
        X_test = binned_data[SPECIES]["test"][relevant_features]
        y_test = binned_data[SPECIES]["test"][TARGET]

        print("\t performing hyperparameter tuning...")

        if MODEL == "RandomForestClassifier":
            params_rf = PARAMS_RF
            params_rf["class_weight"] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=RandomForestClassifier(), _params=params_rf, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = RandomForestClassifier(**fitted_model_params)
        elif MODEL == "XGBClassifier":
            params_xgb = PARAMS_XGB
            params_xgb['scale_pos_weight'] = [define_pos_scale(y_train.values)]
            fitted_model_params = parameter_tuning(_model=xgb.XGBClassifier(), _params=params_xgb, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = xgb.XGBClassifier(**fitted_model_params)
        elif MODEL == "KNeighborsClassifier":
            params_kn = PARAMS_KN
            fitted_model_params = parameter_tuning(_model=KNeighborsClassifier(), _params=params_kn, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = KNeighborsClassifier(**fitted_model_params)
        elif MODEL == "DecisionTreeClassifier":
            params_dt = PARAMS_DT
            params_dt['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=DecisionTreeClassifier(), _params=params_dt, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = DecisionTreeClassifier(**fitted_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            params_hgb = PARAMS_HGB
            fitted_model_params = parameter_tuning(_model=HistGradientBoostingClassifier(), _params=params_hgb, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = HistGradientBoostingClassifier(**fitted_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            params_brf = PARAMS_BRF
            fitted_model_params = parameter_tuning(_model=BalancedRandomForestClassifier(), _params=params_brf, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = BalancedRandomForestClassifier(**fitted_model_params)
        elif MODEL == "RUSBoostClassifier":
            params_rus = PARAMS_RUS
            fitted_model_params = parameter_tuning(_model=RUSBoostClassifier(), _params=params_rus, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = RUSBoostClassifier(**fitted_model_params)
        elif MODEL == "AdaBoostClassifier":
            params_ada = PARAMS_ADA
            fitted_model_params = parameter_tuning(_model=AdaBoostClassifier(), _params=params_ada, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = AdaBoostClassifier(**fitted_model_params)
        else:
            params_svm = PARAMS_SVM
            params_svm['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=SVC(), _params=params_svm, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = SVC(**fitted_model_params)

        # CREATING BAGGING CLASSIFIER
        model = BaggingClassifier(base_estimator=model, n_estimators=15, max_samples=.2, max_features=1., bootstrap=True, bootstrap_features=True, oob_score=True, n_jobs=16)
        print("\t fitting model...")
        model.fit(X_train, y_train)
        # save model
        pickle.dump(model, open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.sav", 'wb'))

        # predict probabilities
        y_pred_proba = model.predict_proba(X_test)

        print("\t performing permutation feature importance...")
        from sklearn.inspection import permutation_importance
        permutation_importance = permutation_importance(model, X_test, y_test, n_repeats=5, random_state=2022, n_jobs=32, scoring=f1_scorer)
        permutation_importance_obj = {}
        for i, feat_imp in enumerate(permutation_importance.importances_mean):
            permutation_importance_obj[all_features[i]] = feat_imp

        print("\t evaluating...")
        results = {}
        results["species"] = SPECIES_CODE[SPECIES]
        results["model"] = MODEL
        results["target"] = TARGET
        results["params"] = fitted_model_params
        results["relevant_features"] = relevant_features
        results["feature_permutaion_importance"] = permutation_importance_obj

        results["metrics"] = {}
        results["metrics"]["auc"] = metrics.roc_auc_score(y_test.values, y_pred_proba[:, 1])

        ## ROC AUC
        results["metrics"]["roc"] = {}
        threshold_roc, gmean_roc = roc_auc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["roc"]["threshold"] = threshold_roc
        y_pred_roc = apply_prediction(y_pred_proba[:, 1], threshold_roc)
        results["metrics"]["roc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["f1"] = metrics.f1_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["recall"] = metrics.recall_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["precision"] = metrics.precision_score(y_test.values, y_pred_roc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_roc).ravel()
        results["metrics"]["roc"]["tn"] = tn
        results["metrics"]["roc"]["fp"] = fp
        results["metrics"]["roc"]["fn"] = fn
        results["metrics"]["roc"]["tp"] = tp

        ## PRC
        results["metrics"]["prc"] = {}
        threshold_prc, fscore_prc = prc_rc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["prc"]["threshold"] = threshold_prc
        y_pred_prc = apply_prediction(y_pred_proba[:, 1], threshold_prc)
        results["metrics"]["prc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["f1"] = metrics.f1_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["recall"] = metrics.recall_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["precision"] = metrics.precision_score(y_test.values, y_pred_prc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_prc).ravel()
        results["metrics"]["prc"]["tn"] = tn
        results["metrics"]["prc"]["fp"] = fp
        results["metrics"]["prc"]["fn"] = fn
        results["metrics"]["prc"]["tp"] = tp

        ## TUNING
        results["metrics"]["tuning"] = {}
        threshold_tuning, fscore_tuneing = tune_threshold(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["tuning"]["threshold"] = threshold_tuning
        y_pred_tuning = apply_prediction(y_pred_proba[:, 1], threshold_tuning)
        results["metrics"]["tuning"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["f1"] = metrics.f1_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["recall"] = metrics.recall_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["precision"] = metrics.precision_score(y_test.values, y_pred_tuning)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_tuning).ravel()
        results["metrics"]["tuning"]["tn"] = tn
        results["metrics"]["tuning"]["fp"] = fp
        results["metrics"]["tuning"]["fn"] = fn
        results["metrics"]["tuning"]["tp"] = tp

        # quick export to dump data
        with open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json", 'w', encoding='utf-8') as f:
            json.dump(str(dict((k, v) for k,v in results.items())), f, ensure_ascii=False, indent=4)
        pd.json_normalize(results).to_csv(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.csv", index=False)

        binary_classifcation_results.append(results)

print("-"*75)
print(f"EXPORTING OVERALL RESULTS TO {EXPORT_PATH}/modelling_pipeline_results.csv")
print("-"*75)
df_result = pd.json_normalize(binary_classifcation_results)
df_result.to_csv(f"{EXPORT_PATH}/modelling_pipeline_results_dead.csv", index=False)
df_result
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Deciduous@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Conifer@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Mixed@is_dead
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ---------------------------------------------------------------------------
# EXPORTING OVERALL RESULTS TO ./results/optimization/v5/modelling_pipeline_results.csv
# ---------------------------------------------------------------------------
#       species                           model   target  \
# 0   Deciduous          RandomForestClassifier  is_dead
# 1   Deciduous  BalancedRandomForestClassifier  is_dead
# 2   Deciduous          DecisionTreeClassifier  is_dead
# 3   Deciduous            KNeighborsClassifier  is_dead
# 4   Deciduous                             SVM  is_dead
# 5   Deciduous              RUSBoostClassifier  is_dead
# 6   Deciduous              AdaBoostClassifier  is_dead
# 7   Deciduous                   XGBClassifier  is_dead
# 8   Deciduous  HistGradientBoostingClassifier  is_dead
# 9     Conifer          RandomForestClassifier  is_dead
# 10    Conifer  BalancedRandomForestClassifier  is_dead
# 11    Conifer          DecisionTreeClassifier  is_dead
# 12    Conifer            KNeighborsClassifier  is_dead
# 13    Conifer                             SVM  is_dead
# 14    Conifer              RUSBoostClassifier  is_dead
# 15    Conifer              AdaBoostClassifier  is_dead
# 16    Conifer                   XGBClassifier  is_dead
# 17    Conifer  HistGradientBoostingClassifier  is_dead
# 18      Mixed          RandomForestClassifier  is_dead
# 19      Mixed  BalancedRandomForestClassifier  is_dead
# 20      Mixed          DecisionTreeClassifier  is_dead
# 21      Mixed            KNeighborsClassifier  is_dead
# 22      Mixed                             SVM  is_dead
# 23      Mixed              RUSBoostClassifier  is_dead
# 24      Mixed              AdaBoostClassifier  is_dead
# 25      Mixed                   XGBClassifier  is_dead
# 26      Mixed  HistGradientBoostingClassifier  is_dead
#
#                                     relevant_features params.warm_start  \
# 0   [location_cluster_2, location_cluster_3, locat...             False
# 1   [location_cluster_0, location_cluster_2, locat...              True
# 2   [location_cluster_2, location_cluster_3, locat...               NaN
# 3   [location_cluster_4, location_cluster_6, locat...               NaN
# 4   [location_cluster_5, evi2_raster, evi2_vegetat...               NaN
# 5   [location_cluster_4, location_cluster_10, loca...               NaN
# 6   [location_cluster_1, location_cluster_4, locat...               NaN
# 7   [location_cluster_10, tree_1, evi2-1, evi2_ras...               NaN
# 8   [location_cluster_4, location_cluster_12, tree...               NaN
# 9   [location_cluster_3, location_cluster_5, locat...              True
# 10  [location_cluster_0, location_cluster_1, locat...             False
# 11  [location_cluster_2, location_cluster_4, locat...               NaN
# 12  [location_cluster_0, location_cluster_5, locat...               NaN
# 13  [location_cluster_4, location_cluster_5, locat...               NaN
# 14  [location_cluster_2, location_cluster_4, locat...               NaN
# 15  [location_cluster_0, location_cluster_4, locat...               NaN
# 16  [location_cluster_1, location_cluster_5, locat...               NaN
# 17  [location_cluster_5, location_cluster_10, loca...               NaN
# 18  [location_cluster_4, location_cluster_5, locat...              True
# 19  [location_cluster_5, location_cluster_11, tree...              True
# 20  [location_cluster_12, evi2-1, evi2_diff, evi2_...               NaN
# 21  [location_cluster_2, location_cluster_4, locat...               NaN
# 22  [location_cluster_5, evi2-1, evi2_raster, evi2...               NaN
# 23  [location_cluster_0, location_cluster_4, locat...               NaN
# 24  [location_cluster_0, location_cluster_4, locat...               NaN
# 25  [location_cluster_0, location_cluster_13, tree...               NaN
# 26  [location_cluster_4, location_cluster_10, loca...               NaN
#
#     params.random_state  params.n_jobs  params.n_estimators  \
# 0                2022.0           58.0                336.0
# 1                2022.0           58.0                320.0
# 2                2022.0            NaN                  NaN
# 3                   NaN           58.0                  NaN
# 4                2022.0            NaN                  NaN
# 5                2022.0            NaN                410.0
# 6                2022.0            NaN                320.0
# 7                   NaN           58.0                485.0
# 8                2022.0            NaN                  NaN
# 9                2022.0           58.0                192.0
# 10               2022.0           58.0                160.0
# 11               2022.0            NaN                  NaN
# 12                  NaN           58.0                  NaN
# 13               2022.0            NaN                  NaN
# 14               2022.0            NaN                455.0
# 15               2022.0            NaN                395.0
# 16                  NaN           58.0                215.0
# 17               2022.0            NaN                  NaN
# 18               2022.0           58.0                464.0
# 19               2022.0           58.0                304.0
# 20               2022.0            NaN                  NaN
# 21                  NaN           58.0                  NaN
# 22               2022.0            NaN                  NaN
# 23               2022.0            NaN                275.0
# 24               2022.0            NaN                350.0
# 25                  NaN           58.0                380.0
# 26               2022.0            NaN                  NaN
#
#     params.min_samples_split  params.min_samples_leaf params.max_features  \
# 0                        6.0                      2.0                sqrt
# 1                        4.0                      2.0                sqrt
# 2                       12.0                     11.0                log2
# 3                        NaN                      NaN                 NaN
# 4                        NaN                      NaN                 NaN
# 5                        NaN                      NaN                 NaN
# 6                        NaN                      NaN                 NaN
# 7                        NaN                      NaN                 NaN
# 8                        NaN                      6.0                 NaN
# 9                        6.0                      2.0                sqrt
# 10                       4.0                      2.0                sqrt
# 11                      10.0                      2.0                log2
# 12                       NaN                      NaN                 NaN
# 13                       NaN                      NaN                 NaN
# 14                       NaN                      NaN                 NaN
# 15                       NaN                      NaN                 NaN
# 16                       NaN                      NaN                 NaN
# 17                       NaN                     25.0                 NaN
# 18                      10.0                      4.0                sqrt
# 19                       8.0                      2.0                sqrt
# 20                      18.0                      8.0                sqrt
# 21                       NaN                      NaN                 NaN
# 22                       NaN                      NaN                 NaN
# 23                       NaN                      NaN                 NaN
# 24                       NaN                      NaN                 NaN
# 25                       NaN                      NaN                 NaN
# 26                       NaN                     31.0                 NaN
#
#     params.max_depth  params.class_weight.0  params.class_weight.1  \
# 0               80.0               0.796774               1.342391
# 1               96.0                    NaN                    NaN
# 2               29.0               0.796774               1.342391
# 3                NaN                    NaN                    NaN
# 4                NaN               0.796774               1.342391
# 5                NaN                    NaN                    NaN
# 6                NaN                    NaN                    NaN
# 7                7.0                    NaN                    NaN
# 8              106.0                    NaN                    NaN
# 9              176.0               0.849586               1.215131
# 10             160.0                    NaN                    NaN
# 11              21.0               0.849586               1.215131
# 12               NaN                    NaN                    NaN
# 13               NaN               0.849586               1.215131
# 14               NaN                    NaN                    NaN
# 15               NaN                    NaN                    NaN
# 16
#
#     feature_permutaion_importance.location_cluster_13  \
# 0                                           -0.001056
# 1                                           -0.005529
# 2                                            0.000000
# 3                                            0.001993
# 4                                           -0.014485
# 5                                           -0.000702
# 6                                           -0.001227
# 7                                            0.000000
# 8                                           -0.001437
# 9                                            0.000190
# 10                                           0.000095
# 11                                           0.000000
# 12                                           0.001017
# 13                                           0.000142
# 14                                          -0.001561
# 15                                          -0.000334
# 16                                          -0.000447
# 17                                          -0.000048
# 18                                          -0.002655
# 19                                          -0.001857
# 20                                           0.000427
# 21                                          -0.001576
# 22                                           0.000000
# 23                                          -0.000428
# 24                                          -0.002930
# 25                                          -0.001505
# 26                                           0.000473
#
#     feature_permutaion_importance.tree_1  feature_permutaion_importance.evi2  \
# 0                              -0.000859                           -0.003161
# 1                              -0.012190                           -0.016019
# 2                               0.009990                            0.000000
# 3                              -0.007015                            0.001879
# 4                              -0.005902                           -0.015147
# 5                              -0.004601                            0.007834
# 6                              -0.000281                           -0.000879
# 7                               0.002040                            0.000278
# 8                               0.000480                           -0.000287
# 9                              -0.000284                           -0.000142
# 10                             -0.000238                           -0.000190
# 11                              0.000000                            0.000000
# 12                              0.001916                            0.001669
# 13                              0.000095                           -0.000723
# 14                             -0.000878                           -0.000390
# 15                             -0.000811                           -0.000358
# 16                             -0.000497                           -0.000397
# 17                             -0.001378                           -0.000571
# 18                             -0.000355                            0.000000
# 19                             -0.000207                           -0.001102
# 20                             -0.000711                           -0.000709
# 21                             -0.000932                            0.002013
# 22                              0.000000                            0.000000
# 23                             -0.002277                            0.000310
# 24                             -0.000342                            0.000000
# 25                              0.000000                           -0.003685
# 26                              0.000000                            0.000336
#
#     feature_permutaion_importance.evi2-1  \
# 0                          -1.914322e-04
# 1                          -4.730376e-03
# 2                           0.000000e+00
# 3                           1.555866e-02
# 4                          -1.145041e-02
# 5                          -1.548265e-02
# 6                          -3.363313e-05
# 7                          -5.546114e-04
# 8                           1.248847e-03
# 9                          -2.370679e-04
# 10                          6.775267e-08
# 11                          0.000000e+00
# 12                          7.907588e-04
# 13                          0.000000e+00
# 14                          9.750000e-05
# 15                         -5.225256e-05
# 16                         -2.599615e-04
# 17                         -1.188337e-03
# 18                          4.260215e-03
# 19                         -1.652319e-03
# 20                         -4.975402e-04
# 21                          2.734175e-03
# 22                          0.000000e+00
# 23                         -3.559806e-04
# 24                         -3.066400e-03
# 25                          0.000000e+00
# 26                          0.000000e+00
#
#     feature_permutaion_importance.evi2_diff  \
# 0                             -1.065061e-02
# 1                             -3.124558e-03
# 2                              0.000000e+00
# 3                              2.213365e-03
# 4                             -8.585087e-03
# 5                             -5.719070e-03
# 6                              2.700098e-03
# 7                              1.056517e-02
# 8                             -1.917957e-04
# 9                             -2.370454e-04
# 10                             9.512474e-05
# 11                             0.000000e+00
# 12                             3.633361e-03
# 13                             0.000000e+00
# 14                            -9.263705e-04
# 15                             2.868260e-04
# 16                             7.035861e-04
# 17                            -9.034368e-04
# 18                             2.347689e-04
# 19                            -1.720788e-03
# 20                             4.235511e-08
# 21                             7.186555e-04
# 22                             0.000000e+00
# 23                             7.081975e-05
# 24                             1.367515e-04
# 25                            -8.211625e-04
# 26                             1.294294e-03
#
#     feature_permutaion_importance.evi2_max_diff  \
# 0                                  5.776561e-04
# 1                                 -2.316937e-03
# 2                                  1.120815e-02
# 3                                  8.999620e-04
# 4                                 -1.287407e-02
# 5                                 -2.383058e-03
# 6                                 -4.076144e-05
# 7                                 -2.773913e-04
# 8                                 -2.010604e-03
# 9                                 -4.272020e-04
# 10                                -1.426193e-04
# 11                                 0.000000e+00
# 12                                 1.384009e-03
# 13                                -4.771631e-04
# 14                                -1.950058e-04
# 15                                 1.912932e-04
# 16                                 9.898245e-05
# 17                                -1.903399e-04
# 18                                -6.564138e-03
# 19                                 1.379725e-04
# 20                                 1.495730e-03
# 21                                 4.447000e-03
# 22                                 1.087649e-03
# 23                                -1.881835e-07
# 24                                 0.000000e+00
# 25                                 3.427200e-04
# 26                                -1.709682e-03
#
#     feature_permutaion_importance.evi2_raster  \
# 0                                   -0.004211
# 1                                   -0.007027
# 2                                    0.004980
# 3                                   -0.006906
# 4                                   -0.012875
# 5                                   -0.001445
# 6                                    0.001060
# 7                                    0.005395
# 8                                   -0.002485
# 9                                   -0.000047
# 10                                   0.000143
# 11                                   0.000000
# 12                                  -0.000814
# 13                                   0.000190
# 14                                   0.000390
# 15                                   0.000622
# 16                                  -0.001152
# 17                                  -0.000666
# 18                                  -0.003748
# 19                                  -0.000138
# 20                                   0.000356
# 21                                  -0.000430
# 22                                   0.000000
# 23                                   0.001909
# 24                                   0.000274
# 25                                   0.001097
# 26                                   0.000553
#
#     feature_permutaion_importance.evi2_raster-1  \
# 0                                     -0.001535
# 1                                     -0.004924
# 2                                      0.000000
# ...
# 12                           NaN                    NaN              NaN
# 13                           NaN                    NaN              NaN
# 14                           NaN                    NaN              NaN
# 15                           NaN                    NaN              NaN
# 16                           NaN                    NaN              NaN
# 17                           NaN                   85.0              NaN
# 18                           NaN                    NaN              NaN
# 19                           NaN                    NaN              NaN
# 20                          0.00                  385.0             gini
# 21                           NaN                    NaN              NaN
# 22                           NaN                    NaN              NaN
# 23                           NaN                    NaN              NaN
# 24                           NaN                    NaN              NaN
# 25                           NaN                    NaN              NaN
# 26                           NaN                   71.0              NaN
#
#     params.ccp_alpha params.weights  params.p  params.n_neighbors  \
# 0                NaN            NaN       NaN                 NaN
# 1                NaN            NaN       NaN                 NaN
# 2                0.0            NaN       NaN                 NaN
# 3                NaN        uniform       2.0                 2.0
# 4                NaN            NaN       NaN                 NaN
# 5                NaN            NaN       NaN                 NaN
# 6                NaN            NaN       NaN                 NaN
# 7                NaN            NaN       NaN                 NaN
# 8                NaN            NaN       NaN                 NaN
# 9                NaN            NaN       NaN                 NaN
# 10               NaN            NaN       NaN                 NaN
# 11               0.0            NaN       NaN                 NaN
# 12               NaN       distance       1.0                 2.0
# 13               NaN            NaN       NaN                 NaN
# 14               NaN            NaN       NaN                 NaN
# 15               NaN            NaN       NaN                 NaN
# 16               NaN            NaN       NaN                 NaN
# 17               NaN            NaN       NaN                 NaN
# 18               NaN            NaN       NaN                 NaN
# 19               NaN            NaN       NaN                 NaN
# 20               0.0            NaN       NaN                 NaN
# 21               NaN       distance       1.0                 4.0
# 22               NaN            NaN       NaN                 NaN
# 23               NaN            NaN       NaN                 NaN
# 24               NaN            NaN       NaN                 NaN
# 25               NaN            NaN       NaN                 NaN
# 26               NaN            NaN       NaN                 NaN
#
#    params.metric  params.leaf_size params.algorithm  params.tol  \
# 0            NaN               NaN              NaN         NaN
# 1            NaN               NaN              NaN         NaN
# 2            NaN               NaN              NaN         NaN
# 3      manhattan              42.0          kd_tree         NaN
# 4            NaN               NaN              NaN       0.007
# 5            NaN               NaN          SAMME.R         NaN
# 6            NaN               NaN          SAMME.R         NaN
# 7            NaN               NaN              NaN         NaN
# 8            NaN               NaN              NaN         NaN
# 9            NaN               NaN              NaN         NaN
# 10           NaN               NaN              NaN         NaN
# 11           NaN               NaN              NaN         NaN
# 12     manhattan              42.0            brute         NaN
# 13           NaN               NaN              NaN       0.005
# 14           NaN               NaN          SAMME.R         NaN
# 15           NaN               NaN          SAMME.R         NaN
# 16           NaN               NaN              NaN         NaN
# 17           NaN               NaN              NaN         NaN
# 18           NaN               NaN              NaN         NaN
# 19           NaN               NaN              NaN         NaN
# 20           NaN               NaN              NaN         NaN
# 21     minkowski              16.0            brute         NaN
# 22           NaN               NaN              NaN       0.009
# 23           NaN               NaN          SAMME.R         NaN
# 24           NaN               NaN            SAMME         NaN
# 25           NaN               NaN              NaN         NaN
# 26           NaN               NaN              NaN         NaN
#
#    params.shrinking params.probability params.kernel  params.gamma  \
# 0               NaN                NaN           NaN           NaN
# 1               NaN                NaN           NaN           NaN
# 2               NaN                NaN           NaN           NaN
# 3               NaN                NaN           NaN           NaN
# 4              True               True           rbf         0.766
# 5               NaN                NaN           NaN           NaN
# 6               NaN                NaN           NaN           NaN
# 7               NaN                NaN           NaN         0.800
# 8               NaN                NaN           NaN           NaN
# 9               NaN                NaN           NaN           NaN
# 10              NaN                NaN           NaN           NaN
# 11              NaN                NaN           NaN           NaN
# 12              NaN                NaN           NaN           NaN
# 13            False               True           rbf         0.916
# 14              NaN                NaN           NaN           NaN
# 15              NaN                NaN           NaN           NaN
# 16              NaN                NaN           NaN         0.200
# 17              NaN                NaN           NaN           NaN
# 18              NaN                NaN           NaN           NaN
# 19              NaN                NaN           NaN           NaN
# 20              NaN                NaN           NaN           NaN
# 21              NaN                NaN           NaN           NaN
# 22            False               True           rbf         0.556
# 23              NaN                NaN           NaN           NaN
# 24              NaN                NaN           NaN           NaN
# 25              NaN                NaN           NaN         0.850
# 26              NaN                NaN           NaN           NaN
#
#    params.decision_function_shape  params.C params.replacement  \
# 0                             NaN       NaN                NaN
# 1                             NaN       NaN                NaN
# 2                             NaN       NaN                NaN
# 3                             NaN       NaN                NaN
# 4                             ovo      5.85                NaN
# 5                             NaN       NaN               True
# 6                             NaN       NaN                NaN
# 7                             NaN       NaN                NaN
# 8                             NaN       NaN                NaN
# 9                             NaN       NaN                NaN
# 10                            NaN       NaN                NaN
# 11                            NaN       NaN                NaN
# 12                            NaN       NaN                NaN
# 13                            ovo      7.10                NaN
# 14                            NaN       NaN              False
# 15                            NaN       NaN                NaN
# 16                            NaN       NaN                NaN
# 17                            NaN       NaN                NaN
# 18                            NaN       NaN                NaN
# 19                            NaN       NaN                NaN
# 20                            NaN       NaN                NaN
# 21                            NaN       NaN                NaN
# 22                            ovo      1.85                NaN
# 23                            NaN       NaN               True
# 24                            NaN       NaN                NaN
# 25                            NaN       NaN                NaN
# 26                            NaN       NaN                NaN
#
#     params.learning_rate  params.subsample  params.seed  \
# 0                    NaN               NaN          NaN
# 1                    NaN               NaN          NaN
# 2                    NaN               NaN          NaN
# 3                    NaN               NaN          NaN
# 4                    NaN               NaN          NaN
# 5                 0.0930               NaN          NaN
# 6                 0.4000               NaN          NaN
# 7                 0.0090              0.70       2022.0
# 8                 0.0230               NaN          NaN
# 9                    NaN               NaN          NaN
# 10                   NaN               NaN          NaN
# 11                   NaN               NaN          NaN
# 12                   NaN               NaN          NaN
# 13                   NaN               NaN          NaN
# 14                0.0950               NaN          NaN
# 15                0.4250               NaN          NaN
# 16                0.0090              0.65       2022.0
# 17                0.0370               NaN          NaN
# 18                   NaN               NaN          NaN
# 19                   NaN               NaN          NaN
# 20                   NaN               NaN          NaN
# 21                   NaN               NaN          NaN
# 22                   NaN               NaN          NaN
# 23                0.0830               NaN          NaN
# 24                0.4000               NaN          NaN
# 25                0.0090              0.70       2022.0
# 26                0.0455               NaN          NaN
#
#     params.scale_pos_weight params.objective  params.lambda  \
# 0                       NaN              NaN            NaN
# 1                       NaN              NaN            NaN
# 2                       NaN              NaN            NaN
# 3                       NaN              NaN            NaN
# 4                       NaN              NaN            NaN
# 5                       NaN              NaN            NaN
# 6                       NaN              NaN            NaN
# 7                  1.684783  binary:logistic            0.0
# 8                       NaN              NaN            NaN
# 9                       NaN              NaN            NaN
# 10                      NaN              NaN            NaN
# 11                      NaN              NaN            NaN
# 12                      NaN              NaN            NaN
# 13                      NaN              NaN            NaN
# 14                      NaN              NaN            NaN
# 15                      NaN              NaN            NaN
# 16                 1.430262  binary:logistic            0.4
# 17                      NaN              NaN            NaN
# 18                      NaN              NaN            NaN
# 19                      NaN              NaN            NaN
# 20                      NaN              NaN            NaN
# 21                      NaN              NaN            NaN
# 22                      NaN              NaN            NaN
# 23                      NaN              NaN            NaN
# 24                      NaN              NaN            NaN
# 25                 1.754777  binary:logistic            0.3
# 26                      NaN              NaN            NaN
#
#    params.eval_metric  params.colsample_bytree params.scoring  \
# 0                 NaN                      NaN            NaN
# 1                 NaN                      NaN            NaN
# 2                 NaN                      NaN            NaN
# 3                 NaN                      NaN            NaN
# 4                 NaN                      NaN            NaN
# 5                 NaN                      NaN            NaN
# 6                 NaN                      NaN            NaN
# 7                 auc                      0.7            NaN
# 8                 NaN                      NaN        roc_auc
# 9                 NaN                      NaN            NaN
# 10                NaN                      NaN            NaN
# 11                NaN                      NaN            NaN
# 12                NaN                      NaN            NaN
# 13                NaN                      NaN            NaN
# 14                NaN                      NaN            NaN
# 15                NaN                      NaN            NaN
# 16              aucpr                      0.5            NaN
# 17                NaN                      NaN        roc_auc
# 18                NaN                      NaN            NaN
# 19                NaN                      NaN            NaN
# 20                NaN                      NaN            NaN
# 21                NaN                      NaN            NaN
# 22                NaN                      NaN            NaN
# 23                NaN                      NaN            NaN
# 24                NaN                      NaN            NaN
# 25              aucpr                      0.5            NaN
# 26                NaN                      NaN             f1
#
#     params.max_iter          params.loss  params.l2_regularization
# 0               NaN                  NaN                       NaN
# 1               NaN                  NaN                       NaN
# 2               NaN                  NaN                       NaN
# 3               NaN                  NaN                       NaN
# 4               NaN                  NaN                       NaN
# 5               NaN                  NaN                       NaN
# 6               NaN                  NaN                       NaN
# 7               NaN                  NaN                       NaN
# 8             400.0  binary_crossentropy                      0.40
# 9               NaN                  NaN                       NaN
# 10              NaN                  NaN                       NaN
# 11              NaN                  NaN                       NaN
# 12              NaN                  NaN                       NaN
# 13              NaN                  NaN                       NaN
# 14              NaN                  NaN                       NaN
# 15              NaN                  NaN                       NaN
# 16              NaN                  NaN                       NaN
# 17            250.0  binary_crossentropy                      0.75
# 18              NaN                  NaN                       NaN
# 19              NaN                  NaN                       NaN
# 20              NaN                  NaN                       NaN
# 21              NaN                  NaN                       NaN
# 22              NaN                  NaN                       NaN
# 23              NaN                  NaN                       NaN
# 24              NaN                  NaN                       NaN
# 25              NaN                  NaN                       NaN
# 26            425.0  binary_crossentropy                      0.20

# %% [markdown]
# ### Healthy Vegetation

# %%
SPECIESES = ["1", "2", "1 2"]
MODELS = ["RandomForestClassifier", "BalancedRandomForestClassifier", "DecisionTreeClassifier", "KNeighborsClassifier", "SVM", "RUSBoostClassifier" , "AdaBoostClassifier", "XGBClassifier", "HistGradientBoostingClassifier"]
TARGET = "is_healthy"

binary_classifcation_results = list()

for SPECIES in SPECIESES:
    num_cols = [col for col in binned_data[SPECIES]["train"].columns if (binned_data[SPECIES]["train"][col].dtype != object)]
    sampling_strategy_over_sample = {
        "healthy": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["healthy"],
        "damaged": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["damaged"],
        "dead": dict(Counter(binned_data[SPECIES]["train"]["damage_class_group"]))["healthy"]
    }
    sampler = SMOTEENN(sampling_strategy=sampling_strategy_over_sample, smote=SMOTE(random_state=2022, k_neighbors=6, sampling_strategy=sampling_strategy_over_sample), enn=EditedNearestNeighbours(n_neighbors=5, kind_sel="mode", n_jobs=58), random_state=2022, n_jobs=58)
    X_resampled, y_resampled = sampler.fit_resample(X=binned_data[SPECIES]["train"][num_cols], y=binned_data[SPECIES]["train"]["damage_class_group"])
    
    # over sample (TARGET WILL BECOME TWICE NUMBERS)
    sampling_strategy_under_sample = {
        "healthy": dict(Counter(y_resampled))["healthy"],
        "damaged": dict(Counter(y_resampled))["healthy"],
        "dead": dict(Counter(y_resampled))["dead"]
    }
    under_sampler = RandomUnderSampler(random_state=2022, sampling_strategy=sampling_strategy_under_sample)
    X_resampled, y_resampled = under_sampler.fit_resample(X=X_resampled[num_cols], y=y_resampled)

    for MODEL in MODELS:
        if os.path.exists(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json"):
            continue
        print("-"*100)
        print(f"{MODEL} -> {SPECIES_CODE[SPECIES]}@{TARGET}")
        print("\t performing backward feature elemination...")
        try:
            init_model_params = get_model_params(_model=MODEL, _target=TARGET, _species=SPECIES_CODE[SPECIES])
        except FileNotFoundError:
            init_model_params = {}
            
        if "class_weight" in init_model_params:
            init_model_params["class_weight"] = define_class_weight(X_resampled[TARGET])
        if "pos_scale" in init_model_params:
            init_model_params["pos_scale"] = define_pos_scale(X_resampled[TARGET])

        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=2022)
        f1_scorer = metrics.make_scorer(metrics.f1_score, **{"average": "weighted"})

        if MODEL == "RandomForestClassifier":
            model = RandomForestClassifier(**init_model_params)
        elif MODEL == "XGBClassifier":
            model = xgb.XGBClassifier(**init_model_params)
        elif MODEL == "KNeighborsClassifier":
            model = KNeighborsClassifier(**init_model_params)
        elif MODEL == "DecisionTreeClassifier":
            model = DecisionTreeClassifier(**init_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            model = HistGradientBoostingClassifier(**init_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            model = BalancedRandomForestClassifier(**init_model_params)
        elif MODEL == "RUSBoostClassifier":
            model = RUSBoostClassifier(**init_model_params)
        elif MODEL == "AdaBoostClassifier":
            model = AdaBoostClassifier(**init_model_params)
        else: #SVM
            model = SVC(**init_model_params)

        sfs = SequentialFeatureSelector(estimator=model, direction="backward", scoring=f1_scorer, cv=skf, n_jobs=58)
        sfs.fit(X_resampled[all_features], X_resampled[TARGET])
        relevant_features = list(X_resampled[all_features].columns[sfs.get_support()])

        # TRAINING DATA
        X_train = X_resampled[relevant_features]
        y_train = X_resampled[TARGET]
        # TEST DATA
        X_test = binned_data[SPECIES]["test"][relevant_features]
        y_test = binned_data[SPECIES]["test"][TARGET]

        print("\t performing hyperparameter tuning...")

        if MODEL == "RandomForestClassifier":
            params_rf = PARAMS_RF
            params_rf["class_weight"] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=RandomForestClassifier(), _params=params_rf, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = RandomForestClassifier(**fitted_model_params)
        elif MODEL == "XGBClassifier":
            params_xgb = PARAMS_XGB
            params_xgb['scale_pos_weight'] = [define_pos_scale(y_train.values)]
            fitted_model_params = parameter_tuning(_model=xgb.XGBClassifier(), _params=params_xgb, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = xgb.XGBClassifier(**fitted_model_params)
        elif MODEL == "KNeighborsClassifier":
            params_kn = PARAMS_KN
            fitted_model_params = parameter_tuning(_model=KNeighborsClassifier(), _params=params_kn, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = KNeighborsClassifier(**fitted_model_params)
        elif MODEL == "DecisionTreeClassifier":
            params_dt = PARAMS_DT
            params_dt['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=DecisionTreeClassifier(), _params=params_dt, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = DecisionTreeClassifier(**fitted_model_params)
        elif MODEL == "HistGradientBoostingClassifier":
            params_hgb = PARAMS_HGB
            fitted_model_params = parameter_tuning(_model=HistGradientBoostingClassifier(), _params=params_hgb, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = HistGradientBoostingClassifier(**fitted_model_params)
        elif MODEL == "BalancedRandomForestClassifier":
            params_brf = PARAMS_BRF
            fitted_model_params = parameter_tuning(_model=BalancedRandomForestClassifier(), _params=params_brf, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = BalancedRandomForestClassifier(**fitted_model_params)
        elif MODEL == "RUSBoostClassifier":
            params_rus = PARAMS_RUS
            fitted_model_params = parameter_tuning(_model=RUSBoostClassifier(), _params=params_rus, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = RUSBoostClassifier(**fitted_model_params)
        elif MODEL == "AdaBoostClassifier":
            params_ada = PARAMS_ADA
            fitted_model_params = parameter_tuning(_model=AdaBoostClassifier(), _params=params_ada, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = AdaBoostClassifier(**fitted_model_params)
        else:
            params_svm = PARAMS_SVM
            params_svm['class_weight'] = [define_class_weight(y_train.values)]
            fitted_model_params = parameter_tuning(_model=SVC(), _params=params_svm, _scoring=f1_scorer, _X=X_train, _y=y_train)
            model = SVC(**fitted_model_params)

        # CREATING BAGGING CLASSIFIER
        model = BaggingClassifier(base_estimator=model, n_estimators=15, max_samples=.2, max_features=1., bootstrap=True, bootstrap_features=True, oob_score=True, n_jobs=16)
        print("\t fitting model...")
        model.fit(X_train, y_train)
        # save model
        pickle.dump(model, open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.sav", 'wb'))

        # predict probabilities
        y_pred_proba = model.predict_proba(X_test)

        print("\t performing permutation feature importance...")
        from sklearn.inspection import permutation_importance
        permutation_importance = permutation_importance(model, X_test, y_test, n_repeats=5, random_state=2022, n_jobs=32, scoring=f1_scorer)
        permutation_importance_obj = {}
        for i, feat_imp in enumerate(permutation_importance.importances_mean):
            permutation_importance_obj[all_features[i]] = feat_imp

        print("\t evaluating...")
        results = {}
        results["species"] = SPECIES_CODE[SPECIES]
        results["model"] = MODEL
        results["target"] = TARGET
        results["params"] = fitted_model_params
        results["relevant_features"] = relevant_features
        results["feature_permutaion_importance"] = permutation_importance_obj

        results["metrics"] = {}
        results["metrics"]["auc"] = metrics.roc_auc_score(y_test.values, y_pred_proba[:, 1])

        ## ROC AUC
        results["metrics"]["roc"] = {}
        threshold_roc, gmean_roc = roc_auc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["roc"]["threshold"] = threshold_roc
        y_pred_roc = apply_prediction(y_pred_proba[:, 1], threshold_roc)
        results["metrics"]["roc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["f1"] = metrics.f1_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["recall"] = metrics.recall_score(y_test.values, y_pred_roc)
        results["metrics"]["roc"]["precision"] = metrics.precision_score(y_test.values, y_pred_roc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_roc).ravel()
        results["metrics"]["roc"]["tn"] = tn
        results["metrics"]["roc"]["fp"] = fp
        results["metrics"]["roc"]["fn"] = fn
        results["metrics"]["roc"]["tp"] = tp

        ## PRC
        results["metrics"]["prc"] = {}
        threshold_prc, fscore_prc = prc_rc(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["prc"]["threshold"] = threshold_prc
        y_pred_prc = apply_prediction(y_pred_proba[:, 1], threshold_prc)
        results["metrics"]["prc"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["f1"] = metrics.f1_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["recall"] = metrics.recall_score(y_test.values, y_pred_prc)
        results["metrics"]["prc"]["precision"] = metrics.precision_score(y_test.values, y_pred_prc)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_prc).ravel()
        results["metrics"]["prc"]["tn"] = tn
        results["metrics"]["prc"]["fp"] = fp
        results["metrics"]["prc"]["fn"] = fn
        results["metrics"]["prc"]["tp"] = tp

        ## TUNING
        results["metrics"]["tuning"] = {}
        threshold_tuning, fscore_tuneing = tune_threshold(y_test.values, y_pred_proba[:,1], axes=None)
        results["metrics"]["tuning"]["threshold"] = threshold_tuning
        y_pred_tuning = apply_prediction(y_pred_proba[:, 1], threshold_tuning)
        results["metrics"]["tuning"]["cohen_kappa"] = metrics.cohen_kappa_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["f1"] = metrics.f1_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["recall"] = metrics.recall_score(y_test.values, y_pred_tuning)
        results["metrics"]["tuning"]["precision"] = metrics.precision_score(y_test.values, y_pred_tuning)
        tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_pred_tuning).ravel()
        results["metrics"]["tuning"]["tn"] = tn
        results["metrics"]["tuning"]["fp"] = fp
        results["metrics"]["tuning"]["fn"] = fn
        results["metrics"]["tuning"]["tp"] = tp

        # quick export to dump data
        with open(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.json", 'w', encoding='utf-8') as f:
            json.dump(str(dict((k, v) for k,v in results.items())), f, ensure_ascii=False, indent=4)
        pd.json_normalize(results).to_csv(f"{EXPORT_PATH}/{MODEL}_{SPECIES_CODE[SPECIES]}_{TARGET}.csv", index=False)

        binary_classifcation_results.append(results)

print("-"*75)
print(f"EXPORTING OVERALL RESULTS TO {EXPORT_PATH}/modelling_pipeline_results.csv")
print("-"*75)
df_result = pd.json_normalize(binary_classifcation_results)
df_result.to_csv(f"{EXPORT_PATH}/modelling_pipeline_results_healthy.csv", index=False)
df_result
# Out:
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Deciduous@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Conifer@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RandomForestClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# BalancedRandomForestClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# DecisionTreeClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# KNeighborsClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# SVM -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# RUSBoostClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# AdaBoostClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# XGBClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ----------------------------------------------------------------------------------------------------
# HistGradientBoostingClassifier -> Mixed@is_healthy
# 	 performing backward feature elemination...
# 	 performing hyperparameter tuning...
# 	 fitting model...
# 	 performing permutation feature importance...
# 	 evaluating...
# ---------------------------------------------------------------------------
# EXPORTING OVERALL RESULTS TO ./results/optimization/v5/modelling_pipeline_results.csv
# ---------------------------------------------------------------------------
#       species                           model      target  \
# 0   Deciduous          RandomForestClassifier  is_healthy
# 1   Deciduous  BalancedRandomForestClassifier  is_healthy
# 2   Deciduous          DecisionTreeClassifier  is_healthy
# 3   Deciduous            KNeighborsClassifier  is_healthy
# 4   Deciduous                             SVM  is_healthy
# 5   Deciduous              RUSBoostClassifier  is_healthy
# 6   Deciduous              AdaBoostClassifier  is_healthy
# 7   Deciduous                   XGBClassifier  is_healthy
# 8   Deciduous  HistGradientBoostingClassifier  is_healthy
# 9     Conifer          RandomForestClassifier  is_healthy
# 10    Conifer  BalancedRandomForestClassifier  is_healthy
# 11    Conifer          DecisionTreeClassifier  is_healthy
# 12    Conifer            KNeighborsClassifier  is_healthy
# 13    Conifer                             SVM  is_healthy
# 14    Conifer              RUSBoostClassifier  is_healthy
# 15    Conifer              AdaBoostClassifier  is_healthy
# 16    Conifer                   XGBClassifier  is_healthy
# 17    Conifer  HistGradientBoostingClassifier  is_healthy
# 18      Mixed          RandomForestClassifier  is_healthy
# 19      Mixed  BalancedRandomForestClassifier  is_healthy
# 20      Mixed          DecisionTreeClassifier  is_healthy
# 21      Mixed            KNeighborsClassifier  is_healthy
# 22      Mixed                             SVM  is_healthy
# 23      Mixed              RUSBoostClassifier  is_healthy
# 24      Mixed              AdaBoostClassifier  is_healthy
# 25      Mixed                   XGBClassifier  is_healthy
# 26      Mixed  HistGradientBoostingClassifier  is_healthy
#
#                                     relevant_features params.warm_start  \
# 0   [location_cluster_0, location_cluster_3, locat...             False
# 1   [location_cluster_0, location_cluster_1, locat...              True
# 2   [location_cluster_8, location_cluster_9, locat...               NaN
# 3   [location_cluster_4, location_cluster_5, locat...               NaN
# 4   [location_cluster_0, location_cluster_1, locat...               NaN
# 5   [location_cluster_4, location_cluster_5, tree_...               NaN
# 6   [location_cluster_3, location_cluster_5, locat...               NaN
# 7   [location_cluster_0, location_cluster_1, locat...               NaN
# 8   [location_cluster_0, location_cluster_4, locat...               NaN
# 9   [location_cluster_0, location_cluster_2, locat...             False
# 10  [location_cluster_1, location_cluster_4, locat...              True
# 11  [location_cluster_3, location_cluster_4, locat...               NaN
# 12  [location_cluster_2, location_cluster_3, locat...               NaN
# 13  [location_cluster_1, location_cluster_4, locat...               NaN
# 14  [location_cluster_1, location_cluster_4, locat...               NaN
# 15  [location_cluster_0, location_cluster_1, locat...               NaN
# 16  [location_cluster_0, location_cluster_2, locat...               NaN
# 17  [location_cluster_1, location_cluster_2, locat...               NaN
# 18  [location_cluster_0, location_cluster_4, locat...             False
# 19  [location_cluster_3, location_cluster_4, locat...              True
# 20  [location_cluster_5, location_cluster_7, locat...               NaN
# 21  [location_cluster_0, location_cluster_2, locat...               NaN
# 22  [location_cluster_3, location_cluster_4, locat...               NaN
# 23  [location_cluster_2, location_cluster_3, locat...               NaN
# 24  [location_cluster_3, location_cluster_4, locat...               NaN
# 25  [location_cluster_2, location_cluster_3, locat...               NaN
# 26  [location_cluster_0, location_cluster_2, locat...               NaN
#
#     params.random_state  params.n_jobs  params.n_estimators  \
# 0                2022.0           58.0                160.0
# 1                2022.0           58.0                224.0
# 2                2022.0            NaN                  NaN
# 3                   NaN           58.0                  NaN
# 4                2022.0            NaN                  NaN
# 5                2022.0            NaN                440.0
# 6                2022.0            NaN                350.0
# 7                   NaN           58.0                485.0
# 8                2022.0            NaN                  NaN
# 9                2022.0           58.0                432.0
# 10               2022.0           58.0                448.0
# 11               2022.0            NaN                  NaN
# 12                  NaN           58.0                  NaN
# 13               2022.0            NaN                  NaN
# 14               2022.0            NaN                425.0
# 15               2022.0            NaN                440.0
# 16                  NaN           58.0                410.0
# 17               2022.0            NaN                  NaN
# 18               2022.0           58.0                224.0
# 19               2022.0           58.0                144.0
# 20               2022.0            NaN                  NaN
# 21                  NaN           58.0                  NaN
# 22               2022.0            NaN                  NaN
# 23               2022.0            NaN                440.0
# 24               2022.0            NaN                485.0
# 25                  NaN           58.0                380.0
# 26               2022.0            NaN                  NaN
#
#     params.min_samples_split  params.min_samples_leaf params.max_features  \
# 0                        2.0                      2.0                sqrt
# 1                        4.0                      2.0                sqrt
# 2                        2.0                      9.0                sqrt
# 3                        NaN                      NaN                 NaN
# 4                        NaN                      NaN                 NaN
# 5                        NaN                      NaN                 NaN
# 6                        NaN                      NaN                 NaN
# 7                        NaN                      NaN                 NaN
# 8                        NaN                     25.0                 NaN
# 9                        4.0                      2.0                sqrt
# 10                       2.0                      2.0                sqrt
# 11                      20.0                      2.0                sqrt
# 12                       NaN                      NaN                 NaN
# 13                       NaN                      NaN                 NaN
# 14                       NaN                      NaN                 NaN
# 15                       NaN                      NaN                 NaN
# 16                       NaN                      NaN                 NaN
# 17                       NaN                      5.0                 NaN
# 18                       4.0                      2.0                sqrt
# 19                       4.0                      2.0                sqrt
# 20                      28.0                      6.0                log2
# 21                       NaN                      NaN                 NaN
# 22                       NaN                      NaN                 NaN
# 23                       NaN                      NaN                 NaN
# 24                       NaN                      NaN                 NaN
# 25                       NaN                      NaN                 NaN
# 26                       NaN                     13.0                 NaN
#
#     params.max_depth  params.class_weight.0  params.class_weight.1  \
# 0               32.0               0.728614               1.593548
# 1              192.0                    NaN                    NaN
# 2                6.0               0.728614               1.593548
# 3                NaN                    NaN                    NaN
# 4                NaN               0.728614               1.593548
# 5                NaN                    NaN                    NaN
# 6                NaN                    NaN                    NaN
# 7                5.0                    NaN                    NaN
# 8              120.0                    NaN                    NaN
# 9              192.0               0.708477               1.699173
# 10             224.0                    NaN                    NaN
# 11              31.0               0.708477               1.699173
# 12               NaN                    NaN                    NaN
# 13               NaN               0.708477               1.699173
# 14               NaN                    NaN                    NaN
# 15               NaN                    NaN                    NaN
# 16               7.0                    NaN                    NaN
# 17              64.0                    NaN                    NaN
# 18             240.0               0.733673               1.569873
# 19             192.0                    NaN                    NaN
# 20               3.0               0.733673               1.569873
# 21               NaN                    NaN                    NaN
# 22               NaN               0.733673               1.569873
# 23               NaN                    NaN                    NaN
# 24               NaN                    NaN                    NaN
# 25               7.0                    NaN                    NaN
# 26              78.0                    NaN                    NaN
#
#     feature_permutaion_importance.location_cluster_0  \
# 0                                          -0.009623
# 1                                          -0.010253
# 2                                           0.001742
# 3                                           0.005432
# 4                                           0.012402
# 5                                           0.014078
# 6                                           0.018116
# 7                                          -0.000819
# 8                                           0.003170
# 9                                          -0.005334
# 10                                         -0.007055
# 11                                          0.000000
# 12                                         -0.001024
# 13                                          0.009836
# 14                                         -0.004158
# 15                                          0.008131
# 16                                         -0.009148
# 17                                          0.004952
# 18                                         -0.003100
# 19                                          0.012119
# 20                                          0.009225
# 21                                         -0.001631
# 22                                         -0.001199
# 23                                          0.001998
# 24                                          0.001341
# 25                                          0.003251
# 26                                         -0.001712
#
#     feature_permutaion_importance.location_cluster_1  \
# 0                
# 25                             -0.006506                           -0.000667
# 26                             -0.005779                            0.000345
#
#     feature_permutaion_importance.evi2-1  \
# 0                              -0.005954
# 1                               0.001557
# 2                               0.000000
# 3                               0.001691
# 4                               0.005484
# 5                               0.020105
# 6                               0.014866
# 7                              -0.000820
# 8                               0.009396
# 9                              -0.017787
# 10                              0.015471
# 11                             -0.002745
# 12                             -0.007052
# 13                              0.031622
# 14                             -0.002798
# 15                              0.001077
# 16                              0.008655
# 17                              0.011381
# 18                             -0.003226
# 19                              0.007609
# 20                              0.007173
# 21                             -0.010962
# 22                              0.000071
# 23                              0.000779
# 24                             -0.001213
# 25                              0.003587
# 26                              0.011184
#
#     feature_permutaion_importance.evi2_diff  \
# 0                                 -0.001174
# 1                                  0.001105
# 2                                 -0.015103
# 3                                  0.004495
# 4                                  0.003188
# 5                                 -0.000750
# 6                                 -0.007647
# 7                                  0.009846
# 8                                 -0.006035
# 9                                 -0.002699
# 10                                 0.012705
# 11                                 0.001613
# 12                                -0.019037
# 13                                 0.006200
# 14                                -0.007649
# 15                                -0.001032
# 16                                -0.002338
# 17                                 0.002610
# 18                                 0.006845
# 19                                 0.025472
# 20                                -0.003815
# 21                                -0.007624
# 22                                 0.004620
# 23                                -0.012592
# 24                                -0.006124
# 25                                 0.026742
# 26                                 0.007203
#
#     feature_permutaion_importance.evi2_max_diff  \
# 0                                      0.003391
# 1                                      0.012319
# 2                                      0.000000
# 3                                     -0.000563
# 4                                      0.003458
# 5                                     -0.004825
# 6                                      0.014754
# 7                                      0.007644
# 8                                     -0.000919
# 9                                     -0.016218
# 10                                    -0.000464
# 11                                     0.000248
# 12                                    -0.002020
# 13                                     0.012891
# 14                                     0.000812
# 15                                     0.012903
# 16                                     0.001120
# 17                                    -0.000578
# 18                                     0.000192
# 19                                     0.004774
# 20                                     0.013718
# 21                                     0.003317
# 22                                    -0.008469
# 23                                     0.001569
# 24                                    -0.004584
# 25                                    -0.004655
# 26                                    -0.005174
#
#     feature_permutaion_importance.evi2_raster  \
# 0                                    0.007321
# 1                                    0.022568
# 2                                    0.000000
# 3                                    0.011778
# 4                                    0.012180
# 5                                    0.001393
# 6                                    0.000311
# 7                                    0.015346
# 8                                    0.000380
# 9                                   -0.000804
# 10                                   0.000429
# 11                                   0.003632
# 12                                  -0.010866
# 13                                   0.011837
# 14                                   0.011015
# 15                                  -0.004375
# 16                                  -0.000850
# 17                                   0.004305
# 18                                  -0.010574
# 19                                   0.035429
# 20                                   0.007517
# 21                                  -0.009519
# 22                                   0.003645
# 23                                   0.017085
# 24                                  -0.020043
# 25                                   0.001865
# 26                                  -0.003246
#
#     feature_permutaion_importance.evi2_raster-1  \
# ...
# 12                           NaN                    NaN              NaN
# 13                           NaN                    NaN              NaN
# 14                           NaN                    NaN              NaN
# 15                           NaN                    NaN              NaN
# 16                           NaN                    NaN              NaN
# 17                           NaN                   36.0              NaN
# 18                           NaN                    NaN              NaN
# 19                           NaN                    NaN              NaN
# 20                          0.00                  513.0          entropy
# 21                           NaN                    NaN              NaN
# 22                           NaN                    NaN              NaN
# 23                           NaN                    NaN              NaN
# 24                           NaN                    NaN              NaN
# 25                           NaN                    NaN              NaN
# 26                           NaN                   43.0              NaN
#
#     params.ccp_alpha params.weights  params.p  params.n_neighbors  \
# 0                NaN            NaN       NaN                 NaN
# 1                NaN            NaN       NaN                 NaN
# 2                0.0            NaN       NaN                 NaN
# 3                NaN       distance       1.0                16.0
# 4                NaN            NaN       NaN                 NaN
# 5                NaN            NaN       NaN                 NaN
# 6                NaN            NaN       NaN                 NaN
# 7                NaN            NaN       NaN                 NaN
# 8                NaN            NaN       NaN                 NaN
# 9                NaN            NaN       NaN                 NaN
# 10               NaN            NaN       NaN                 NaN
# 11               0.0            NaN       NaN                 NaN
# 12               NaN       distance       1.0                10.0
# 13               NaN            NaN       NaN                 NaN
# 14               NaN            NaN       NaN                 NaN
# 15               NaN            NaN       NaN                 NaN
# 16               NaN            NaN       NaN                 NaN
# 17               NaN            NaN       NaN                 NaN
# 18               NaN            NaN       NaN                 NaN
# 19               NaN            NaN       NaN                 NaN
# 20               0.0            NaN       NaN                 NaN
# 21               NaN       distance       2.0                 3.0
# 22               NaN            NaN       NaN                 NaN
# 23               NaN            NaN       NaN                 NaN
# 24               NaN            NaN       NaN                 NaN
# 25               NaN            NaN       NaN                 NaN
# 26               NaN            NaN       NaN                 NaN
#
#    params.metric  params.leaf_size params.algorithm  params.tol  \
# 0            NaN               NaN              NaN         NaN
# 1            NaN               NaN              NaN         NaN
# 2            NaN               NaN              NaN         NaN
# 3      minkowski              44.0          kd_tree         NaN
# 4            NaN               NaN              NaN       0.003
# 5            NaN               NaN          SAMME.R         NaN
# 6            NaN               NaN          SAMME.R         NaN
# 7            NaN               NaN              NaN         NaN
# 8            NaN               NaN              NaN         NaN
# 9            NaN               NaN              NaN         NaN
# 10           NaN               NaN              NaN         NaN
# 11           NaN               NaN              NaN         NaN
# 12     minkowski              24.0        ball_tree         NaN
# 13           NaN               NaN              NaN       0.002
# 14           NaN               NaN          SAMME.R         NaN
# 15           NaN               NaN          SAMME.R         NaN
# 16           NaN               NaN              NaN         NaN
# 17           NaN               NaN              NaN         NaN
# 18           NaN               NaN              NaN         NaN
# 19           NaN               NaN              NaN         NaN
# 20           NaN               NaN              NaN         NaN
# 21     manhattan              34.0        ball_tree         NaN
# 22           NaN               NaN              NaN       0.001
# 23           NaN               NaN          SAMME.R         NaN
# 24           NaN               NaN          SAMME.R         NaN
# 25           NaN               NaN              NaN         NaN
# 26           NaN               NaN              NaN         NaN
#
#    params.shrinking params.probability params.kernel  params.gamma  \
# 0               NaN                NaN           NaN           NaN
# 1               NaN                NaN           NaN           NaN
# 2               NaN                NaN           NaN           NaN
# 3               NaN                NaN           NaN           NaN
# 4              True               True          poly         0.506
# 5               NaN                NaN           NaN           NaN
# 6               NaN                NaN           NaN           NaN
# 7               NaN                NaN           NaN         0.650
# 8               NaN                NaN           NaN           NaN
# 9               NaN                NaN           NaN           NaN
# 10              NaN                NaN           NaN           NaN
# 11              NaN                NaN           NaN           NaN
# 12              NaN                NaN           NaN           NaN
# 13            False               True          poly         0.686
# 14              NaN                NaN           NaN           NaN
# 15              NaN                NaN           NaN           NaN
# 16              NaN                NaN           NaN         0.950
# 17              NaN                NaN           NaN           NaN
# 18              NaN                NaN           NaN           NaN
# 19              NaN                NaN           NaN           NaN
# 20              NaN                NaN           NaN           NaN
# 21              NaN                NaN           NaN           NaN
# 22             True               True           rbf         0.951
# 23              NaN                NaN           NaN           NaN
# 24              NaN                NaN           NaN           NaN
# 25              NaN                NaN           NaN         0.200
# 26              NaN                NaN           NaN           NaN
#
#    params.decision_function_shape  params.C params.replacement  \
# 0                             NaN       NaN                NaN
# 1                             NaN       NaN                NaN
# 2                             NaN       NaN                NaN
# 3                             NaN       NaN                NaN
# 4                             ovo      4.35                NaN
# 5                             NaN       NaN               True
# 6                             NaN       NaN                NaN
# 7                             NaN       NaN                NaN
# 8                             NaN       NaN                NaN
# 9                             NaN       NaN                NaN
# 10                            NaN       NaN                NaN
# 11                            NaN       NaN                NaN
# 12                            NaN       NaN                NaN
# 13                            ovo      1.85                NaN
# 14                            NaN       NaN               True
# 15                            NaN       NaN                NaN
# 16                            NaN       NaN                NaN
# 17                            NaN       NaN                NaN
# 18                            NaN       NaN                NaN
# 19                            NaN       NaN                NaN
# 20                            NaN       NaN                NaN
# 21                            NaN       NaN                NaN
# 22                            ovo      7.10                NaN
# 23                            NaN       NaN               True
# 24                            NaN       NaN                NaN
# 25                            NaN       NaN                NaN
# 26                            NaN       NaN                NaN
#
#     params.learning_rate  params.subsample  params.seed  \
# 0                    NaN               NaN          NaN
# 1                    NaN               NaN          NaN
# 2                    NaN               NaN          NaN
# 3                    NaN               NaN          NaN
# 4                    NaN               NaN          NaN
# 5                 0.0850               NaN          NaN
# 6                 0.4000               NaN          NaN
# 7                 0.0090              0.85       2022.0
# 8                 0.0325               NaN          NaN
# 9                    NaN               NaN          NaN
# 10                   NaN               NaN          NaN
# 11                   NaN               NaN          NaN
# 12                   NaN               NaN          NaN
# 13                   NaN               NaN          NaN
# 14                0.0710               NaN          NaN
# 15                0.4250               NaN          NaN
# 16                0.0090              0.70       2022.0
# 17                0.0400               NaN          NaN
# 18                   NaN               NaN          NaN
# 19                   NaN               NaN          NaN
# 20                   NaN               NaN          NaN
# 21                   NaN               NaN          NaN
# 22                   NaN               NaN          NaN
# 23                0.0870               NaN          NaN
# 24                0.4500               NaN          NaN
# 25                0.0070              0.95       2022.0
# 26                0.0400               NaN          NaN
#
#     params.scale_pos_weight params.objective  params.lambda  \
# 0                       NaN              NaN            NaN
# 1                       NaN              NaN            NaN
# 2                       NaN              NaN            NaN
# 3                       NaN              NaN            NaN
# 4                       NaN              NaN            NaN
# 5                       NaN              NaN            NaN
# 6                       NaN              NaN            NaN
# 7                  2.187097  binary:logistic            0.4
# 8                       NaN              NaN            NaN
# 9                       NaN              NaN            NaN
# 10                      NaN              NaN            NaN
# 11                      NaN              NaN            NaN
# 12                      NaN              NaN            NaN
# 13                      NaN              NaN            NaN
# 14                      NaN              NaN            NaN
# 15                      NaN              NaN            NaN
# 16                 2.398345  binary:logistic            0.9
# 17                      NaN              NaN            NaN
# 18                      NaN              NaN            NaN
# 19                      NaN              NaN            NaN
# 20                      NaN              NaN            NaN
# 21                      NaN              NaN            NaN
# 22                      NaN              NaN            NaN
# 23                      NaN              NaN            NaN
# 24                      NaN              NaN            NaN
# 25                 2.139746  binary:logistic            0.1
# 26                      NaN              NaN            NaN
#
#    params.eval_metric  params.colsample_bytree params.scoring  \
# 0                 NaN                      NaN            NaN
# 1                 NaN                      NaN            NaN
# 2                 NaN                      NaN            NaN
# 3                 NaN                      NaN            NaN
# 4                 NaN                      NaN            NaN
# 5                 NaN                      NaN            NaN
# 6                 NaN                      NaN            NaN
# 7               aucpr                     0.70            NaN
# 8                 NaN                      NaN        roc_auc
# 9                 NaN                      NaN            NaN
# 10                NaN                      NaN            NaN
# 11                NaN                      NaN            NaN
# 12                NaN                      NaN            NaN
# 13                NaN                      NaN            NaN
# 14                NaN                      NaN            NaN
# 15                NaN                      NaN            NaN
# 16                auc                     0.50            NaN
# 17                NaN                      NaN        roc_auc
# 18                NaN                      NaN            NaN
# 19                NaN                      NaN            NaN
# 20                NaN                      NaN            NaN
# 21                NaN                      NaN            NaN
# 22                NaN                      NaN            NaN
# 23                NaN                      NaN            NaN
# 24                NaN                      NaN            NaN
# 25                auc                     0.75            NaN
# 26                NaN                      NaN        roc_auc
#
#     params.max_iter          params.loss  params.l2_regularization
# 0               NaN                  NaN                       NaN
# 1               NaN                  NaN                       NaN
# 2               NaN                  NaN                       NaN
# 3               NaN                  NaN                       NaN
# 4               NaN                  NaN                       NaN
# 5               NaN                  NaN                       NaN
# 6               NaN                  NaN                       NaN
# 7               NaN                  NaN                       NaN
# 8             375.0  binary_crossentropy                      0.80
# 9               NaN                  NaN                       NaN
# 10              NaN                  NaN                       NaN
# 11              NaN                  NaN                       NaN
# 12              NaN                  NaN                       NaN
# 13              NaN                  NaN                       NaN
# 14              NaN                  NaN                       NaN
# 15              NaN                  NaN                       NaN
# 16              NaN                  NaN                       NaN
# 17            400.0  binary_crossentropy                      0.25
# 18              NaN                  NaN                       NaN
# 19              NaN                  NaN                       NaN
# 20              NaN                  NaN                       NaN
# 21              NaN                  NaN                       NaN
# 22              NaN                  NaN                       NaN
# 23              NaN                  NaN                       NaN
# 24              NaN                  NaN                       NaN
# 25              NaN                  NaN                       NaN
# 26            475.0  binary_crossentropy                      0.00

# %% [markdown]
# ## Ensemble Learning: Base Model Results

# %%
df_results = [pd.read_csv(f"{EXPORT_PATH}/{file}.csv") for file in ["modelling_pipeline_results", "modelling_pipeline_results_dead", "modelling_pipeline_results_healthy"]]
df_results = pd.concat(df_results, ignore_index=True)
df_metrics, df_best_metrics, df_parameter, df_feature_importance = parse_results(df_results)
df_best_metrics
# Out:
#      group                           model      target    species       auc  \
# 0      prc          RandomForestClassifier  is_damaged    Conifer  0.758450
# 1      prc          RandomForestClassifier  is_damaged      Mixed  0.738243
# 2   tuning              AdaBoostClassifier  is_damaged      Mixed  0.768337
# 3   tuning  HistGradientBoostingClassifier  is_damaged      Mixed  0.788438
# 4      prc              AdaBoostClassifier  is_damaged  Deciduous  0.702559
# ..     ...                             ...         ...        ...       ...
# 76  tuning          DecisionTreeClassifier     is_dead    Conifer  0.802049
# 77     roc                             SVM     is_dead  Deciduous  0.469308
# 78     roc          DecisionTreeClassifier     is_dead  Deciduous  0.431910
# 79     roc  BalancedRandomForestClassifier     is_dead      Mixed  0.805140
# 80  tuning  BalancedRandomForestClassifier     is_dead  Deciduous  0.471165
#
#     threshold  cohen_kappa        f1    recall  precision    tn   fp  fn    tp
# 0    0.339557     0.515887  0.949618  0.984683   0.916964   122  163  28  1800
# 1    0.294460     0.191548  0.948625  0.991679   0.909154    20  131  11  1311
# 2    0.493000     0.229014  0.947636  0.985628   0.912465    26  125  19  1303
# 3    0.148000     0.272373  0.947368  0.980333   0.916549    33  118  26  1296
# 4    0.491952     0.434160  0.945547  0.976866   0.916174    50   85  22   929
# ..        ...          ...       ...       ...        ...   ...  ...  ..   ...
# 76   0.616000     0.020506  0.025641  0.166667   0.013889  2036   71   5     1
# 77   0.035447     0.007407  0.023609  0.777778   0.011986   500  577   2     7
# 78   0.520115     0.007092  0.023121  0.444444   0.011869   744  333   5     4
# 79   0.123400     0.016942  0.022222  1.000000   0.011236  1117  352   0     4
# 80   0.400000     0.005963  0.021898  0.333333   0.011321   815  262   6     3
#
# [81 rows x 14 columns]
